# %% [markdown]
# # Mining the Social Web
#
# ## Mining Web Pages
#
# This Jupyter Notebook provides an interactive way to follow along with and explore the examples from the video series. The intent behind this notebook is to reinforce the concepts in a fun, convenient, and effective way.

# %% [markdown]
# ## Using `dragnet` to extract the text from a web page
#
# Example blog post:
# http://radar.oreilly.com/2010/07/louvre-industrial-age-henry-ford.html
#
# In *Mining the Social Web, 3rd Edition*, we used a library called `boilerpipe` to extract the main content of web pages. `boilerpipe` is a sophisticated piece of software that works very well but has some software dependencies that can be very difficult to install, especially if you do not have administrative privileges on the computer you are working with. I have replaced `boilerpipe` with `Goose`, which can be easily installed using `pip`:
#
# `pip install goose3`
#
# You can learn more about `goose3` on its [GitHub page](https://github.com/goose3/goose3). Another example of a content extraction library for Python is `dragnet`, which you can find [here](https://github.com/dragnet-org/dragnet).

# %%
from goose3 import Goose

g = Goose()
URL='https://www.oreilly.com/ideas/ethics-in-data-project-design-its-about-planning'
article = g.extract(url=URL)

print(article.title)
print('-'*len(article.title))
print(article.meta_description)

content = article.cleaned_text
print()
print('{}...'.format(content[:500]))
# Out:
# Ethics in data project design: It's about planning
# --------------------------------------------------
# The destination and rules of the road are clear; the route you choose to get there makes a huge difference.
#
# When I explain the value of ethics to students and professionals alike, I refer it as an “orientation.” As any good designer, scientist, or researcher knows, how you orient yourself toward a problem can have a big impact on the sort of solution you develop—and how you get there. As Ralph Waldo Emerson once wrote, “perception is not whimsical, but fatal.” Your particular perspective, knowledge of, and approach to a problem shapes your solution, opening up certain paths forward and forestalling ot...

# %% [markdown]
# ## Using feedparser to extract the text (and other fields) from an RSS or Atom feed

# %%
import feedparser # pip install feedparser

FEED_URL='http://feeds.feedburner.com/oreilly/radar/atom'

fp = feedparser.parse(FEED_URL)

for e in fp.entries:
    print(e.title)
    print(e.links[0].href)
    print(e.content[0].value)
# Out:
# Four short links: 13 May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/KQ5CMAVsal8/
# <ol>
# <li><a href="https://www.wired.com/story/confessions-marcus-hutchins-hacker-who-saved-the-internet/">The Confessions of Marcus Hutchins, the Hacker Who Saved the Internet</a> &#8212; Story of the MalwareTech security researcher who foiled WannaCry, only to be arrested by the FBI for having sold malware as a kid. Young Marcus had terrible opsec.</li>
# <li><a href="https://www.nfx.com/post/next-social-era/">The Next Social Era is Here</a> &#8212; Arguing we&#8217;re ready for another boom in social software. <i>First, the pandemic is creating a new topology of psychological and emotional needs. [&#8230;] Second, the work environment is now open game for new social products. Two reasons for this. First, we see how good communication can be with consumer products and demand the same excellence in our work lives. But second, and newer, is that in the last few months, the distance between our work identities and our home identities have blurred. </i></li>
# <li><a href="https://blogs.gartner.com/martin-kihn/cookies-chaos-and-the-browser-meet-lou-montulli/">Cookies, Chaos and the Browser: Meet Lou Montulli</a> &#8212; An interview with a Web oldbie, the guy who worked on https, cookies, forms, animated GIFs, but who will always have a treasured spot in my heart for the Curses-based text-mode browser Lynx.</li>
# <li><a href="https://saagarjha.com/blog/2020/05/10/why-we-at-famous-company-switched-to-hyped-technology/">Why we at $FAMOUS_COMPANY Switched to $HYPED_TECHNOLOGY</a> &#8212; Hilarious parody of a tech announcement.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/KQ5CMAVsal8" height="1" width="1" alt=""/>
# Four short links: 12 May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/V6dF5m1ZxBM/
# <ol>
# <li><a href="https://github.com/SanderMertens/flecs">flecs</a> &#8212; <i>a Fast and Lightweight ECS (Entity Component System). An ECS [&#8230;] is a way to organize code that is mostly used in gaming and simulation projects. ECS code generally performs better than traditional OOP, and is typically easier to reuse. The main differences between ECS and OOP are composition is a first class citizen in ECS, and that data is represented as plain data types rather than encapsulated classes.</i></li>
# <li><a href="https://spin.atomicobject.com/2020/05/11/categorize-software-errors/">Two Ways to Categorize Errors</a> &#8212; <i>two dimensions that are useful for categorizing errors: Exceptional Errors vs. Failures; Internal vs. External Errors.</i> Often the first step to solving a problem is finding the right lens to look at it through.</li>
# <li><a href="https://a9.io/glue-comic/">Chatting with Glue</a> &#8212; An interestingly-presented set of ideas about how we might offer more structural affordances in chat software to assist comprehension. I&#8217;m not doing it justice: it&#8217;s provocative. How to help people think better with software is a conversation I&#8217;m always up for, so this has really hit my buttons.</li>
# <li><a href="https://fivebooks.com/best-books/politics-of-information-henry-farrell/">The Best Books on the Politics of Information</a> &#8212; <i>If we are to understand how politics and markets work at the moment, we need to pay attention to how algorithms work, and how the economy is being remade from the ground up by these new forms of information processing. [&#8230;] My starting point was ‘Okay, if we started thinking about the core of a curriculum for a course on this topic, what could we include?’ These would be the core books you would want as part of the discussion.</i></li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/V6dF5m1ZxBM" height="1" width="1" alt=""/>
# When models are everywhere
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/sGh3eBhuYOo/
# <p>You probably interact with fifty to a hundred machine learning products every day, from your social media feeds and YouTube recommendations to your email spam filter and the updates that the New York Times, CNN, or Fox News decide to push, not to mention the hidden models that place ads on the websites you visit, and that redesign your &#8216;experience&#8217; on the fly. Not all models are created equal, however: they operate on different principles, and impact us as individuals and communities in different ways. They differ fundamentally from each other along dimensions such as alignment of incentives between stakeholders, “creep factor”, and the nature of how their feedback loops operate.&nbsp;<br></p>
#
#
#
# <p>To understand the menagerie of models that are fundamentally altering our individual and shared realities, we need to build a typology, a classification of their effects and impacts. This typology is based on concepts such as the nature of different feedback loops in currently deployed algorithms, and how incentives can be aligned and misaligned between various stakeholders. Let’s start by looking at how models impact us.<br></p>
#
#
#
# <p><strong>SCREENS, FEEDBACK, AND “THE ENTERTAINMENT”</strong><br></p>
#
#
#
# <p>Many of the models you interact with are mediated through screens, and there’s no shortage of news about how many of us spend our lives glued to them. <a href="https://www.theguardian.com/technology/2018/aug/22/kids-are-glued-to-their-screens-but-parents-are-in-no-position-to-criticize">Children, parents, friends, relatives</a>: we are all subject to screens, ranging from screens that fit on our wrist to screens that occupy entire walls. You may have seen loved ones sitting on the couch, watching a smart TV while playing a game on an iPad, texting on their smartphones, and receiving update after update on their Apple Watch, a kaleidoscope of screens of decreasing size. We even have apps to monitor and limit screen time. Limiting screen time has been an option on iPhones for over a year, and there are <a href="https://www.educationalappstore.com/best-apps/best-parental-control-apps-to-monitor-and-limit-screen-time">apps</a> for iPhones and Android that not only monitor your childrens’ screen time, they let you <a href="https://www.educationalappstore.com/app/screen-time-parental-control">reward</a> them for doing their chores or their homework by giving them more. Screen time has been gamified: where are you on the leaderboard?&nbsp;<br></p>
#
#
#
# <p>We shouldn’t be surprised. In the 70s, TV wasn’t called the “boob tube” for nothing. In David Foster Wallace’s novel <em>Infinite Jest</em>, there is a video tape known as “The Entertainment.” When somebody watches it, they are unable to look away, no longer caring about food, shelter or sleep, and they eventually enter a state of immobile, catatonic bliss. There’s a telling sequence in which more and more people approach those watching it to see what all the hullabaloo is about and also end up with their eyes glued to the screen.&nbsp;<br></p>
#
#
#
# <p><em>Infinite Jest</em> was published in 1996, just as the modern Web was coming into being. It predates recommendation engines, social media, engagement metrics, and the recent explosion of AI, but not by much. And like a lot of near-future SciFi, it’s remarkably prescient. It’s a shock to read a novel about the future, and realize that you’re living that future.&nbsp;<br></p>
#
#
#
# <p>“The Entertainment” is <em>not</em> the result of algorithms, business incentives and product managers optimizing for engagement metrics. There’s no Facebook, Twitter, or even a Web; it’s a curious relic of the 80s and 90s that The Entertainment appeared in the form of a VHS tape, rather than an app. “The Entertainment” <em>is</em> a tale of the webs that connect form, content and addiction, along with the societal networks and feedback loops that keep us glued to our screens. David Foster Wallace had the general structure of the user–product interaction correct. That loop isn’t new, of course; it was well-known to TV network executives. Television only lacked the immediate feedback that comes with clicks, tracking cookies, tracking pixels, online experimentation, machine learning, and “agile” product cycles.&nbsp;&nbsp;</p>
#
#
#
# <p>Does “The Entertainment” show people what they want to see? In a highly specific, short-term sense, possibly. In a long-term sense, definitely not. Regardless of how we think of ourselves, humans aren’t terribly good at trading off short-term stimulus against long-term benefits. That’s something we’re all familiar with: we’d rather eat bacon than vegetables, we’d rather watch Game of Thrones than do homework, and so on.&nbsp; Short-term stimulus is addictive: maybe not as addictive as “The Entertainment,” but addictive nonetheless.&nbsp;&nbsp;<br></p>
#
#
#
# <p><strong>YOUTUBE, CONSPIRACY, AND OPTIMIZATION</strong><br></p>
#
#
#
# <p>We’ve seen the same argument play out on YouTube: when their recommendation algorithm was optimized for how long users would keep their eyeballs on YouTube, resulting in more polarizing conspiracy videos being shown, we were told that YouTube was showing people what they wanted to see. This is a subtle sleight-of-mind, and it’s also wrong. As Zeynep Tufekci <a href="https://www.theguardian.com/technology/2018/feb/02/how-youtubes-algorithm-distorts-truth">points out</a>, this is analogous to an automated school cafeteria loading plates with fatty, salty, and sweet food because it has figured out that’s what keeps kids in the cafeteria the longest. What’s also interesting is that YouTube never wrote &#8216;Show more polarizing conspiracy videos&#8217; into their algorithm: that was merely a result of the optimization process. YouTube’s algorithm was measuring what kept viewers there the longest, not what they wanted to see, and feeding them more of the same. Like sugar and fat, conspiracy videos proved to be addictive, regardless of the viewer’s position on any given cause. If “The Entertainment” were posted to YouTube, it would be highly recommended on the platform: viewers can’t leave. It’s the ultimate <a href="https://www.darkpatterns.org/types-of-dark-pattern/roach-motel">virtual roach trap</a>. If that’s not engagement, what is? But it’s clearly not what viewers want–viewers certainly don’t want to forget about food and shelter, not even for a great TV show.&nbsp;<br></p>
#
#
#
# <p>One result of this is that in 2016, out of 1,000 videos recommended by YouTube after an equal number of searches for “Trump” and “Clinton”,<a href="https://www.theguardian.com/technology/2018/feb/02/youtube-algorithm-election-clinton-trump-guillaume-chaslot"> 86% of recommended videos favored the Republican nominee</a>. In retrospect, the recommendation algorithm’s “logic” is inescapable. If you’re a Democrat, Trump videos made you mad. If you’re a Republican, Trump’s content was designed to make you mad. And anger and polarization are bankable commodities that drive the feedback loop in an engagement-driven world.&nbsp;<br></p>
#
#
#
# <p>Another result is the weirdness encountered in certain parts of kids’ Youtube, such as “<a href="https://vicki.substack.com/p/the-reign-of-big-recsys">surprise Eggs videos [that] depict, often at excruciating length, the process of unwrapping Kinder and other egg toys</a>.” Some of these have up to<a href="http://nymag.com/intelligencer/2016/04/inside-the-strange-world-of-million-view-surprise-egg-youtube-videos.html"> 66 million views</a>. These are all results of business incentives for both YouTube and its content providers, the metrics used to measure success and the power of feedback loops on an individual level and in society, as manifested in modern big tech recommender systems.&nbsp;<br></p>
#
#
#
# <p>It’s important to note that the incentives of YouTube, its advertisers, and its users are often misaligned, in that users searching for “real news” continually end up being shunted down conspiracy theory and “fake news” rabbit holes due to the mixed incentive structure of the advertising-based business model. Such mixed incentives were even noted by Google founders Sergey Brin and Larry Page in their 1998 paper <em>The Anatomy of a Large-Scale Hypertextual Web Search Engine</em>, which details their first implementation of the Google Search algorithm. In <a href="http://infolab.stanford.edu/~backrub/google.html#a">Appendix A</a>, aptly titled ‘Advertising and Mixed Motives’, Brin and Page state explicitly that “the goals of the advertising business model do not always correspond to providing quality search to users” and “we expect that advertising funded search engines will be inherently biased towards the advertisers and away from the needs of the consumers.” *Gulp*. Also note that they refer to the user of Search here as a consumer.</p>
#
#
#
# <p><strong>FEEDBACK LOOPS, FILTER BUBBLES, ECHO CHAMBERS, AND INCENTIVE STRUCTURES</strong><br></p>
#
#
#
# <p>YouTube is a case study on the impact of feedback loops on the individual: if I watch something for a certain amount of time, YouTube will recommend similar things to me, for some definition of similar (similarity is defined by broader societal interactions with content), resulting in what we now call “filter bubbles”, a term coined by internet activist Eli Pariser in his 2011 book <a href="https://books.google.com/books/about/The_Filter_Bubble.html?id=-FWO0puw3nYC"><em>The Filter Bubble: What the Internet Is Hiding from You</em></a>. Netflix’s algorithm has historically resulted in similar types of recommendations and filter bubbles (although business incentives are now forcing them to<a href="https://vicki.substack.com/p/big-recsys-redux-recs-at-netflix"> surface more of their own content</a>).</p>
#
#
#
# <p>Twitter and Facebook have feedback loops that operate slightly differently, because every user can be both a content provider and a consumer, and the recommendations arise from a network of multi-sided interactions. If I’m sharing content and liking content, the respective algorithms will show me more that is similar to both, resulting in what we call “echo chambers.” These echo chambers represent a different kind of feedback that doesn’t just involve a single user: it’s a feedback loop that involves the user and their connections. The network that directly impacts me is that of my connections and the people I follow.&nbsp;<br></p>
#
#
#
# <p>We don’t have to look far to see other feedback loops offline. There are runaway <a href="https://www.smithsonianmag.com/innovation/artificial-intelligence-is-now-used-predict-crime-is-it-biased-180968337/">feedback loops in “predictive policing”</a>, whereby more police are sent to neighborhoods with higher “reported &amp; predicted crime,” resulting in more police being sent there and more reports of crime and so on. Due to the information and power asymmetries at play here, along with how such feedback loops discriminate against specific socioeconomic classes, projects such as <a href="https://whitecollar.thenewinquiry.com/"><em>White Collar Crime Risk Zones</em></a>, which maps predictions of white collar crime, are important. <a href="https://www.theverge.com/2019/10/24/20929337/care-algorithm-study-race-bias-health">An application that hospitals use to screen for patients</a> with high-risk conditions that require special care wasn’t recommending that care for black patients as often; white patients spend more on health care, making their conditions appear to be more serious. While these applications look completely different, the feedback loop is the same. If you spend more, you get more care; if you police more, you make more arrests. And the cycle goes on. Note that in both cases, a major part of the problem was also the use of proxies for metrics: cost as a proxy for health, police reports a proxy for crime, not dissimilar to the use of Youtube view-time as a proxy for what a viewer <em>wants</em> to watch (for more on metrics and proxies, we <em>highly </em>recommend the post <a href="https://www.fast.ai/2019/09/24/metrics/">The problem with metrics is a big problem for AI</a> by Rachel Thomas, Director of the Center for Applied Data Ethics at USF). There are also interaction effects between many models deployed in society that mean they feedback into each other: those most likely to be treated unfairly by the healthcare algorithm are more likely to be discriminated against by models used in employment hiring flows and more likely to be targeted by predatory payday loan ads online, as detailed by Cathy O’Neil in <a href="https://weaponsofmathdestructionbook.com/">Weapons of Math Destruction</a>.</p>
#
#
#
# <p>Google search operates at another scale of networked feedback, that of <em>everybody</em>. When I search for “Artificial Intelligence,” the results aren’t only a function of what Google knows about me, but also of how successful each link has been for everybody that has seen it previously. Google Search also operates in a fundamentally different way to many modern recommendation systems: historically, it has optimized its results to get you off its platform, though recently <a href="https://qz.com/1540608/the-problem-with-silicon-valleys-obsession-with-blitzscaling-growth/">its emphasis has shifted</a>. Whereas so many tech companies optimize for engagement with their platforms, trying to keep you from going elsewhere, Google’s incentive with Search was to direct you to another site, most often for the purpose of discovering facts. Under this model, there is an argument that the incentives of Google, advertisers, and users were all aligned, at least when searching for basic facts: all three stakeholders <em>want </em>to get the right fact in front of the user, at least in theory. This is why Search weighs long clicks more heavily than short clicks (the longer the time before the user clicks back to Google, the better).&nbsp; Now that Google has <a href="https://www.oreilly.com/ideas/antitrust-regulators-are-using-the-wrong-tools-to-break-up-big-tech">shifted to providing answers to questions</a> rather than links to answers, they are valuing engagement with their platform over engagement with other advertisers; as an advertiser, you’re more likely to succeed if you advertise directly on Google’s result page. Even more recently, Google <a href="https://www.blog.google/products/search/search-language-understanding-bert/">announced</a> its incorporation of BERT (Bidirectional Encoder Representations from Transformers, a technology enabling “anyone to train their own state-of-the-art question answering system”) into Search, which will allow users to make more complex and conversational queries and will enable you to “search in a way that feels natural for you” (according to Google, this is “one of the biggest leaps forward in the history of Search”). Fundamental changes in Search to encourage more complex queries could result in a shift of incentives.&nbsp;<br></p>
#
#
#
# <p>Also, this theoretical alignment of incentives between Google, advertisers, and users is an idealization. In practice, Google search encodes all types of cultural and societal biases, such as racial discrimination, as investigated in Safiya Noble’s <a href="https://nyupress.org/9781479837243/algorithms-of-oppression/"><em>Algorithms of Oppression</em></a>. An example of this is that, for many years, when using Google image search with the keyword “beautiful,” the results would be dominated by photos of white women. In the words of <a href="https://www.ruhabenjamin.com/">Ruha Benjamin</a>, Associate Professor of African American Studies at Princeton University, “race and technology are co-produced.”&nbsp;&nbsp;<br></p>
#
#
#
# <p>A final word (for now) on developing healthy Google Search habits and practices: know that the SEO (Search Engine Optimization) industry is worth close to $80 billion and that the way you’re served results and the potential mis-alignment of incentives depends on whether your search is <em>informational </em>(searching for information, such as “Who was the 44th President of the United States?”), <em>navigational </em>(searching for a particular website, such as “Wikipedia”), or <em>transactional </em>(searching to buy something, such as “Buy Masterclass subscription”). Keep a skeptical mind about the results you’re served! Personalization of search results may be handy in the short-term.&nbsp; However, when making informational searches, you’re being served what you regularly assume is ground truth but is tailored to you, based on what Google already knows about your online and, increasingly, offline behavior. There is also an information asymmetry, in that you don’t know what Google knows about you, and how that information plays into the incentives of Google’s ad-based business model. For informational searches, this could be quite disturbing. As Jaron Lanier points out in <a href="http://www.jaronlanier.com/tenarguments.html"><em>Ten Arguments for Deleting Your Social Media Accounts Right Now</em></a>, how would you feel if Wikipedia showed you and I different histories, based on our respective browser activities? To take this a step further, what if Wikipedia tailored the “facts” served to us as a function of an ad-based business model?<br></p>
#
#
#
# <p>For advertisers, incentive systems are also strangely skewed. We recently searched for Stitch Fix, the online personal styling service. This is a basic navigational search and Google could easily have served us the Stitch Fix website and they did, but above it were two advertisements: the first one was for Stitch Fix and the second one was for Trunk Club, a Stitch Fix competitor. This means that Trunk Club is buying ads for the keywords of their competitor, a common practice, and Stitch Fix then had to engage in defensive advertising due to how much traffic Google Search has, even when the user is clearly looking for their product! As a result, the user sees only ads above the scroll (at least on a cell phone) and needs to scroll down to find the correct and obvious search result. There is an argument that, if a user is explicitly searching to buy a product, it should be illegal for Google to force the product in question into defensive advertising.</p>
#
#
#
# <p><strong>TOWARDS A TYPOLOGY OF MODEL IMPACT AND EFFECTS</strong><br></p>
#
#
#
# <p>YouTube, the Facebook feed, Google Search, and Twitter are examples of modern algorithms and models that alter our perceptions of reality; applications like predictive policing reflect biased perceptions of reality that may have little to do with actual reality–indeed, these models create their own realities, becoming self-fulfilling prophecies. They all operate in different ways and on different principles. The nature of the feedback loops, the resulting phenomena, and the alignment of incentives between user, platform, content providers and advertisers are all different. In a world that’s increasingly filled with models, we need to assess their impact, identify challenges and concerns, and discuss and implement paths in the solution space.</p>
#
#
#
# <p>This first attempt at a model impact and effect classification probed several models that are part of our daily lives by looking at the nature of their feedback loops and the alignment of incentives between stakeholders (model builders, users, and advertisers). Other key dimensions to explore include “creep” factor, “hackability” factor, and how networked the model itself is (is it constantly online and re-trained?). Such a classification will allow us to assess the potential impact of classes of models, consider how we wish to interact with them, and to propose paths forward. This work is part of a broader movement of users, researchers, and builders who are actively engaged in discovering and documenting how these models work, are deployed, and what their impacts are. If you are interested in exploring this space, we encourage you to check out the non-exhaustive reading list below.<br></p>
#
#
#
# <p>***<br></p>
#
#
#
# <p>The authors would like to thank <a href="https://twitter.com/shiraamitchell">Shira Mitchell</a> for valuable feedback on an early draft of this essay and <a href="https://datasociety.net/people/moss-emanuel/">Manny Moss</a> for valuable feedback on a late draft.<br></p>
#
#
#
# <p><strong>READING LIST</strong><br></p>
#
#
#
# <ul><li><a href="https://arxiv.org/abs/1810.03993">Model Cards for Model Reporting</a> by Mitchell et al.</li><li><a href="https://arxiv.org/abs/1803.09010">Datasheets for Datasets</a> by Gerbu et al.</li><li><a href="https://www.aclweb.org/anthology/Q18-1041/">Data Statements for Natural Language Processing: Toward Mitigating System Bias and Enabling Better Science</a> by Bender &amp; Friedman</li><li><a href="https://anatomyof.ai/">Anatomy of an AI System</a> by Crawford and Joler</li><li><a href="https://nyupress.org/9781479837243/algorithms-of-oppression/">Algorithms of Oppression</a> by Safiya Umoja Noble</li><li><a href="https://weaponsofmathdestructionbook.com/">Weapons of Math Destruction</a> by Cathy O’Neil</li><li><a href="https://www.ruhabenjamin.com/race-after-technology">Race after Technology</a> by Ruha Benjamin</li><li><a href="https://us.macmillan.com/books/9781250074317">Automating Inequality</a> by Virginia Eubanks</li><li><a href="https://www.twitterandteargas.org/">Twitter and Tear Gas</a> by Zeynep Tufekci</li><li><a href="https://yalebooks.yale.edu/book/9780300199000/its-complicated">It&#8217;s Complicated: The Social Lives of Networked Teens</a> by danah boyd</li><li><a href="http://www.jaronlanier.com/tenarguments.html">Ten Arguments for Deleting Your Social Media Accounts Right Now</a> by Jaron Lanier</li><li><a href="https://www.ruinedby.design/">Ruined by Design</a> by Mike Monteiro</li><li><a href="https://ainowinstitute.org/AI_Now_2018_Report.pdf">AI Now Report 2018</a> by Whittaker et al.</li><li><a href="https://datasociety.net/output/owning-ethics-corporate-logics-silicon-valley-and-the-institutionalization-of-ethics/">Owning Ethics: Corporate Logics, Silicon Valley, and the Institutionalization of Ethics</a> by Jacob Metcalf, Emanuel Moss, and danah boyd (Data &amp; Society)</li><li><a href="https://www.youtube.com/watch?v=jIXIuYdnyyk">21 Fairness Definitions and Their Politics</a>, a tutorial by Arvind Narayanan at <a href="https://fatconference.org/">FAT*</a> 2018</li><li><a href="https://arxiv.org/abs/1811.07867">Prediction-Based Decisions and Fairness: A Catalogue of Choices, Assumptions, and Definitions</a> by Mitchell et al.</li><li><a href="https://www.fast.ai/2019/09/24/metrics/">The problem with metrics is a big problem for AI</a> by Rachel Thomas</li><li><a href="https://datascience.columbia.edu/ethical-principles-okrs-and-kpis-what-youtube-and-facebook-could-learn-tukey">Ethical Principles, OKRs, and KPIs: what YouTube and Facebook could learn from Tukey</a> by Chris Wiggins</li><li><a href="https://datasociety.net/output/algorithmic-accountability-a-primer/">Algorithmic Accountability: A Primer</a> by Caplan et al. (Data &amp; Society)</li><li>The <a href="https://www.odbproject.org/wp-content/uploads/2019/03/ODB_DDP_HighRes_Single.pdf">Digital Defense Playbook</a> by <a href="https://www.odbproject.org/">Our Data Bodies</a></li><li>The <a href="https://www.ajlunited.org/">Algorithmic Justice League</a></li></ul>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/sGh3eBhuYOo" height="1" width="1" alt=""/>
# Four short links: 11 May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/qa0FsPUaJS0/
# <ol>
# <li><a href="https://github.com/oragono/oragono">Oragono</a> &#8212; <i>a modern IRC server written in Go</i>.</li>
# <li><a href="https://fifteen.ai/">DeepFake Cartoon Voices</a> &#8212; Fifteen.ai is <i>a text-to-speech tool that you can use to generate 44.1 kHz voices of various characters. The voices are generated in real time using multiple audio synthesis algorithms and customized deep neural networks trained on very little available data (between 55 seconds and 120 minutes of clean dialogue for each character). This project demonstrates a significant reduction in the amount of audio required to realistically clone voices while retaining their affective prosodies.</i></li>
# <li><a href="https://github.com/angrave/SystemProgramming/wiki">System Programming Book</a> &#8212; CS241 &#8220;Intro to Systems Programming&#8221; textbook that was created in a wiki by University of Illinois students over 5 years.</li>
# <li><a href="https://www.microsoft.com/en-us/research/wp-content/uploads/2009/10/Realizing-Quality-Improvement-Through-Test-Driven-Development-Results-and-Experiences-of-Four-Industrial-Teams-nagappan_tdd.pdf">Realizing Quality Improvement Through Test Driven Development: Results and Experiences of Four Industrial Teams</a> &#8212; <i>The results of the case studies indicate that the pre-release defect density of the four products decreased between 40% and 90% relative to similar projects that did not use the TDD practice. Subjectively, the teams experienced a 15–35% increase in initial development time after adopting TDD.</i></li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/qa0FsPUaJS0" height="1" width="1" alt=""/>
# Four short links: 8 May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/fFqKH7WawVM/
# <ol>
# <li><a href="https://mml-book.github.io/">Mathematics for Machine Learning</a> &#8212; <i>We wrote a book on Mathematics for Machine Learning that motivates people to learn mathematical concepts. The book is not intended to cover advanced machine learning techniques because there are already plenty of books doing this. Instead, we aim to provide the necessary mathematical skills to read those other books.</i></li>
# <li><a href="https://github.com/cardsagainstcontainers/deck">Cards Against Containers</a> &#8212; nerd cards a-la Cards Against Humanity. (But without the swears.)</li>
# <li><a href="https://opensafely.org/">OpenSAFELY</a> &#8212; <i>a new secure analytics platform for electronic health records in the NHS, created to deliver urgent results during the global COVID-19 emergency. It is now successfully delivering analyses across more than 24 million patients’ full pseudonymised primary care NHS records, with more to follow shortly. All our analytic software is open for security review, scientific review, and re-use</i>. An amazing collaborative piece of work that you can read about in <a href="https://twitter.com/bengoldacre/status/1258431405450833921">Ben Goldacre&#8217;s thread</a>.</li>
# <li><a href="https://www.oreilly.com/radar/radar-trends-to-watch-may-2020/">Radar Trends to Watch in May 2020</a> &#8212; Mike Loukides&#8217;s roundup of weak signs of the future.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/fFqKH7WawVM" height="1" width="1" alt=""/>
# Radar trends to watch: May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/a7i2dB4x85I/
# <p>After last month’s “all coronavirus, all the time” report, I was concerned that this month would be more of the same.&nbsp; And there is, indeed, a lot of coronavirus. But there are many other trends and interesting items to look at–possibly a sign that people are working effectively from home.</p>
#
#
#
# <h3>Coronavirus</h3>
#
#
#
# <ul><li>Coronavirus prompts serious discussion of changes to the financial system. There’s no doubt that money’s dirty; and it isn’t terribly useful in the context of “social distancing.” Rethinking our financial system might lead to a <a href="https://www.technologyreview.com/2020/04/17/1000110/coronavirus-public-venmo-new-york/">public venmo, or even further to a digital dolla</a>r.&nbsp; (China is the leader here–by a large margin.)<br></li></ul>
#
#
#
# <ul><li>Coronavirus and <a href="https://www.technologyreview.com/2020/04/16/999944/coronavirus-animal-crossing-video-games-social-media/">game play</a>: Not surprisingly, COVID-19 has led to a big surge in <a href="https://techxplore.com/news/2020-04-digital-video-game-high-virus.html">game play and virtual reality</a>. Might surviving isolation during a pandemic be the killer app for VR?&nbsp; (This trend arrived too late to help the VR startup Magic Leap, which appears to be <a href="https://techcrunch.com/2020/04/27/daily-crunch-what-went-wrong-at-magic-leap/">failing</a>.) Fred Wilson <a href="https://avc.com/2020/04/in-real-life/">says</a>, wisely I think, that social isolation will teach how much we crave being in “real life.”<br></li></ul>
#
#
#
# <ul><li>It’s hardly news that <a href="https://techxplore.com/news/2020-04-coronavirus-misinformation-social-media-users.html">misinformation</a> about Coronavirus is proliferating. The big question is whether automated attempts to stop that proliferation will succeed. <a href="https://www.engadget.com/2020-04-05-youtube-to-remove-5g-coronavirus-videos.html">YouTube</a>, Twitter, and Facebook (including <a href="https://www.cnn.com/2020/04/07/tech/whatsapp-misinformation-forward-limit/index.html">WhatsApp</a>) are cracking down. Facebook is referring people who see misinformation to “authoritative resources.”<br></li></ul>
#
#
#
# <ul><li>I haven’t heard as much about Citizen Science in the past few years, but it’s making a reappearance. <a href="https://fold.it/portal/blog">Coronavirus binder designs</a> (proteins that bind to Coronavirus) modeled by citizen scientists, are in the pipeline for testing. Fold-it is a game where you design proteins (protein folding) to achieve some goal–in this case, binding to Coronavirus.<br></li></ul>
#
#
#
# <ul><li>Citizens are also playing a role on the front lines, with community-run <a href="https://caterina.net/2020/04/20/community-run-testing-for-covid-19/">COVID-19 testing</a>.  (I’ve also seen pleas for citizens willing to help with contact tracing.)<br></li></ul>
#
#
#
# <ul><li>Apple and Google are <a href="https://www.apple.com/newsroom/2020/04/apple-and-google-partner-on-covid-19-contact-tracing-technology/">collaborating</a> on OS-level tools for privacy-protecting contact tracing that will interoperate between Android and iOS. (Apps will be implemented by third parties, presumably healthcare organizations.) Germany was working on its own framework for contact tracing using cell phone apps, but it is now <a href="https://www.reuters.com/article/us-health-coronavirus-europe-tech/germany-flips-to-apple-google-approach-on-smartphone-contact-tracing-idUSKCN22807J">backing the Apple-Google collaboration</a>.&nbsp;<br></li></ul>
#
#
#
# <ul><li>Will we see “<a href="https://techxplore.com/news/2020-04-virus-upends-outsourcing-firms-reshore.html">re-shoring</a>” of jobs because of coronavirus? Outsourcing isn’t as attractive when lockdowns limit the supply of offshore labor, and it’s impossible to visit overseas contractors.&nbsp; Another consequence will be the increased use of AI, particularly in customer service.</li></ul>
#
#
#
# <h3>Robotics</h3>
#
#
#
# <ul><li><a href="https://www.mic.com/p/scientists-have-created-a-new-type-of-robot-that-is-literally-alive-22758584">Xenobots</a> are living (literally) programmable robots, assembled from cultured frog skin cells.&nbsp;<br></li></ul>
#
#
#
# <ul><li>Farming is very high tech. A European project called ROMI is developing robots for <a href="https://cordis.europa.eu/project/id/773875">weeding</a> crops on small (micro) farms; should cost <a href="https://techxplore.com/news/2020-04-robots-weeding-farms-patrolling-greenhouse.html">under $5000</a>. Uses AI and computer vision to identify weeds and crop diseases.</li></ul>
#
#
#
# <h3>Artificial Intelligence and Machine Learning</h3>
#
#
#
# <ul><li>Good thinking about <a href="https://stratechery.com/2020/how-tech-can-build/">how tech can build</a>: infusing manufacturing with software and intelligence (IoT); enabling remote work; getting beyond the unicorn mindset.<br></li></ul>
#
#
#
# <ul><li>Microsoft uses <a href="https://www.microsoft.com/security/blog/2020/04/16/secure-software-development-lifecycle-machine-learning/">machine learning</a> to inspect source code for security vulnerabilities. They claim they can identify high priority security bugs in new code 97% of the time.<br></li></ul>
#
#
#
# <ul><li>Facebook uses <a href="https://www.technologyreview.com/2020/04/15/999871/facebook-ai-bot-simulation/">AI bots</a> to simulate users for testing new social applications. They start up thousands of bots at a time to experiment with group dynamics, vulnerabilities, and privacy settings.<br></li></ul>
#
#
#
# <ul><li>Google Duo now uses AI to&nbsp; <a href="https://ai.googleblog.com/2020/04/improving-audio-quality-in-duo-with.html">synthesize missing speech segments</a> arising from lost packets in calls.</li></ul>
#
#
#
# <h3>The new workplace</h3>
#
#
#
# <ul><li>Splunk announced Remote Work Insights, a <a href="https://www.splunk.com/en_us/blog/leadership/introducing-splunk-remote-work-insights-our-solution-for-the-new-work-from-home-reality.html">network monitoring</a> product for work-at-home companies. It has been criticized as employee surveillance; Splunk has <a href="https://www.splunk.com/en_us/blog/leadership/introducing-splunk-remote-work-insights-our-solution-for-the-new-work-from-home-reality.html">responded</a> that their intent is to monitor connectedness, not activity.&nbsp;&nbsp;<br></li></ul>
#
#
#
# <ul><li><a href="https://www.forbes.com/sites/columbiabusinessschool/2020/04/28/low-code-automation-and-the-future-of-work/">Low-code automation</a> is another aspect of the democratization of technology. The idea is to build tools that can be used by people without requiring a lot of programming experience. The target audiences are all over the place: from unskilled workers to managers, and even to programmers, where these tools will simplify product development.&nbsp;</li></ul>
#
#
#
# <h3>Programming</h3>
#
#
#
# <ul><li>Microsoft announced IPE, a project that will <a href="https://www.zdnet.com/article/microsoft-announces-ipe-a-new-code-integrity-feature-for-linux/">contribute</a> to the Linux kernel. IPE is for listing allowed binaries, and automatically checking signatures; it is intended for high security versions of Linux. But what’s more important is that this is another sign that Microsoft has changed very deeply.&nbsp;<br></li></ul>
#
#
#
# <ul><li>IBM is offering free <a href="https://www.inputmag.com/tech/ibm-will-offer-free-cobol-training-to-address-overloaded-unemployment-systems">COBOL training</a>, in response to state governments’ needs for more programmers to update unemployment systems.<br></li></ul>
#
#
#
# <ul><li><a href="https://jupyterlab.readthedocs.io/en/latest/">JupyterLab</a> is now a full-fledged, web-based, multi-language IDE for data.<br></li><li>Google is <a href="https://tryolabs.com/blog/2020/04/02/swift-googles-bet-on-differentiable-programming/">adding differentiable programming</a> to the Swift programming language to simplify development of ML models. This means that their enhanced Swift language has primitives for computing the derivative/gradient of a function; in turn, this greatly simplifies key AI algorithms that involve gradient descent.</li></ul>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/a7i2dB4x85I" height="1" width="1" alt=""/>
# Four short links: 7 May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/02gVn4fsoAs/
# <ol>
# <li><a href="https://christine.website/blog/super-bootable-64-2020-05-06">Super Bootable 64</a> &#8212; Super Mario 64 shipped before the SDK was finalised, and it had to be compiled with optimisations turned off. This meant the binary was easily reversed to source code, and now the unportable has been ported. This site probably won&#8217;t last long, because DMCA, but it&#8217;s technically a sweet feat. (via <a href="https://lobste.rs/s/lmhaaa/super_bootable_64">lobsters</a>)</li>
# <li><a href="https://mobile.twitter.com/BrianRoemmele/status/1257832168455208963">IBM System/370 on a Raspberry Pi</a> &#8212; <i>I have been running a full IBM System/370 Mainframe on a $5 Raspberry Pi Zero for ~5 years. About 7 times faster System/370. Millions of lines of COBOL JCLs running flawless on a battery. Tested an entire bank’s mainframe COBOL on it.</i></li>
# <li><a href="https://github.com/aftertheflood/sparks">sparks</a> &#8212; <i>A typeface for creating sparklines in text without code.</i></li>
# <li><a href="https://www.oversightboard.com/news/announcing-the-first-members-of-the-oversight-board/">Announcing the First Members of the Oversight Board</a> &#8212; <i>The Board will review whether content is consistent with Facebook and Instagram’s policies and values, as well as a commitment to upholding freedom of expression within the framework of international norms of human rights. We will make decisions based on these principles, and the impact on users and society, without regard to Facebook’s economic, political or reputational interests. Facebook must implement our decisions, unless implementation could violate the law.</i> Impressive credentials. I&#8217;d love to be a fly on the wall for their conversations, because this problem is Hard.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/02gVn4fsoAs" height="1" width="1" alt=""/>
# Four short links: 6 May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/JzKmpMWaB6M/
# <ol>
# <li><a href="http://www.open-raman.org/">Raman Spectroscopy</a> &#8212; <i>Low Cost, High Performances, 100% Open Source Raman Spectrometer. [&#8230;] We currently offer the spectrometer in a Starter Edition version designed for teaching Raman spectroscopy and we will soon release a Performance Edition version which achieves a tested 12 cm-1 resolution at low costs.</i> Great to see this getting into the hands of hackers.</li>
# <li><a href="https://www.svese.de/impact-vs-backlog-frame-in-software-development">Frames in Software Development</a> &#8212; not the Lisp AI frames, but the semantic frames. <i> I always wondered why it isn’t called “product debt” because product took the credit to get a feature faster and must pay back by investing the time to clean up. Technology is the bank that gave credit.</i></li>
# <li><a href="https://www.phoenixframework.org/">Phoenix Framework</a> &#8212; <i>a web development framework written in Elixir which implements the server-side Model View Controller (MVC) pattern.</i> I&#8217;m reminded of <a href="https://twitter.com/ceejbot/status/1257390683930976262">ceej&#8217;s</a> &#8220;Write your own frameworks. You learn a lot. Your framework might solve a problem your ecosystem needs to have solved. By your tenth one, you know enough to write one worth wide adoption. Progress in our industry depends on all of us pushing it forward.&#8221;</li>
# <li><a href="https://blog.twitter.com/engineering/en_us/topics/infrastructure/2020/deleting-data-distributed-throughout-your-microservices-architecture.html">Deleting Data Distributed Throughout Your Microservices Architecture</a> &#8212; <i>One solution is to think of data deletion not as an event, but as a process. At Twitter, we call this process “erasure” and coordinate data deletion between systems using an erasure pipeline. In this post, we’ll discuss how to set up an erasure pipeline, including data discoverability, access, and processing. We’ll also touch on common problems and how to ensure ongoing maintenance of an erasure pipeline.</i></li>
# <li><a href="https://arxiv.org/abs/2003.11755">A Survey of Deep Learning for Scientific Discovery</a> &#8212; <i>The sheer breadth and diversity of different deep learning techniques makes it difficult to determine what scientific problems might be most amenable to these methods, or which specific combination of methods might offer the most promising first approach. In this survey, we focus on addressing this central issue, providing an overview of many widely used deep learning models, spanning visual, sequential and graph structured data, associated tasks and different training methods, along with techniques to use deep learning with less data and better interpret these complex models &#8212; two central considerations for many scientific use cases. We also include overviews of the full design process, implementation tips, and links to a plethora of tutorials, research summaries and open-sourced deep learning pipelines and pretrained models, developed by the community.</i></li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/JzKmpMWaB6M" height="1" width="1" alt=""/>
# Four short links: 5 May 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XxiXn3lntjQ/
# <ol>
# <li><a href="https://www.tbray.org/ongoing/When/202x/2020/04/29/Leaving-Amazon">Leaving Amazon</a> (Tim Bray) &#8212; <i>May 1st was my last day as a VP and Distinguished Engineer at Amazon Web Services, after five years and five months of rewarding fun. I quit in dismay at Amazon firing whistleblowers who were making noise about warehouse employees frightened of Covid-19.</i></li>
# <li><a href="https://charity.wtf/2020/03/03/observability-is-a-many-splendored-thing/">Observability is a Many-Splendoured Thing</a> (Charity Majors) &#8212; <i>if you <b>can’t</b> predict all the questions you’ll need to ask in advance, or if you <b>don’t</b> know what you’re looking for, then you’re in o11y territory.</i></li>
# <li><a href="https://ai.googleblog.com/2020/04/using-neural-networks-to-find-answers.html">Using Neural Networks to Find Answers</a> (Google) &#8212; deep learning to figure out how to turn natural language questions into queries over tables of data.</li>
# <li><a href="https://widgets.weforum.org/blockchain-toolkit/">Redesigning Trust: Blockchain Deployment Toolkit</a> &#8212; World Economic Forum report on distributed ledger deployments, with advice. <i>This toolkit provides tools, resources, and know-how to organizations undertaking blockchain projects. It was developed through lessons from and analysis of real projects, to help organizations embed best practices and avoid possible obstacles in deployment of distributed ledger technology</i></li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/XxiXn3lntjQ" height="1" width="1" alt=""/>
# On COBOL
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/qjjGs15OegQ/
# <div class="wp-block-group"><div class="wp-block-group__inner-container">
# <div class="wp-block-group"><div class="wp-block-group__inner-container">
# <p class="has-background has-text-align-left has-very-light-gray-background-color"><strong>Helping government through this crisis.&nbsp;</strong><br>We’re offering free access to O’Reilly online learning to any individual who works for a US government agency to get the learning you need as your agency responds to unprecedented demand.</p>
#
#
#
# <div class="wp-block-button"><a class="wp-block-button__link has-text-color has-vivid-red-color has-background has-very-light-gray-background-color" href="https://www.oreilly.com/online-learning/government-free-access.html">Free .gov access &gt;</a></div>
# </div></div>
# </div></div>
#
#
#
# <p><br><br>We’ve all seen that the world (well, governments, specifically <a href="https://qz.com/1832988/covid-19-results-in-new-jersey-desperately-needing-cobol-coders/">state</a> <a href="https://onezero.medium.com/our-government-runs-on-a-60-year-old-coding-language-and-now-its-falling-apart-61ec0bc8e121">governments</a>, to say nothing of the banks) is screaming for COBOL programmers—a cry that goes up roughly every five years. We somehow muddle through the crisis at hand, then people forget that it was ever a problem. It&#8217;s time we asked what the crisis really is, and why it keeps returning.<br></p>
#
#
# <p></p>
#
#
# ...
# <li><strong>Let go of perfection</strong>. It’s better to send out a revised set of rules everyday rather than being silent for days while executives try to land on the perfect policy and ideal language. Modify standard policies and make exceptions to long-held rules. Be transparent—it’s OK not to have all the answers because there are few definitive answers. Be transparent and say what you know and admit what you don’t know.</li>
# <li><strong>Monitor the CDC and your state health authorities</strong>. There will be rumors, fake news, and speculation. The only thing we know is that we have never been through this before. In 1918 during the Spanish Flu, it took days to cross the Atlantic and antibiotics hadn’t been invented. Because this is unprecedented in our modern world, the CDC and your state health authorities are doing admirable work providing the most reliable and trustworthy information.</li>
# <li><strong>People will respond very differently—prepare for that to cause problems</strong>. Some people may begin refusing to come to work—others might seem cavalier about COVID19. That divide may create serious friction in your organization. People who come to work begin to resent those who don’t. Those who stay home begin to believe that some of their co-workers don’t care about the health of families. After SARS, it took a long time to heal this split in the office. Acknowledge the split and that both points of view are valid.</li>
# <li><strong>Create new remote work guidelines—today</strong>. It doesn’t matter if you change these guidelines (see #3), just put out some basics. Is there a daily meeting? Will teams need to check in every day? What tools should they use? Should all meeting participants turn on their video? Whatever you decide—put out some guidelines so people have a place to start. You can modify these tomorrow and completely rewrite them when the crisis passes.</li>
# <li><strong>We may not return to “business as usual.”</strong> You are going to want to reassure people, and that may be an important part of your job. Tell people it will be OK—because it will. But be careful: don’t make any promises, because “OK” may not mean what it used to mean. Companies will likely make changes during the crisis or as things begin to recover. And, this may be an opportunity to change how your organization works. You are going to learn things about how your people learn, adapt, and improvise that will inform the new future.</li>
# <li><strong>Take care of yourself</strong>. This is a marathon not a sprint. And, to carry that metaphor forward, we don’t know the course of the marathon. We know some of you have been working around the clock—that’s not going to end tomorrow. If you aren’t healthy and grounded, you can’t see your team through this. Ground yourself; whatever gives you peace and contentment—you need that now, for you, for your family, and for the demands of your work.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/zsrywhHLzI8" height="1" width="1" alt=""/>
# Four short links: 18 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/FQ2S_dHbHTs/
# <ol>
# <li><a href="https://www.inklestudios.com/">Inklewriter</a> &#8212; open source interactive text adventure game creator. (Fun for adults, but also great to give to kids who love to read) (via <a href="http://waxy.org/links">Andy Baio</a>)</li>
# <li><a href="https://steveblank.com/2020/03/17/the-virus-survival-strategy-for-your-startup/">The Virus Survival Strategy Guide for Your Startup</a> (Steve Blank) &#8212; <i>Unfortunately, it’s no longer a normal market. All your assumptions about customers; sales cycle; and, most importantly, revenue, burn rate, and runway are no longer true. If you’re a startup, you’ve likely calculated your runway to last until you raise your next round of funding. Assuming there was going to be a next round. That may be no longer true.</i></li>
# <li><a href="https://www.cambridge.org/core/what-we-publish/textbooks">Free Cambridge University Textbooks</a> &#8212; all available in HTML for free (gratis) until the end of May.</li>
# <li><a href="http://shop.oreilly.com/product/0636920296423.do">Software Engineering at Google</a> &#8212; a new O&#8217;Reilly book. <i>Covers Google’s unique engineering culture, processes, and tools, and how these aspects contribute to the effectiveness of an engineering organization.</i></li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/FQ2S_dHbHTs" height="1" width="1" alt=""/>
# Four short links: 17 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/3XhdFqZsNS8/
# <ol>
# <li><a href="https://media.ccc.de/v/32c3-7196-how_the_great_firewall_discovers_hidden_circumvention_servers#video">How the Great Firewall Discovers Hidden Circumvention Servers</a> &#8212; really interesting CCC talk from a few years ago.</li>
# <li><a href="https://www.lawfareblog.com/challenge-software-liability">The Challenge of Software Liability</a> &#8212; <i>Liability for insecure software is already a reality. The question is whether Congress will step in to give it shape and a coherent legal structure.</i></li>
# <li><a href="https://xoxofest.com/videos/">XOXO Talks</a> &#8212; video archive of past talks. Suitable for the long nights of social isolation.</li>
# <li><a href="https://censorbib.nymity.ch/">Selected Research Papers on Internet Censorship</a> &#8212; <i>Most papers on CensorBib approach the topic from a technical angle, by proposing designs that circumvent censorship systems, or by measuring how censorship works.</i></li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/3XhdFqZsNS8" height="1" width="1" alt=""/>
# Four short links: 16 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/3tj3NiTXThA/
# <ol>
# <li><a href="https://uncensoredlibrary.com/en">The Uncensored Library</a> &#8212; Reporters Without Borders built a library in Minecraft, in which you can read banned books. (via <a href="https://www.gizmodo.com.au/2020/03/this-minecraft-library-provides-a-platform-for-censored-journalists/">Gizmodo</a>)</li>
# <li><a href="https://www.youtube.com/playlist?list=PL7-g2-mnZwSFX0qd41qOYHO28tmisjwCJ">Shmoocon 2020 Talk Recordings</a> &#8212; everything from email addresses to Verilog by way of Zero Trust, social media, and choose-your-own-adventure ransomware.</li>
# <li><a href="https://research.kudelskisecurity.com/2020/03/11/differential-privacy-a-comparison-of-libraries/">Differential Privacy: A Comparison of Libraries</a> &#8212; <i>We will have a look at how the dataset size affects accuracy and how the desired privacy level (epsilon) affects data accuracy. For each case, we will compare the results obtained using the various differential privacy libraries.</i></li>
# <li><a href="https://jacobian.org/2020/mar/13/layoffs-are-coming/">Layoffs are Coming</a> (Jacob Kaplan-Moss) &#8212; who is likely to get laid off and how to prepare, from a web elder who has lived through two recessions.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/3tj3NiTXThA" height="1" width="1" alt=""/>
# Four short links: 13 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/qlfo450nz88/
# <ol>
# <li><a href="https://github.com/OpenIdentityPlatform/OpenAM/">OpenAM</a> &#8212; <i>an open-access management solution that includes authentication, SSO, authorization, federation, entitlements and web services security.</i></li>
# <li><a href="https://bartekci.substack.com/p/building-relationships-as-a-remote">Building Relationships as a Remote Engineering Manager</a> &#8212; <i>And if you haven’t realized it yet, get used to this—you’re going to spend a lot of time writing.</i></li>
# <li><a href="https://nordicapis.com/introducing-the-api-security-maturity-model/">API Security Maturity Model</a> &#8212; I&#8217;m not sure if I agree with this specific framework, but I like the idea of a maturity model for APIs in general and security in particular. <i>Level 0 – API Keys and Basic Authentication; Level 1 – Token-Based Authentication; Level 2 – Token-Based Authorization; Level 3 – Centralized Trust Using Claims.</i></li>
# <li><a href="https://netflixtechblog.com/ready-for-changes-with-hexagonal-architecture-b315ec967749">Hexagonal Architecture</a> (Netflix) &#8212; <i>The idea of Hexagonal Architecture is to put inputs and outputs at the edges of our design. Business logic should not depend on whether we expose a REST or a GraphQL API, and it should not depend on where we get data from—a database, a microservice API exposed via gRPC or REST, or just a simple CSV file.</i> How Netflix used this architectural concept in practice.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/qlfo450nz88" height="1" width="1" alt=""/>
# Four short links: 12 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/wpmmdqTildY/
# <ol>
# <li><a href="https://www.lastweekinaws.com/blog/an-aws-bill-analysis-changelogs-md/">AWS Bill Analysis</a> &#8212; always interesting to see how to approach lowering your costs. In this case, the project owner works for Amazon on AWS, but still there were savings to be had.</li>
# <li><a href="https://hasura.io/blog/design-guide-to-offline-first-apps/">A Design Guide to Writing Offline-first Apps</a> &#8212; <i>In this article, we will be diving into some of the engineering challenges that make designing robust offline-first applications with good user experience hard, and explore some architectures.</i></li>
# <li><a href="https://stratechery.com/2020/zero-trust-information/">Zero Trust Information</a> &#8212; <i>To that end, instead of trying to fight the internet—to try to build a castle and moat around information, with all of the impossible tradeoffs that result—how much more value might there be in embracing the deluge?</i> The either-or is a false frame: you can fight the worst without giving up the best. (I think Ben and I would agree that limiting access to encryption is a bad idea.)</li>
# <li><a href="https://danluu.com/corp-eng-blogs/">How Some Good Corporate Engineering Blogs Are Written</a> (Dan Luu) &#8212; <i>In order to have a boring blog, the corporation has to actively stop engineers from putting interesting content out there. Unfortunately, it appears that the natural state of large corporations tends toward risk aversion and blocking people from writing, just in case it causes a legal or PR or other problem.</i> Presents the process at a couple of different companies with interesting blogs, and some with boring blogs.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/wpmmdqTildY" height="1" width="1" alt=""/>
# Four short links: 11 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/zPAuddHbgXk/
# <ol>
# <li><a href="https://pluralistic.net/">Pluralistic</a> &#8212; Cory Doctorow&#8217;s news site and newsletter, where you can learn about <a href="https://pluralistic.net/2020/03/05/warner-chappell-copyfraud/#gbwhatsapp">African WhatsApp modders</a> among other things.</li>
# <li><a href="https://mapnik.org/">Mapnik</a> &#8212; LGPLed software that <i>combines pixel-perfect image output with lightning-fast cartographic algorithms, and exposes interfaces in C++, Python, and Node.</i></li>
# <li><a href="https://p-node.org/">pi node</a> &#8212; <i>A π-box is a modular system of radio/streaming broadcast, composed of multiples inputs and outputs. The π-box aims to provide a multi-functional and easy-to-use micro-FM and streaming micro radio station. It is based on the mini-FM approach developed in the 80&#8217;s by the Japanese artist and researcher Tetsuo Kogawa, which promotes radio transmissions of FM waves upon a tiny perimeter, such as a house, a block, or a small zone. The π-box combines this ultra local transmission with internet possibilities (through ethernet, Wi-Fi or 3G/4G) to leverage all the possibilities of hybrid transmissions. The system is open source and based on open source software / open hardware.</i></li>
# <li><a href="https://arxiv.org/abs/2003.03384">AutoML-Zero</a> &#8212; evolutionary search by modifying basic math operations with minimal human direction: <i>evolutionary search shows promising results by discovering linear regression with gradient descent, 2-layer neural networks with backpropagation, and even algorithms that surpass hand-designed baselines of comparable complexity</i>. <a href="https://github.com/google-research/google-research/tree/master/automl_zero">Code available</a>.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/zPAuddHbgXk" height="1" width="1" alt=""/>
# Four short links: 10 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/RXf9JHAKX3s/
# <ol>
# <li><a href="https://mlflow.org/">MLflow</a> &#8212; <i>an open source platform to manage the ML lifecycle, including experimentation, reproducibility, and deployment. It currently offers three components: tracking, projects, and models.</i></li>
# <li><a href="https://www.tbray.org/ongoing/When/202x/2020/03/07/Eventing-Facets">Eventing Facets</a> (Tim Bray) &#8212; the word &#8220;eventing&#8221; makes my skin crawl, but this series of posts has A+ info in it.</li>
# <li><a href="https://developers.google.com/web/tools/workbox">Workbox</a> &#8212; <i>JavaScript Libraries for adding offline support to web apps</i>, from Google.</li>
# <li><a href="https://www.tensorflow.org/quantum">TensorFlow Quantum</a> &#8212; <i>a library for hybrid quantum-classical machine learning</i>. See also <a href="https://arxiv.org/abs/2003.02989">arXiv paper</a>, <a href="https://ai.googleblog.com/2020/03/announcing-tensorflow-quantum-open.html">Google AI Blog</a>, and <a href="https://github.com/tensorflow/quantum">source</a>.</li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/RXf9JHAKX3s" height="1" width="1" alt=""/>
# Four short links: 9 March 2020
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/ohtN5Y_peBg/
# <ol>
# <li><a href="https://sno.earth/">Sno</a> &#8212; <i>Distributed version control<br />
# for geospatial and tabular data</i>. Finally, git for (geo)data done right. Open source.</li>
# <li><a href="https://arxiv.org/pdf/1909.01326.pdf">The Woman Worked as a Babysitter: On Biases in Language Generation</a> &#8212; plugging prompts like &#8220;the woman worked as&#8221; and &#8220;the white person worked as&#8221; into text generation systems, and the horrors you get back. (via <a href="https://twitter.com/VioletNPeng/status/1191982282011230213">Violent Peng</a>)</li>
# <li><a href="https://docs.google.com/document/d/1EABkSzEdJk5cmMLETpSbXaeDXmFwcTz7SUXP_C3dN9k/edit?usp=sharing">How to Run a Free Online Academic Conference: A Workbook</a> &#8212; as f2f conferences are canceled left, right, and center, this might be of interest to folks. (via <a href="https://twitter.com/fdsayre/status/1236023757434580992">Franklin Sayre</a>)</li>
# <li><a href="https://docs.microsoft.com/en-us/archive/msdn-magazine/2008/october/concurrency-hazards-solving-problems-in-your-multithreaded-code">Solving 11 Likely Problems in Your Multithreaded Code</a> &#8212; <i>There really is a fundamental set of concepts that you need to learn and become comfortable with. It&#8217;s likely that certain languages and libraries can hide some concepts over time, but if you&#8217;re doing concurrency today, you won&#8217;t have that luxury. This article describes some of the more common challenges to be aware of and presents advice for coping with them in your software.</i></li>
# </ol>
# <img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/ohtN5Y_peBg" height="1" width="1" alt=""/>

# %% [markdown]
# ## Harvesting blog data by parsing feeds

# %%
import os
import sys
import json
import feedparser
from bs4 import BeautifulSoup
from nltk import clean_html

FEED_URL = 'http://feeds.feedburner.com/oreilly/radar/atom'

def cleanHtml(html):
    if html == "": return ""

    return BeautifulSoup(html, 'html5lib').get_text()

fp = feedparser.parse(FEED_URL)

print("Fetched {0} entries from '{1}'".format(len(fp.entries[0].title), fp.feed.title))

blog_posts = []
for e in fp.entries:
    blog_posts.append({'title': e.title, 'content'
                      : cleanHtml(e.content[0].value), 'link': e.links[0].href})

out_file = os.path.join('feed.json')
f = open(out_file, 'w+')
f.write(json.dumps(blog_posts, indent=1))
f.close()

print('Wrote output file to {0}'.format(f.name))
# Out:
# Fetched 29 entries from 'Radar'
# Wrote output file to feed.json

# %% [markdown]
# ## Starting to write a web crawler

# %%
#more about beautifulsoup
#https://www.crummy.com/software/BeautifulSoup/bs4/doc/
import httplib2
import re
from bs4 import BeautifulSoup

http = httplib2.Http()
status, response = http.request('http://www.nytimes.com')

soup = BeautifulSoup(response, 'html5lib')

links = []
#more about re.compile
#this is using regular expression
#https://docs.python.org/3.2/library/re.html

#more about regular expressions
#https://www.pythonsheets.com/notes/python-rexp.html#match-email

 
for link in soup.findAll('a', attrs={'href': re.compile("^http(s?)://")}):
    links.append(link.get('href'))

for link in links:
    print(link)
# Out:
# https://www.nytimes.com/es/
# https://cn.nytimes.com
# https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi
# https://www.nytimes.com/section/todayspaper
# https://www.nytimes.com/section/world
# https://www.nytimes.com/section/us
# https://www.nytimes.com/section/politics
# https://www.nytimes.com/section/nyregion
# https://www.nytimes.com/section/business
# https://www.nytimes.com/section/opinion
# https://www.nytimes.com/section/technology
# https://www.nytimes.com/section/science
# https://www.nytimes.com/section/health
# https://www.nytimes.com/section/sports
# https://www.nytimes.com/section/arts
# https://www.nytimes.com/section/books
# https://www.nytimes.com/section/style
# https://www.nytimes.com/section/food
# https://www.nytimes.com/section/travel
# https://www.nytimes.com/section/magazine
# https://www.nytimes.com/section/t-magazine
# https://www.nytimes.com/section/realestate
# https://www.nytimes.com/video
# https://www.nytimes.com/section/world
# https://www.nytimes.com/section/us
# https://www.nytimes.com/section/politics
# https://www.nytimes.com/section/nyregion
# https://www.nytimes.com/section/business
# https://www.nytimes.com/section/opinion
# https://www.nytimes.com/section/technology
# https://www.nytimes.com/section/science
# https://www.nytimes.com/section/health
# https://www.nytimes.com/section/sports
# https://www.nytimes.com/section/arts
# https://www.nytimes.com/section/books
# https://www.nytimes.com/section/style
# https://www.nytimes.com/section/food
# https://www.nytimes.com/section/travel
# https://www.nytimes.com/section/magazine
# https://www.nytimes.com/section/t-magazine
# https://www.nytimes.com/section/realestate
# https://www.nytimes.com/video
# https://www.nytimes.com/interactive/2020/world/coronavirus-maps.html
# https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html
# https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html
# https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html
# https://www.nytimes.com/interactive/2020/world/europe/united-kingdom-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/europe/united-kingdom-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/europe/united-kingdom-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/europe/italy-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/europe/italy-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/europe/italy-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/americas/brazil-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/americas/brazil-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/americas/brazil-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/asia/india-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/asia/india-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/asia/india-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/canada/canada-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/canada/canada-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/canada/canada-coronavirus-cases.html
# https://www.nytimes.com/interactive/2020/world/coronavirus-maps.html
# https://www.nytimes.com/2020/05/13/business/stock-market-live-coronavirus.html
# https://www.nytimes.com/interactive/2020/05/12/us/coronavirus-reopening-shutdown.html
#
# https://www.nytimes.com/interactive/2020/05/12/us/coronavirus-reopening-shutdown.html
#
# https://www.nytimes.com/2020/05/13/us/coronavirus-updates.html
# https://www.nytimes.com/2020/05/13/world/coronavirus-world-news-updates.html?type=styln-live-updates&label=global&index=0
# https://www.nytimes.com/2020/05/13/world/coronavirus-world-news-updates.html?type=styln-live-updates&label=global&index=0#link-e03247b
# https://www.nytimes.com/2020/05/13/world/coronavirus-world-news-updates.html?type=styln-live-updates&label=global&index=0#link-55a22180
# https://www.nytimes.com/2020/05/13/world/coronavirus-world-news-updates.html?type=styln-live-updates&label=global&index=0#link-5459755e
# https://www.nytimes.com/2020/05/13/business/stocks-today-coronavirus.html?type=styln-live-updates&label=the economy&index=1
# https://www.nytimes.com/2020/05/13/business/stocks-today-coronavirus.html?type=styln-live-updates&label=the economy&index=1#link-1f021516
# https://www.nytimes.com/2020/05/13/business/stocks-today-coronavirus.html?type=styln-live-updates&label=the economy&index=1#link-4b1159ef
# https://www.nytimes.com/2020/05/13/business/stocks-today-coronavirus.html?type=styln-live-updates&label=the economy&index=1#link-612fab12
# https://www.nytimes.com/2020/05/13/nyregion/coronavirus-new-york-update.html?type=styln-live-updates&label=new york&index=2
# https://www.nytimes.com/2020/05/13/nyregion/coronavirus-new-york-update.html?type=styln-live-updates&label=new york&index=2#link-7e5c9087
# https://www.nytimes.com/2020/05/13/nyregion/coronavirus-new-york-update.html?type=styln-live-updates&label=new york&index=2#link-292ae012
# https://www.nytimes.com/2020/05/13/nyregion/coronavirus-new-york-update.html?type=styln-live-updates&label=new york&index=2#link-13e34c72
# https://www.nytimes.com/news-event/coronavirus
# https://www.nytimes.com/2020/05/13/well/move/coronavirus-gym-safety.html
# https://www.nytimes.com/2020/05/12/business/employer-health-plans-coronavirus.html
# https://www.nytimes.com/2020/05/13/parenting/kids-death-coronavirus-grieving.html
# https://www.nytimes.com/section/opinion?pagetype=Homepage&action=click&module=Opinion
# http://nyt.qualtrics.com/jfe/form/SV_eFJmKj9v0krSE0l
# https://help.nytimes.com/hc/en-us/articles/115014792127-Copyright-notice
# https://www.nytco.com/
# https://help.nytimes.com/hc/en-us/articles/115015385887-Contact-Us
# https://www.nytco.com/careers/
# https://nytmediakit.com/
# http://www.tbrandstudio.com/
# https://help.nytimes.com/hc/en-us/articles/115014892108-Privacy-policy
# https://help.nytimes.com/hc/en-us/articles/115014892108-Privacy-policy
# https://help.nytimes.com/hc/en-us/articles/115014893428-Terms-of-service
# https://help.nytimes.com/hc/en-us/articles/115014893968-Terms-of-sale
# https://spiderbites.nytimes.com
# https://help.nytimes.com/hc/en-us
# https://www.nytimes.com/subscription?campaignId=37WXW

# %% [markdown]
# ```
# Create an empty graph
# Create an empty queue to keep track of nodes that need to be processed
#
# Add the starting point to the graph as the root node
# Add the root node to a queue for processing
#
# Repeat until some maximum depth is reached or the queue is empty:
#   Remove a node from the queue
#   For each of the node's neighbors:
#     If the neighbor hasn't already been processed:
#       Add it to the queue
#       Add it to the graph
#       Create an edge in the graph that connects the node and its neighbor
# ```

# %% [markdown]
# ## Using NLTK to parse web page data

# %% [markdown]
# **Naive sentence detection based on periods**

# %%
text = "Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow."
print(text.split("."))
# Out:
# ['Mr', ' Green killed Colonel Mustard in the study with the candlestick', ' Mr', ' Green is not a very nice fellow', '']

# %% [markdown]
# **More sophisticated sentence detection**

# %%
import nltk # Installation instructions: http://www.nltk.org/install.html

# Downloading nltk packages used in this example
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Sohair
# [nltk_data]     Zaki\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#import link for nltk 
#https://www.guru99.com/nltk-tutorial.html

sentences = nltk.tokenize.sent_tokenize(text)
print(sentences)
# Out:
# ['Mr. Green killed Colonel Mustard in the study with the candlestick.', 'Mr. Green is not a very nice fellow.']

# %%
harder_example = """My name is John Smith and my email address is j.smith@company.com.
Mostly people call Mr. Smith. But I actually have a Ph.D.!
Can you believe it? Neither can most people..."""

sentences = nltk.tokenize.sent_tokenize(harder_example)
print(sentences)
# Out:
# ['My name is John Smith and my email address is j.smith@company.com.', 'Mostly people call Mr. Smith.', 'But I actually have a Ph.D.!', 'Can you believe it?', 'Neither can most people...']

# %% [markdown]
# **Word tokenization**

# %%
text = "Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow."
sentences = nltk.tokenize.sent_tokenize(text)

tokens = [nltk.word_tokenize(s) for s in sentences]
print(tokens)
# Out:
# [['Mr.', 'Green', 'killed', 'Colonel', 'Mustard', 'in', 'the', 'study', 'with', 'the', 'candlestick', '.'], ['Mr.', 'Green', 'is', 'not', 'a', 'very', 'nice', 'fellow', '.']]

# %% [markdown]
# **Part of speech tagging for tokens**

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

# Downloading nltk packages used in this example
nltk.download('maxent_treebank_pos_tagger')

pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]
print(pos_tagged_tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Sohair Zaki\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     C:\Users\Sohair Zaki\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [[('Mr.', 'NNP'), ('Green', 'NNP'), ('killed', 'VBD'), ('Colonel', 'NNP'), ('Mustard', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('study', 'NN'), ('with', 'IN'), ('the', 'DT'), ('candlestick', 'NN'), ('.', '.')], [('Mr.', 'NNP'), ('Green', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('very', 'RB'), ('nice', 'JJ'), ('fellow', 'NN'), ('.', '.')]]

# %% [markdown]
# **Alphabetical list of part-of-speech tags used in the Penn Treebank Project**
#
# See: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
#
# | # | POS Tag | Meaning |
# |:-:|:-------:|:--------|
# | 1	| CC | Coordinating conjunction|
# |2|	CD	|Cardinal number|
# |3|	DT	|Determiner|
# |4|	EX	|Existential there|
# |5|	FW	|Foreign word|
# |6|	IN	|Preposition or subordinating conjunction|
# |7|	JJ	|Adjective|
# |8|	JJR	|Adjective, comparative|
# |9|	JJS	|Adjective, superlative|
# |10|	LS	|List item marker|
# |11|	MD	|Modal|
# |12|	NN	|Noun, singular or mass|
# |13|	NNS	|Noun, plural|
# |14|	NNP	|Proper noun, singular|
# |15|	NNPS	|Proper noun, plural|
# |16|	PDT	|Predeterminer|
# |17|	POS	|Possessive ending|
# |18|	PRP	|Personal pronoun|
# |19|	PRP\$	|Possessive pronoun|
# |20|	RB	|Adverb|
# |21|	RBR	|Adverb, comparative|
# |22|	RBS	|Adverb, superlative|
# |23|	RP	|Particle|
# |24|	SYM	|Symbol|
# |25|	TO	|to|
# |26|	UH	|Interjection|
# |27|	VB	|Verb, base form|
# |28|	VBD	|Verb, past tense|
# |29|	VBG	|Verb, gerund or present participle|
# |30|	VBN	|Verb, past participle|
# |31|	VBP	|Verb, non-3rd person singular present|
# |32|	VBZ	|Verb, 3rd person singular present|
# |33|	WDT	|Wh-determiner|
# |34|	WP	|Wh-pronoun|
# |35|	WP\$|Possessive wh-pronoun|
# |36|	WRB	|Wh-adverb|

# %% [markdown]
# **Named entity extraction/chunking for tokens**

# %%
# Downloading nltk packages used in this example
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\Sohair
# [nltk_data]     Zaki\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to C:\Users\Sohair
# [nltk_data]     Zaki\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
jim = "Jim bought 300 shares of Acme Corp. in 2006."

tokens = nltk.word_tokenize(jim)
jim_tagged_tokens = nltk.pos_tag(tokens)

ne_chunks = nltk.chunk.ne_chunk(jim_tagged_tokens)

# %%
ne_chunks

# %%
ne_chunks = [nltk.chunk.ne_chunk(ptt) for ptt in pos_tagged_tokens]

ne_chunks[0].pprint()
ne_chunks[1].pprint()
# Out:
# (S
#   (PERSON Mr./NNP)
#   (PERSON Green/NNP)
#   killed/VBD
#   (ORGANIZATION Colonel/NNP Mustard/NNP)
#   in/IN
#   the/DT
#   study/NN
#   with/IN
#   the/DT
#   candlestick/NN
#   ./.)
# (S
#   (PERSON Mr./NNP)
#   (ORGANIZATION Green/NNP)
#   is/VBZ
#   not/RB
#   a/DT
#   very/RB
#   nice/JJ
#   fellow/NN
#   ./.)

# %% [markdown]
# ## Using NLTK’s NLP tools to process human language in blog data

# %%
import json
import nltk

BLOG_DATA = "data/feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

# Download nltk packages used in this example
nltk.download('stopwords')

# Customize your list of stopwords as needed. Here, we add common
# punctuation and contraction artifacts.

stop_words = nltk.corpus.stopwords.words('english') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    u'—',
    ']',
    '[',
    '...'
    ]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\szaki5\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
for post in blog_data:
    sentences = nltk.tokenize.sent_tokenize(post['content'])

    words = [w.lower() for sentence in sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)

    # Remove stopwords from fdist
    for sw in stop_words:
        del fdist[sw]
   
    # Basic stats

    num_words = sum([i[1] for i in fdist.items()])
    num_unique_words = len(fdist.keys())

    # Hapaxes are words that appear only once
    num_hapaxes = len(fdist.hapaxes())

    top_10_words_sans_stop_words = fdist.most_common(10)

    print(post['title'])
    print('\tNum Sentences:'.ljust(25), len(sentences))
    print('\tNum Words:'.ljust(25), num_words)
    print('\tNum Unique Words:'.ljust(25), num_unique_words)
    print('\tNum Hapaxes:'.ljust(25), num_hapaxes)
    print('\tTop 10 Most Frequent Words (sans stop words):\n\t\t', \
          '\n\t\t'.join(['{0} ({1})'.format(w[0], w[1]) for w in top_10_words_sans_stop_words]))
    print()
# Out:
# Four short links: 21 August 2017
# 	Num Sentences:           10
# 	Num Words:               140
# 	Num Unique Words:        113
# 	Num Hapaxes:             93
# 	Top 10 Most Frequent Words (sans stop words):
# 		 signals (5)
# 		cloud (4)
# 		application (3)
# 		drone (3)
# 		operations (2)
# 		machine (2)
# 		learning (2)
# 		radio (2)
# 		flying (2)
# 		cameras (2)
#
# 6 practical guidelines for implementing conversational AI
# 	Num Sentences:           69
# 	Num Words:               908
# 	Num Unique Words:        528
# 	Num Hapaxes:             354
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (21)
# 		“ (21)
# 		” (21)
# 		conversational (15)
# 		bots (7)
# 		says (7)
# 		interaction (7)
# 		must (7)
# 		user (7)
# 		kai (7)
#
# Four short links: 18 August 2017
# 	Num Sentences:           16
# 	Num Words:               263
# 	Num Unique Words:        204
# 	Num Hapaxes:             173
# 	Top 10 Most Frequent Words (sans stop words):
# 		 hype (9)
# 		jobs (5)
# 		technologies (5)
# 		cycle (5)
# 		’ (5)
# 		bayesian (4)
# 		years (4)
# 		style (3)
# 		cycles (3)
# 		20 (3)
#
# How Ray makes continuous learning accessible and easy to scale
# 	Num Sentences:           5
# 	Num Words:               85
# 	Num Unique Words:        64
# 	Num Hapaxes:             47
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (5)
# 		data (3)
# 		show (2)
# 		robert (2)
# 		nishihara (2)
# 		philipp (2)
# 		moritz (2)
# 		framework (2)
# 		reinforcement (2)
# 		ai (2)
#
# Julie Stanford on vetting designs through rapid experimentation
# 	Num Sentences:           3
# 	Num Words:               48
# 	Num Unique Words:        35
# 	Num Hapaxes:             27
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (5)
# 		rapid (3)
# 		experimentation (3)
# 		’ (2)
# 		podcast (2)
# 		julie (2)
# 		stanford (2)
# 		get (2)
# 		reilly (1)
# 		quickly (1)
#
# Jack Daniel on building community and historical context in InfoSec
# 	Num Sentences:           2
# 	Num Words:               43
# 	Num Unique Words:        30
# 	Num Hapaxes:             20
# 	Top 10 Most Frequent Words (sans stop words):
# 		 community (4)
# 		security (3)
# 		podcast (2)
# 		bsides (2)
# 		infosec (2)
# 		jack (2)
# 		daniel (2)
# 		building (2)
# 		historical (2)
# 		context (2)
#
# Four short links: 17 August 2017
# 	Num Sentences:           11
# 	Num Words:               169
# 	Num Unique Words:        145
# 	Num Hapaxes:             129
# 	Top 10 Most Frequent Words (sans stop words):
# 		 via (4)
# 		interaction (4)
# 		us (3)
# 		mappy (3)
# 		system (3)
# 		rooms (3)
# 		eliminating (2)
# 		mapping (2)
# 		nes (2)
# 		world (2)
#
# Contouring learning rate to optimize neural nets
# 	Num Sentences:           115
# 	Num Words:               1371
# 	Num Unique Words:        674
# 	Num Hapaxes:             434
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (70)
# 		rate (45)
# 		’ (16)
# 		network (16)
# 		loss (15)
# 		decay (14)
# 		gradient (13)
# 		error (13)
# 		training (13)
# 		rates (11)
#
# Creating better disaster recovery plans
# 	Num Sentences:           73
# 	Num Words:               686
# 	Num Unique Words:        408
# 	Num Hapaxes:             283
# 	Top 10 Most Frequent Words (sans stop words):
# 		 n't (13)
# 		disaster (10)
# 		need (10)
# 		recovery (8)
# 		system (8)
# 		dependencies (8)
# 		systems (7)
# 		one (7)
# 		start (7)
# 		make (6)
#
# Announcing the Rebecca Bace Pioneer Award for Defensive Security
# 	Num Sentences:           34
# 	Num Words:               445
# 	Num Unique Words:        276
# 	Num Hapaxes:             206
# 	Top 10 Most Frequent Words (sans stop words):
# 		 becky (17)
# 		security (17)
# 		bace (10)
# 		’ (8)
# 		award (6)
# 		pioneer (6)
# 		detection (6)
# 		rebecca (5)
# 		community (5)
# 		reilly (4)
#
# How synthetic biology startups are building the future at RebelBio
# 	Num Sentences:           132
# 	Num Words:               1724
# 	Num Unique Words:        1012
# 	Num Hapaxes:             700
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (22)
# 		biology (18)
# 		new (18)
# 		“ (13)
# 		” (13)
# 		rebelbio (11)
# 		world (11)
# 		image (11)
# 		figure (10)
# 		team (10)
#
# The impact of design at Shopify
# 	Num Sentences:           87
# 	Num Words:               799
# 	Num Unique Words:        477
# 	Num Hapaxes:             341
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (26)
# 		design (16)
# 		designers (10)
# 		developers (10)
# 		work (9)
# 		process (8)
# 		use (8)
# 		learn (8)
# 		designer (7)
# 		shopify (6)
#
# Take the 2018 Data Science Salary Survey
# 	Num Sentences:           5
# 	Num Words:               43
# 	Num Unique Words:        35
# 	Num Hapaxes:             28
# 	Top 10 Most Frequent Words (sans stop words):
# 		 survey (3)
# 		data (2)
# 		responses (2)
# 		reported (2)
# 		aggregate (2)
# 		assure (2)
# 		anonymity (2)
# 		professional (1)
# 		invited (1)
# 		share (1)
#
# Four short links: 16 August 2017
# 	Num Sentences:           13
# 	Num Words:               155
# 	Num Unique Words:        119
# 	Num Hapaxes:             93
# 	Top 10 Most Frequent Words (sans stop words):
# 		 neural (4)
# 		networks (4)
# 		’ (4)
# 		virtual (3)
# 		network (3)
# 		natural (3)
# 		language (3)
# 		iot (2)
# 		using (2)
# 		logical (2)
#
# Four short links: 15 August 2017
# 	Num Sentences:           19
# 	Num Words:               206
# 	Num Unique Words:        144
# 	Num Hapaxes:             112
# 	Top 10 Most Frequent Words (sans stop words):
# 		 problems (6)
# 		solution (5)
# 		efficient (5)
# 		n't (5)
# 		p (4)
# 		np (4)
# 		problem (4)
# 		proven (4)
# 		`` (4)
# 		'' (4)
#
# How to use Presto Sketching to clarify your team’s purpose
# 	Num Sentences:           44
# 	Num Words:               545
# 	Num Unique Words:        283
# 	Num Hapaxes:             202
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (33)
# 		team (31)
# 		purpose (24)
# 		‘ (11)
# 		map (10)
# 		group (9)
# 		everyone (8)
# 		future (6)
# 		goals (6)
# 		see (5)
#
# Four short links: 14 August 2017
# 	Num Sentences:           9
# 	Num Words:               123
# 	Num Unique Words:        98
# 	Num Hapaxes:             81
# 	Top 10 Most Frequent Words (sans stop words):
# 		 failures (6)
# 		robotics (3)
# 		interviews (3)
# 		complex (3)
# 		systems (3)
# 		customer (2)
# 		development (2)
# 		engineering (2)
# 		method (2)
# 		“ (2)
#
# A multi-cloud strategy is the foundation for digital transformation
# 	Num Sentences:           32
# 	Num Words:               564
# 	Num Unique Words:        371
# 	Num Hapaxes:             290
# 	Top 10 Most Frequent Words (sans stop words):
# 		 digital (16)
# 		cloud (15)
# 		transformation (12)
# 		multi-cloud (12)
# 		data (10)
# 		companies (9)
# 		business (8)
# 		strategy (8)
# 		one (6)
# 		technology (6)
#
# How to choose a cloud provider
# 	Num Sentences:           60
# 	Num Words:               514
# 	Num Unique Words:        310
# 	Num Hapaxes:             225
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (19)
# 		cloud (18)
# 		use (13)
# 		providers (12)
# 		provider (11)
# 		case (7)
# 		make (6)
# 		level (6)
# 		managed (6)
# 		services (6)
#
# Four short links: 11 August 2017
# 	Num Sentences:           14
# 	Num Words:               200
# 	Num Unique Words:        160
# 	Num Hapaxes:             135
# 	Top 10 Most Frequent Words (sans stop words):
# 		 game (6)
# 		dna (5)
# 		simulation (4)
# 		> (4)
# 		wi-fi (3)
# 		security (3)
# 		computer (3)
# 		predictive (3)
# 		cracking (2)
# 		animation (2)
#
# Mike Roberts on serverless architectures
# 	Num Sentences:           3
# 	Num Words:               51
# 	Num Unique Words:        34
# 	Num Hapaxes:             23
# 	Top 10 Most Frequent Words (sans stop words):
# 		 serverless (4)
# 		’ (3)
# 		reilly (3)
# 		architecture (3)
# 		roberts (3)
# 		programming (2)
# 		podcast (2)
# 		next (2)
# 		cloud (2)
# 		mike (2)
#
# How to craft a voice user interface that won’t leave you frustrated
# 	Num Sentences:           1
# 	Num Words:               14
# 	Num Unique Words:        14
# 	Num Hapaxes:             14
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (1)
# 		principles (1)
# 		creating (1)
# 		truly (1)
# 		conversational (1)
# 		ui.continue (1)
# 		reading (1)
# 		craft (1)
# 		voice (1)
# 		user (1)
#
# Four short links: 10 August 2017
# 	Num Sentences:           8
# 	Num Words:               133
# 	Num Unique Words:        106
# 	Num Hapaxes:             84
# 	Top 10 Most Frequent Words (sans stop words):
# 		 salmon (5)
# 		sarcasm (3)
# 		% (3)
# 		gmo (2)
# 		new (2)
# 		deep (2)
# 		learning (2)
# 		courses (2)
# 		serverless (2)
# 		malware (2)
#
# Four short links: 9 August 2017
# 	Num Sentences:           10
# 	Num Words:               180
# 	Num Unique Words:        143
# 	Num Hapaxes:             119
# 	Top 10 Most Frequent Words (sans stop words):
# 		 event (7)
# 		’ (4)
# 		detection (3)
# 		autonomous (3)
# 		john (3)
# 		deere (3)
# 		tractor (3)
# 		still (3)
# 		trend (2)
# 		separation (2)
#
# Deep learning revolutionizes conversational AI
# 	Num Sentences:           120
# 	Num Words:               1290
# 	Num Unique Words:        581
# 	Num Hapaxes:             348
# 	Top 10 Most Frequent Words (sans stop words):
# 		 speech (54)
# 		recognition (41)
# 		machine (19)
# 		system (18)
# 		ai (17)
# 		learning (17)
# 		data (17)
# 		deep (16)
# 		language (11)
# 		techniques (10)
#
# Cancer detection, one slice at a time
# 	Num Sentences:           67
# 	Num Words:               764
# 	Num Unique Words:        479
# 	Num Hapaxes:             362
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ke (19)
# 		’ (19)
# 		data (15)
# 		slide (12)
# 		tissue (11)
# 		histowiz (11)
# 		cancer (10)
# 		slides (8)
# 		researchers (7)
# 		research (7)
#
# Integrating data with AI
# 	Num Sentences:           17
# 	Num Words:               310
# 	Num Unique Words:        208
# 	Num Hapaxes:             161
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (11)
# 		’ (10)
# 		knudsen (7)
# 		important (7)
# 		spam (5)
# 		“ (4)
# 		” (4)
# 		need (4)
# 		email (4)
# 		tamr (3)
#
# Jupyter Insights: Lorena Barba, an associate professor of mechanical and aerospace engineering
# 	Num Sentences:           45
# 	Num Words:               379
# 	Num Unique Words:        275
# 	Num Hapaxes:             219
# 	Top 10 Most Frequent Words (sans stop words):
# 		 jupyter (15)
# 		research (6)
# 		new (5)
# 		’ (5)
# 		reproducibility (4)
# 		use (4)
# 		tools (4)
# 		reproducible (4)
# 		education (3)
# 		barba (3)
#
# Four short links: 8 August 2017
# 	Num Sentences:           7
# 	Num Words:               69
# 	Num Unique Words:        58
# 	Num Hapaxes:             48
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ai (3)
# 		bloom (2)
# 		filter (2)
# 		future (2)
# 		adversarial (2)
# 		benchmarking (2)
# 		civilized (2)
# 		jeff (2)
# 		stand (2)
# 		anything (2)
#
# Why continuous learning is key to AI
# 	Num Sentences:           45
# 	Num Words:               605
# 	Num Unique Words:        355
# 	Num Hapaxes:             247
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (31)
# 		rl (12)
# 		continuous (10)
# 		’ (8)
# 		ai (8)
# 		algorithms (8)
# 		set (7)
# 		ray (7)
# 		machine (6)
# 		data (6)
#
# Four short links: 7 August 2017
# 	Num Sentences:           8
# 	Num Words:               157
# 	Num Unique Words:        125
# 	Num Hapaxes:             105
# 	Top 10 Most Frequent Words (sans stop words):
# 		 social (4)
# 		computational (4)
# 		zoom (4)
# 		ai (3)
# 		architecture (3)
# 		game (3)
# 		framework (3)
# 		several (3)
# 		technology (3)
# 		policy (2)
#
# How to move your team closer to clarity
# 	Num Sentences:           36
# 	Num Words:               364
# 	Num Unique Words:        265
# 	Num Hapaxes:             219
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (10)
# 		thinking (8)
# 		agile (8)
# 		lean (7)
# 		mindset (7)
# 		software (6)
# 		’ (6)
# 		development (3)
# 		learning (3)
# 		mindsets (3)
#
# Four short links: 4 August 2017
# 	Num Sentences:           6
# 	Num Words:               133
# 	Num Unique Words:        114
# 	Num Hapaxes:             98
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (5)
# 		history (2)
# 		intelligence (2)
# 		patreon (2)
# 		javascript (2)
# 		quackspeak (2)
# 		china (2)
# 		three (2)
# 		channel (2)
# 		people (2)
#
# JupyterHub on Google Cloud
# 	Num Sentences:           67
# 	Num Words:               1170
# 	Num Unique Words:        507
# 	Num Hapaxes:             321
# 	Top 10 Most Frequent Words (sans stop words):
# 		 # (74)
# 		jupyterhub (36)
# 		helm (18)
# 		name (17)
# 		> (15)
# 		install (14)
# 		cluster (14)
# 		gcloud (12)
# 		image (12)
# 		$ (11)
#
# Why AI and machine learning researchers are beginning to embrace PyTorch
# 	Num Sentences:           5
# 	Num Words:               93
# 	Num Unique Words:        71
# 	Num Hapaxes:             56
# 	Top 10 Most Frequent Words (sans stop words):
# 		 learning (4)
# 		pytorch (4)
# 		chintala (3)
# 		deep (3)
# 		researchers (3)
# 		data (2)
# 		show (2)
# 		soumith (2)
# 		successor (2)
# 		torch (2)
#
# A DevOps approach to data management
# 	Num Sentences:           26
# 	Num Words:               358
# 	Num Unique Words:        232
# 	Num Hapaxes:             163
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (24)
# 		types (5)
# 		multi-model (4)
# 		variety (4)
# 		devops (4)
# 		needs (4)
# 		also (4)
# 		schemas (4)
# 		database (4)
# 		approach (3)
#
# Four short links: 3 August 2017
# 	Num Sentences:           12
# 	Num Words:               129
# 	Num Unique Words:        112
# 	Num Hapaxes:             99
# 	Top 10 Most Frequent Words (sans stop words):
# 		 price (4)
# 		poverty (3)
# 		study (3)
# 		unicorns (2)
# 		finding (2)
# 		’ (2)
# 		% (2)
# 		reading (2)
# 		early (2)
# 		customer (2)
#
# Declaring variables in Kotlin
# 	Num Sentences:           1
# 	Num Words:               12
# 	Num Unique Words:        11
# 	Num Hapaxes:             10
# 	Top 10 Most Frequent Words (sans stop words):
# 		 variables (2)
# 		learn (1)
# 		difference (1)
# 		mutable (1)
# 		immutable (1)
# 		cut (1)
# 		boilerplate (1)
# 		code.continue (1)
# 		reading (1)
# 		declaring (1)
#
# Building—and scaling—a reliable distributed architecture
# 	Num Sentences:           7
# 	Num Words:               95
# 	Num Unique Words:        71
# 	Num Hapaxes:             58
# 	Top 10 Most Frequent Words (sans stop words):
# 		 service (5)
# 		scale (5)
# 		joseph (3)
# 		robert (3)
# 		managing (3)
# 		dependencies (3)
# 		netflix (3)
# 		breuer (2)
# 		reta (2)
# 		implementing (2)
#
# Operationalizing security risk
# 	Num Sentences:           1
# 	Num Words:               10
# 	Num Unique Words:        9
# 	Num Hapaxes:             8
# 	Top 10 Most Frequent Words (sans stop words):
# 		 risk (2)
# 		bruce (1)
# 		potter (1)
# 		build (1)
# 		assessment (1)
# 		program.continue (1)
# 		reading (1)
# 		operationalizing (1)
# 		security (1)
#
# Reinforcement learning for complex goals, using TensorFlow
# 	Num Sentences:           112
# 	Num Words:               1372
# 	Num Unique Words:        595
# 	Num Hapaxes:             364
# 	Top 10 Most Frequent Words (sans stop words):
# 		 \ (45)
# 		agent (23)
# 		reward (23)
# 		battery (21)
# 		learning (18)
# 		environment (15)
# 		future (15)
# 		network (15)
# 		goal (13)
# 		state (13)
#
# Jay Jacobs on data analytics and security
# 	Num Sentences:           2
# 	Num Words:               58
# 	Num Unique Words:        33
# 	Num Hapaxes:             19
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (8)
# 		security (6)
# 		analytics (3)
# 		’ (2)
# 		reilly (2)
# 		podcast (2)
# 		convenient (2)
# 		first (2)
# 		steps (2)
# 		toward (2)
#
# Four short links: 2 August 2017
# 	Num Sentences:           11
# 	Num Words:               126
# 	Num Unique Words:        101
# 	Num Hapaxes:             82
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ; (4)
# 		app (3)
# 		make (3)
# 		threshold (3)
# 		research (3)
# 		headless (2)
# 		chrome (2)
# 		scientific (2)
# 		significance (2)
# 		sizes (2)
# The wisdom hierarchy: From signals to artificial intelligence and beyond
# 	Num Sentences:           73
# 	Num Words:               796
# 	Num Unique Words:        449
# 	Num Hapaxes:             319
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (37)
# 		wisdom (19)
# 		information (17)
# 		knowledge (17)
# 		’ (13)
# 		hierarchy (13)
# 		humans (11)
# 		ai (10)
# 		human (9)
# 		value (8)
#
# Four short links: 1 August 2017
# 	Num Sentences:           9
# 	Num Words:               142
# 	Num Unique Words:        120
# 	Num Hapaxes:             102
# 	Top 10 Most Frequent Words (sans stop words):
# 		 x86 (3)
# 		ai (3)
# 		bugs (3)
# 		; (3)
# 		rna (2)
# 		coding (2)
# 		1960s (2)
# 		based (2)
# 		make (2)
# 		decisions (2)
#
# How can I add simple, automated data visualizations and dashboards to Jupyter Notebooks
# 	Num Sentences:           1
# 	Num Words:               21
# 	Num Unique Words:        18
# 	Num Hapaxes:             15
# 	Top 10 Most Frequent Words (sans stop words):
# 		 jupyter (2)
# 		notebooks (2)
# 		visualizations (2)
# 		learn (1)
# 		use (1)
# 		pixiedust (1)
# 		create (1)
# 		quick (1)
# 		easy (1)
# 		powerful (1)
#
# From prototype to product with hybrid neural networks
# 	Num Sentences:           33
# 	Num Words:               578
# 	Num Unique Words:        354
# 	Num Hapaxes:             262
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (16)
# 		deep (9)
# 		learning (9)
# 		neural (9)
# 		network (9)
# 		networks (8)
# 		declarative (7)
# 		frameworks (7)
# 		framework (7)
# 		“ (7)
#
# Four short links: 31 July 2017
# 	Num Sentences:           9
# 	Num Words:               175
# 	Num Unique Words:        140
# 	Num Hapaxes:             118
# 	Top 10 Most Frequent Words (sans stop words):
# 		 “ (5)
# 		” (5)
# 		sign (5)
# 		conditions (4)
# 		fiction (3)
# 		anonymous (3)
# 		statistics (2)
# 		machine (2)
# 		learning (2)
# 		digital (2)
#
# Four short links: 28 July 2017
# 	Num Sentences:           13
# 	Num Words:               129
# 	Num Unique Words:        107
# 	Num Hapaxes:             91
# 	Top 10 Most Frequent Words (sans stop words):
# 		 machine (4)
# 		security (3)
# 		a-ha (3)
# 		knitting (3)
# 		img2track (3)
# 		usable (2)
# 		philosophy (2)
# 		time (2)
# 		making (2)
# 		default (2)
#
# Eric Freeman and Elisabeth Robson on design patterns
# 	Num Sentences:           2
# 	Num Words:               54
# 	Num Unique Words:        41
# 	Num Hapaxes:             30
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (3)
# 		patterns (3)
# 		’ (2)
# 		reilly (2)
# 		programming (2)
# 		podcast (2)
# 		eric (2)
# 		freeman (2)
# 		elisabeth (2)
# 		robson (2)
#
# John Whalen on using brain science in design
# 	Num Sentences:           2
# 	Num Words:               71
# 	Num Unique Words:        56
# 	Num Hapaxes:             43
# 	Top 10 Most Frequent Words (sans stop words):
# 		 ’ (3)
# 		design (3)
# 		podcast (2)
# 		“ (2)
# 		six (2)
# 		minds (2)
# 		” (2)
# 		human (2)
# 		john (2)
# 		whalen (2)
#
# When you hear hooves, think horse, not zebra
# 	Num Sentences:           9
# 	Num Words:               123
# 	Num Unique Words:        109
# 	Num Hapaxes:             98
# 	Top 10 Most Frequent Words (sans stop words):
# 		 think (3)
# 		horse (3)
# 		patient (3)
# 		physician (2)
# 		zebras (2)
# 		diagnosis (2)
# 		one (2)
# 		hear (2)
# 		would (2)
# 		fevers (2)
#
# Classifying traffic signs with Apache MXNet: An introduction to computer vision with neural networks
# 	Num Sentences:           93
# 	Num Words:               2106
# 	Num Unique Words:        834
# 	Num Hapaxes:             484
# 	Top 10 Most Frequent Words (sans stop words):
# 		 = (77)
# 		'' (67)
# 		# (37)
# 		image (35)
# 		data (29)
# 		set (21)
# 		32 (21)
# 		name= (20)
# 		network (19)
# 		neural (18)
#
# Four short links: 27 July 2017
# 	Num Sentences:           6
# 	Num Words:               87
# 	Num Unique Words:        77
# 	Num Hapaxes:             69
# 	Top 10 Most Frequent Words (sans stop words):
# 		 trust (3)
# 		embryos (3)
# 		next (2)
# 		evolution (2)
# 		indoor (2)
# 		robots (2)
# 		game (2)
# 		first (2)
# 		death (1)
# 		embryo (1)
#
# R’s tidytext turns messy text into valuable insight
# 	Num Sentences:           48
# 	Num Words:               705
# 	Num Unique Words:        373
# 	Num Hapaxes:             257
# 	Top 10 Most Frequent Words (sans stop words):
# 		 text (40)
# 		data (24)
# 		mining (19)
# 		r (12)
# 		words (11)
# 		“ (10)
# 		” (10)
# 		’ (10)
# 		sentiment (9)
# 		tidy (8)
#
# Four short links: 26 July 2017
# 	Num Sentences:           9
# 	Num Words:               145
# 	Num Unique Words:        125
# 	Num Hapaxes:             110
# 	Top 10 Most Frequent Words (sans stop words):
# 		 employees (4)
# 		securities (3)
# 		use (3)
# 		company (3)
# 		blockchain (2)
# 		robotics (2)
# 		deep (2)
# 		learning (2)
# 		report (2)
# 		capital (2)
#
# Making great hires in your design organization
# 	Num Sentences:           1
# 	Num Words:               13
# 	Num Unique Words:        12
# 	Num Hapaxes:             11
# 	Top 10 Most Frequent Words (sans stop words):
# 		 design (2)
# 		help (1)
# 		team (1)
# 		succeed (1)
# 		develop (1)
# 		stronger (1)
# 		practice.continue (1)
# 		reading (1)
# 		making (1)
# 		great (1)
#
# A lesson in prescriptive modeling
# 	Num Sentences:           1
# 	Num Words:               12
# 	Num Unique Words:        12
# 	Num Hapaxes:             12
# 	Top 10 Most Frequent Words (sans stop words):
# 		 simulate (1)
# 		new (1)
# 		business (1)
# 		models (1)
# 		practices (1)
# 		open (1)
# 		source (1)
# 		code.continue (1)
# 		reading (1)
# 		lesson (1)
#
# Four short links: 25 July 2017
# 	Num Sentences:           12
# 	Num Words:               131
# 	Num Unique Words:        112
# 	Num Hapaxes:             97
# 	Top 10 Most Frequent Words (sans stop words):
# 		 u2f (4)
# 		ai (3)
# 		soft (3)
# 		sentencing (2)
# 		encrypted (2)
# 		email (2)
# 		algorithm (2)
# 		ca (2)
# 		n't (2)
# 		whether (2)
#
# Data science startups focus on AI-enabled efficiency
# 	Num Sentences:           25
# 	Num Words:               308
# 	Num Unique Words:        244
# 	Num Hapaxes:             204
# 	Top 10 Most Frequent Words (sans stop words):
# 		 data (14)
# 		us (4)
# 		winner (4)
# 		winners (3)
# 		business (3)
# 		clouds (3)
# 		ai (3)
# 		gave (3)
# 		often (3)
# 		big (3)

# %% [markdown]
# ## A document summarization algorithm based principally upon sentence detection and frequency analysis within sentences

# %%
import json
import nltk
import numpy

BLOG_DATA = "feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

N = 100  # Number of words to consider
CLUSTER_THRESHOLD = 5  # Distance between words to consider
TOP_SENTENCES = 5  # Number of sentences to return for a "top n" summary

# %%
stop_words = nltk.corpus.stopwords.words('english') + [
    '.',
    ',',
    '--',
    '\'s',
    '?',
    ')',
    '(',
    ':',
    '\'',
    '\'re',
    '"',
    '-',
    '}',
    '{',
    u'—',
    '>',
    '<',
    '...'
    ]

# %%
# Approach taken from "The Automatic Creation of Literature Abstracts" by H.P. Luhn
def _score_sentences(sentences, important_words):
    scores = []
    sentence_idx = 0

    for s in [nltk.tokenize.word_tokenize(s) for s in sentences]:

        word_idx = []

        # For each word in the word list...
        for w in important_words:
            try:
                # Compute an index for where any important words occur in the sentence.
                word_idx.append(s.index(w))
            except ValueError: # w not in this particular sentence
                pass

        word_idx.sort()

        # It is possible that some sentences may not contain any important words at all.
        if len(word_idx)== 0: continue

        # Using the word index, compute clusters by using a max distance threshold
        # for any two consecutive words.

        clusters = []
        cluster = [word_idx[0]]
        i = 1
        while i < len(word_idx):
            if word_idx[i] - word_idx[i - 1] < CLUSTER_THRESHOLD:
                cluster.append(word_idx[i])
            else:
                clusters.append(cluster[:])
                cluster = [word_idx[i]]
            i += 1
        clusters.append(cluster)

        # Score each cluster. The max score for any given cluster is the score 
        # for the sentence.

        max_cluster_score = 0
        
        for c in clusters:
            significant_words_in_cluster = len(c)
            # true clusters also contain insignificant words, so we get 
            # the total cluster length by checking the indices
            total_words_in_cluster = c[-1] - c[0] + 1
            score = 1.0 * significant_words_in_cluster**2 / total_words_in_cluster

            if score > max_cluster_score:
                max_cluster_score = score

        scores.append((sentence_idx, max_cluster_score))
        sentence_idx += 1

    return scores

# %%
def summarize(txt):
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    normalized_sentences = [s.lower() for s in sentences]

    words = [w.lower() for sentence in normalized_sentences for w in
             nltk.tokenize.word_tokenize(sentence)]

    fdist = nltk.FreqDist(words)
    
    # Remove stopwords from fdist
    for sw in stop_words:
        del fdist[sw]

    top_n_words = [w[0] for w in fdist.most_common(N)]

    scored_sentences = _score_sentences(normalized_sentences, top_n_words)

    # Summarization Approach 1:
    # Filter out nonsignificant sentences by using the average score plus a
    # fraction of the std dev as a filter

    avg = numpy.mean([s[1] for s in scored_sentences])
    std = numpy.std([s[1] for s in scored_sentences])
    mean_scored = [(sent_idx, score) for (sent_idx, score) in scored_sentences
                   if score > avg + 0.5 * std]

    # Summarization Approach 2:
    # Another approach would be to return only the top N ranked sentences

    top_n_scored = sorted(scored_sentences, key=lambda s: s[1])[-TOP_SENTENCES:]
    top_n_scored = sorted(top_n_scored, key=lambda s: s[0])

    # Decorate the post object with summaries

    return dict(top_n_summary=[sentences[idx] for (idx, score) in top_n_scored],
                mean_scored_summary=[sentences[idx] for (idx, score) in mean_scored])

# %%
for post in blog_data: 
    post.update(summarize(post['content']))

    print(post['title'])
    print('=' * len(post['title']))
    print()
    print('Top N Summary')
    print('-------------')
    print(' '.join(post['top_n_summary']))
    print()
    print('Mean Scored Summary')
    print('-------------------')
    print(' '.join(post['mean_scored_summary']))
    print()
# Out:
# Four short links: 30 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# To Microservices and Back Again: Why Segment Went Back to a Monolith — microservices came with increased operational overhead and problems around code reuse. … If microservices are implemented incorrectly or used as a band-aid without addressing some of the root flaws in your system, you’ll be unable to do new product development because you’re drowning in the complexity. Not limited to editing basic entities such as bits and bytes, it provides a full-fledged procedural, interactive programming language designed to describe data structures and to operate on them. (via Kernel Recipes)
# Blender — Facebook open sourced their open-domain (“can talk about anything!”) chatbot. Human evaluations show our best models are superior to existing approaches in multi-turn dialogue in terms of engagingness and humanness measurements.
#
# Mean Scored Summary
# -------------------
# Not limited to editing basic entities such as bits and bytes, it provides a full-fledged procedural, interactive programming language designed to describe data structures and to operate on them. (via Kernel Recipes)
# Blender — Facebook open sourced their open-domain (“can talk about anything!”) chatbot. Human evaluations show our best models are superior to existing approaches in multi-turn dialogue in terms of engagingness and humanness measurements.
#
# Four short links: 29 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# podpaperscissors — From the classic “prisoner’s dilemma” to more obscure coördination games, Pod Paper Scissors takes game theory out of the dry textbook and into the real world. Experts in a variety of fields will casually converse with the hosts about how the particular game discussed applies to their work. The podcast is hosted by game theorist Ben Klemens and science journalist and composer Liz Landau. (via Ben Klemens)
# Verification Handbook (3ed) — latest guide to investigating disinformation and media manipulation, covering identifying actors, investigating platforms, tracking ads, etc. (via Craig Silverman)
# Ransomware Groups (Microsoft) — analysis of ransomware campaigns yields this report, which includes a great graphic taxonomy of ransomware payloads.
#
# Mean Scored Summary
# -------------------
#
# podpaperscissors — From the classic “prisoner’s dilemma” to more obscure coördination games, Pod Paper Scissors takes game theory out of the dry textbook and into the real world. (via Ben Klemens)
# Verification Handbook (3ed) — latest guide to investigating disinformation and media manipulation, covering identifying actors, investigating platforms, tracking ads, etc.
#
# Four short links: 28 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# Learning a Language — this list of questions facing anyone taking a new language for a test run just burns with truth. (Also: encouraging to see how many of these questions are answered by the Cookbook format)
# OpenVAS — Open Vulnerability Assessment Scanner, aka “what a cheap external security assessment vendor will run and then mail you the report from.”
# Paxos vs Raft: Have we Reached Consensus on Distributed Consensus? Most notably, Raft only allows servers with up-to-date logs to become leaders, whereas Paxos allows any server to be leader provided it then updates its log to ensure it is up-to-date. We surmise that much of the understandability of Raft comes from the paper’s clear presentation rather than being fundamental to the underlying algorithm being presented. Google Research Football — a novel Reinforcement Learning environment where agents aim to master the world’s most popular sport—football.
#
# Mean Scored Summary
# -------------------
# (Also: encouraging to see how many of these questions are answered by the Cookbook format)
# OpenVAS — Open Vulnerability Assessment Scanner, aka “what a cheap external security assessment vendor will run and then mail you the report from.”
# Paxos vs Raft: Have we Reached Consensus on Distributed Consensus?
#
# Four short links: 27 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# Teleforking a Process onto a Different Computer — a working proof of concept (I just don’t replicate tricky things so that I could keep it simple, meaning it’s just a fun tech demo you probably shouldn’t use for anything real) of a telefork() function call that spawns a process on another machine and returns the instance ID. Consistency Maps — Jepsen analyses the safety properties of distributed systems–most notably, identifying violations of consistency models. What kind of consistency does a given program really need? In this reference guide, we provide basic definitions, intuitive explanations, and theoretical underpinnings of various consistency models for engineers and academics alike. Expert Twitter Only Goes So Far: Bring Back Blogs (Wired) — we’re surrounded by opinion machines (because opinion is cheap to produce and make inflammatory, it’s a natural fit for engagement-driven businesses), so it’s nice to find knowledgeable people sharing their expertise.
#
# Mean Scored Summary
# -------------------
#
# Teleforking a Process onto a Different Computer — a working proof of concept (I just don’t replicate tricky things so that I could keep it simple, meaning it’s just a fun tech demo you probably shouldn’t use for anything real) of a telefork() function call that spawns a process on another machine and returns the instance ID. Consistency Maps — Jepsen analyses the safety properties of distributed systems–most notably, identifying violations of consistency models. In this reference guide, we provide basic definitions, intuitive explanations, and theoretical underpinnings of various consistency models for engineers and academics alike. Expert Twitter Only Goes So Far: Bring Back Blogs (Wired) — we’re surrounded by opinion machines (because opinion is cheap to produce and make inflammatory, it’s a natural fit for engagement-driven businesses), so it’s nice to find knowledgeable people sharing their expertise.
#
# Four short links: 24 April 2020
# ===============================
#
# Top N Summary
# -------------
# It is deeply embedded in Python, and its just-in-time compiler offloads compute-intensive tasks to multi-core CPUs and massively parallel GPUs. The intended audience includes engineers and scientists budgeting their model-training experiments, as well as non-practitioners trying to make sense of the economics of modern-day Natural Language Processing (NLP). Killing Net Neutrality Did Not Save the Pandemic Internet — there’s no evidence that European networks have fallen apart during the COVID-19 crisis. Netflix’s decision to throttle back its bandwidth usage by 25% was done entirely pro-actively. There was no underlying network data provided by regulators to justify the move.
#
# Mean Scored Summary
# -------------------
# It is deeply embedded in Python, and its just-in-time compiler offloads compute-intensive tasks to multi-core CPUs and massively parallel GPUs. The intended audience includes engineers and scientists budgeting their model-training experiments, as well as non-practitioners trying to make sense of the economics of modern-day Natural Language Processing (NLP). Killing Net Neutrality Did Not Save the Pandemic Internet — there’s no evidence that European networks have fallen apart during the COVID-19 crisis. Netflix’s decision to throttle back its bandwidth usage by 25% was done entirely pro-actively.
#
# Four short links: 23 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# Moloch — Large scale, open source, indexed packet capture and search. 3Dify Instagram Photos — open source toolset for adding a 3d effect to photos on Instagram’s web site. It uses 3d-photo-inpainting running in Colab (free GPU) and Cloud pubsub/storage for communication. A glimpse of the future: we could augment all our apps with deep learning-based services, but we still need to conquer paying for the GPUs and making it easy to use. Full of killer points like Every responsibility a team cedes to increase its focus becomes a new cross-team dependency.
#
# Mean Scored Summary
# -------------------
# A glimpse of the future: we could augment all our apps with deep learning-based services, but we still need to conquer paying for the GPUs and making it easy to use. Full of killer points like Every responsibility a team cedes to increase its focus becomes a new cross-team dependency.
#
# How data privacy leader Apple found itself in a data ethics catastrophe
# =======================================================================
#
# Top N Summary
# -------------
# The European Union’s General Data Protection Regulation (GDPR), for instance, imposes fines of up to 2%–4% of global annual revenue. For instance, Apple has implemented some provisions of the European Union’s General Data Protection Regulation for all US residents—not just EU and CA residents—including the ability to access and edit data. But ethics strategies have major limitations leaders must address
#
#
#
# As demonstrated by the waves of ethical “principles” released by Fortune 500 companies and commissions, ethics programs can be murky, dominated by a white, male, and Western interpretation. To move beyond narrow interpretations of ethics, ethical leaders must engage with critiques—like the Feminist Data Manifest-no. While incorporating human rights and ethics into business strategies may be costly in the short run, over the long term, Paul Barrett, deputy director of New York University’s Center for Business and Human Rights, argues that “companies will benefit financially from operating humane, efficient supply chains and employing motivated workers proud of their jobs.”
#
#
#
# Ultimately, organizations that discard ethics may find themselves on the wrong side of history.
#
# Mean Scored Summary
# -------------------
# Three months ago, Apple released a new credit card in partnership with Goldman Sachs that aimed to disrupt the highly regulated world of consumer finance. The importance of ethics does not, however, mean companies should ignore compliance
#
#
#
# Compliance functions are powerful because legal violations result in clear financial costs. The European Union’s General Data Protection Regulation (GDPR), for instance, imposes fines of up to 2%–4% of global annual revenue. Fines in the billions have been levied against Google and Facebook, and Practice Fusion (an electronic medical records company) has agreed to a $145 million settlement for using “its EHR software to influence physician prescribing of opioid pain medications.”
#
#
#
# Because of its clear impact on the bottom line, compliance often reshapes business operations. Here, the public discovered that even highly experienced senators didn’t fully understand key technologies, like Facebook, much less their potential harm on users. Furthermore, compliance-only companies will play a seemingly insurmountable game of “whack-a-mole” as new data regulations pass around the world. An ethics leader protects users and workers in its operations by using governance best practices. When creating the product, it uses data protection by design, working with cross-functional roles like legal and privacy engineers to embed ethical principles into the lifecycle of the product and formalize data-sharing agreements. Before launching, it audits the product thoroughly and conducts scenario planning to understand potential ethical mishaps, such as perceived or real gender bias or human rights violations in its supply chain. Ethics leaders also fight for users and workers, who can be forgotten. With social movements, leaders fight powerful actors preying on vulnerable communities or the public at large—and critically examines and ameliorates its own participation in systemic violence. Finally, ethics leaders empower their users and workers. Alison Taylor, the Executive Director of Ethical Systems, argues that internal processes should “improve [workers’] reasoning and creativity, instead of short-circuiting them.” Enabling this is a culture of psychological safety and training to engage kindly with divergent ideas. For instance, Apple has implemented some provisions of the European Union’s General Data Protection Regulation for all US residents—not just EU and CA residents—including the ability to access and edit data. But ethics strategies have major limitations leaders must address
#
#
#
# As demonstrated by the waves of ethical “principles” released by Fortune 500 companies and commissions, ethics programs can be murky, dominated by a white, male, and Western interpretation. When companies substitute unaccountable data ethics principles for thoughtful engagement with the enforceable data regulation principles, users will be harmed. In recessions, these “soft” programs may be the first on the chopping block. To move beyond narrow interpretations of ethics, ethical leaders must engage with critiques—like the Feminist Data Manifest-no. Similarly, leaders must engage with international human rights frameworks (IHRFs), such as the Universal Declaration of Human Rights and International Covenant on Economic, Social and Cultural Rights. To gain more buy-in from top internal business leaders, ethics leaders can form coalitions with compliance, data, and even marketing departments. By leading programs with resources and measurable accountability, ethics leaders must articulate how ethics improves trust and loyalty. The effectiveness of such coalitions may explain the rise of chief ethics and compliance officers— as well as a host of new chief trust, social responsibility, citizenship, and data officers by technology leaders like Salesforce, Workday, and Unisys. These include those focused (a) on specific technologies like AI, such as The Partnership on AI, (b) on specific industries, such as health (All-in), government (Civic Data Privacy Leaders Network), and cities (Cities Coalition for Digital Rights or the Right to the City Alliance); or (c) on a general set of emerging issues, such as IEEE, WEF, Metrolab, or Data Collaboratives Research Network. While incorporating human rights and ethics into business strategies may be costly in the short run, over the long term, Paul Barrett, deputy director of New York University’s Center for Business and Human Rights, argues that “companies will benefit financially from operating humane, efficient supply chains and employing motivated workers proud of their jobs.”
#
#
#
# Ultimately, organizations that discard ethics may find themselves on the wrong side of history.
#
# Four short links: 22 April 2020
# ===============================
#
# Top N Summary
# -------------
# They would make all these unreasonable requests, give us bad data, stuff like that. So all my staff could come by my office when they were mad at their users and punch the clown to feel better. I had two doors in my office, and one time some guy I’d never seen before in my life walked into my office without knocking, punched the clown, and walked out the other door. Never saw him again.NetLogo — a multi-agent programmable modeling environment. For simulations/modeling.Things I Wished More Developers Knew About Databases (Jaana B. Dogan) — really good points, hard won from experience.
#
# Mean Scored Summary
# -------------------
# They would make all these unreasonable requests, give us bad data, stuff like that. I had two doors in my office, and one time some guy I’d never seen before in my life walked into my office without knocking, punched the clown, and walked out the other door. For simulations/modeling.Things I Wished More Developers Knew About Databases (Jaana B. Dogan) — really good points, hard won from experience.
#
# Four short links: 21 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# It’s Time to Learn (Scott Berkun) — a strong response to Marc Andreessen’s It’s Time to Build. Desert Island Devops — a single-day virtual event, to be livestreamed on twitch.tv/oncallmemaybe on April 30th, 2020. All presentations will take place in the world of Animal Crossing: New Horizons. MSFT’s Machine Learning-Powered Bug Sorting — Since 2001 Microsoft has collected 13 million work items and bugs. We used that data to develop a process and machine learning model that correctly distinguishes between security and non-security bugs 99 percent of the time and accurately identifies the critical, high priority security bugs, 97 percent of the time.
#
# Mean Scored Summary
# -------------------
# MSFT’s Machine Learning-Powered Bug Sorting — Since 2001 Microsoft has collected 13 million work items and bugs. We used that data to develop a process and machine learning model that correctly distinguishes between security and non-security bugs 99 percent of the time and accurately identifies the critical, high priority security bugs, 97 percent of the time.
#
# Four short links: 20 April 2020
# ===============================
#
# Top N Summary
# -------------
# […] allows efficient collaboration on data editing. Mainframes Are Having a Moment (IEEE Spectrum) — Although many college and university computer science departments have cut back or dropped mainframe programming curriculum to focus on more modern languages and technologies, faculty and staff at others report an uptick in interest in Cobol and related classes. The increase began well before pandemic-related layoffs inundated state unemployment agency computer systems, causing government officials to put out the call for programmers who know Cobol to step in and help. swimOS — a complete, self-contained distributed software platform for building stateful, massively real-time streaming applications. swimOS implements a distributed microkernel, called the Swim Kernel, that is persistent without a database, reactive without a message broker, autonomous without a job manager, and which executes general purpose stateful applications without a separate app server.
#
# Mean Scored Summary
# -------------------
# Mainframes Are Having a Moment (IEEE Spectrum) — Although many college and university computer science departments have cut back or dropped mainframe programming curriculum to focus on more modern languages and technologies, faculty and staff at others report an uptick in interest in Cobol and related classes. The increase began well before pandemic-related layoffs inundated state unemployment agency computer systems, causing government officials to put out the call for programmers who know Cobol to step in and help.
#
# Four short links: 17 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# Nebula —open source distributed, scalable, lightning-fast graph database. COBOL Programming Course — from the Open Mainframe Project. Serverless Handbook — a resource teaching frontend engineers everything they need to know to dive into backend. Novel Annealing Processor Is the Best Ever at Solving Combinatorial Optimization Problems (IEEE Spectrum) — Dubbed STATICA (Stochastic Cellular Automata Annealer Architecture), the processor is designed to take on challenges such as portfolio, logistic, and traffic flow optimization when they are expressed in the form of Ising models.
#
# Mean Scored Summary
# -------------------
# Novel Annealing Processor Is the Best Ever at Solving Combinatorial Optimization Problems (IEEE Spectrum) — Dubbed STATICA (Stochastic Cellular Automata Annealer Architecture), the processor is designed to take on challenges such as portfolio, logistic, and traffic flow optimization when they are expressed in the form of Ising models.
#
# Four short links: 16 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# Kanboard — free and open source Trello-like Kanban boards. Remote Work Playbook — really useful advice on the actual mechanics of working remotely, not just which tools to use but how to use them. If your answer to both questions is yes, write documentation for the thing and store in a common place where your team can access. avatarify — deep fake technology used to give you avatars of your choice for use in Zoom and Skype. pstress — Database concurrency and crash recovery testing tool.
#
# Mean Scored Summary
# -------------------
# Remote Work Playbook — really useful advice on the actual mechanics of working remotely, not just which tools to use but how to use them. avatarify — deep fake technology used to give you avatars of your choice for use in Zoom and Skype.
#
# Four short links: 15 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# Coding vs Programming (John Gruber) — I’d noticed this linguistic change too. See also Engineering vs Programming vs Computer Science. :D). Both are currently about 50 lines of code each. It’s like doping for e-sports.
#
# Mean Scored Summary
# -------------------
# Both are currently about 50 lines of code each. It’s like doping for e-sports.
#
# Four short links: 14 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# The Science of Happiness — free enrolment in Berkeley’s MOOC to teach positive psychology. Learn science-based principles and practices for a happy, meaningful life. The New Business of AI (A16Z) — many AI companies have: Lower gross margins due to heavy cloud infrastructure usage and ongoing human support; Scaling challenges due to the thorny problem of edge cases; Weaker defensive moats due to the commoditization of AI models and challenges with data network effects. Group Chat: The Best Way to Totally Stress Out Your Team — Group chat is like being in an all-day meeting, with random participants, and no agenda. Human Standards Project — p2p-shared international and device manufacturer standards to assist diy ventilator and masks teams.
#
# Mean Scored Summary
# -------------------
# The New Business of AI (A16Z) — many AI companies have: Lower gross margins due to heavy cloud infrastructure usage and ongoing human support; Scaling challenges due to the thorny problem of edge cases; Weaker defensive moats due to the commoditization of AI models and challenges with data network effects.
#
# Radar trends to watch: April 2020
# =================================
#
# Top N Summary
# -------------
# That’s a trend we expect to continue through April and probably beyond. So let’s start with Coronavirus news, and hope that we have something different for next month. Coronavirus
#
#
#
# The Coronavirus pandemic is forcing reconsideration of how private data is used. Maciej Ceglowski’s post “We need A Massive Surveillance Program” is important, particularly since Maciej has a long history as a privacy advocate. At the same time, many other privacy advocates are saying, “Be careful what you give up, because you won’t get it back,” including Edward Snowden.A number of organizations are using blockchains as a way of sharing coronavirus data.
#
# Mean Scored Summary
# -------------------
# That’s a trend we expect to continue through April and probably beyond. So let’s start with Coronavirus news, and hope that we have something different for next month. Coronavirus
#
#
#
# The Coronavirus pandemic is forcing reconsideration of how private data is used. Maciej Ceglowski’s post “We need A Massive Surveillance Program” is important, particularly since Maciej has a long history as a privacy advocate. At the same time, many other privacy advocates are saying, “Be careful what you give up, because you won’t get it back,” including Edward Snowden.A number of organizations are using blockchains as a way of sharing coronavirus data.
#
# Four short links: 13 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# Introduction to COBOL — a 1999 web site (!) IBM will offer free (presumably more modern) training. zoombot — a highly advanced AI to handle Zoom calls. storybook.js — open source toolkit and sandbox to build UI components in isolation so you can develop hard-to-reach states and edge cases. tic-80 — a fantasy computer for making, playing and sharing tiny games.
#
# Mean Scored Summary
# -------------------
# storybook.js — open source toolkit and sandbox to build UI components in isolation so you can develop hard-to-reach states and edge cases.
#
# Four short links: 10 April 2020
# ===============================
#
# Top N Summary
# -------------
#
# FairMOT — one-shot multi-object tracking that remarkably outperforms the state-of-the-arts on the MOT challenge datasets at 30 FPS. Compiler Explorer — an interactive tool that lets you type code in one window and see the results of its compilation in another window. Using the site should be pretty self-explanatory: by default the left hand pane is the source window and the right hand has the assembly output. (via Tim Westbrook)
# MOOM — move and zoom windows on a Mac. (via Ben Gracewood and @kylehqcom)
#
# Mean Scored Summary
# -------------------
#
# FairMOT — one-shot multi-object tracking that remarkably outperforms the state-of-the-arts on the MOT challenge datasets at 30 FPS. Compiler Explorer — an interactive tool that lets you type code in one window and see the results of its compilation in another window. Using the site should be pretty self-explanatory: by default the left hand pane is the source window and the right hand has the assembly output.
#
# Four short links: 9 April 2020
# ==============================
#
# Top N Summary
# -------------
#
# The Fuzzy Edges of Character Encoding — the history, politics, and computational basics of text-based character encoding and digital representations of text, from Morse Code to ASCII to Unicode (and emoji), as well as alternative text encoding schemes. (via Everest Pipkin)
# AutoHotkey — an automation scripting language for Windows. The Electronic Nose and its Applications: A Survey — very good summary of tech, limitations, and applications of “electronic noses” aka multiple chemical sensors plus some machine learning/statistics. falsisign — Make it look like a PDF has been hand signed and scanned.
#
# Mean Scored Summary
# -------------------
#
# The Fuzzy Edges of Character Encoding — the history, politics, and computational basics of text-based character encoding and digital representations of text, from Morse Code to ASCII to Unicode (and emoji), as well as alternative text encoding schemes. The Electronic Nose and its Applications: A Survey — very good summary of tech, limitations, and applications of “electronic noses” aka multiple chemical sensors plus some machine learning/statistics.
#
# Four short links: 8 April 2020
# ==============================
#
# Top N Summary
# -------------
#
# System Design for Advanced Beginners — a friendly explanation of the what and why of systems, with acknowledgement of the real world like There are many tools out there, each with different strengths and weaknesses, and many ways to build a technology company. The real, honest reasons that we will make many of our technological choices will be “we chose X because Sara knows a lot about X” and “we chose Y on the spur of the moment when it didn’t seem like a big decision and we never found the time to re-evaluate.”
# Lozya — Teleconferencing with an RPG map. Walk around, talk to folks, have private conversations by huddling in a corner, or drop in on other conversations. It lets you write Lua scripts that hook into operating system functionality, allowing you to interact with the keyboard/mouse, windows, displays, filesystem, and much more. (via CSAIL’s Missing Semester Potpourri)
# The Hitchiker’s Guide to Logical Verification (PDF) — book for a course, using Microsoft Research’s Lean theorem prover.
#
# Mean Scored Summary
# -------------------
# The real, honest reasons that we will make many of our technological choices will be “we chose X because Sara knows a lot about X” and “we chose Y on the spur of the moment when it didn’t seem like a big decision and we never found the time to re-evaluate.”
# Lozya — Teleconferencing with an RPG map. It lets you write Lua scripts that hook into operating system functionality, allowing you to interact with the keyboard/mouse, windows, displays, filesystem, and much more. (via CSAIL’s Missing Semester Potpourri)
# The Hitchiker’s Guide to Logical Verification (PDF) — book for a course, using Microsoft Research’s Lean theorem prover.
#
# Four short links: 7 April 2020
# ==============================
#
# Top N Summary
# -------------
#
# locust — open source load testing tool: define user behaviour with Python code, and swarm your system with millions of simultaneous users. (via @nzigel)
# Background Matting — a method for creating a matte – the per-pixel foreground color and alpha – of a person by taking photos or videos in an everyday setting with a handheld camera. Most existing matting methods require a green screen background or a manually created trimap to produce a good matte. Learning to See Through Obstructions — a learning-based approach for removing unwanted obstructions, such as window reflections, fence occlusions or raindrops, from a short sequence of images captured by a moving camera. Covid-19 Primer — algorithmic summaries of Covid-19 research, updated every 24h.
#
# Mean Scored Summary
# -------------------
#
# locust — open source load testing tool: define user behaviour with Python code, and swarm your system with millions of simultaneous users. (via @nzigel)
# Background Matting — a method for creating a matte – the per-pixel foreground color and alpha – of a person by taking photos or videos in an everyday setting with a handheld camera. Most existing matting methods require a green screen background or a manually created trimap to produce a good matte.
#
# Governance and Discovery
# ========================
#
# Top N Summary
# -------------
# Data Governance sounds like a candidate for the most boring topic in technology: something dreamed up by middle-managers to add friction to data scientists’ lives. How does this look in practice? It’s really about metadata management, and that’s at the heart of data governance. It also doesn’t track data lineage (at least, not yet), although users can add metadata about how data is modified and remixed. So it’s not a complete solution—but it’s a step toward a solution.
#
# Mean Scored Summary
# -------------------
# Data Governance sounds like a candidate for the most boring topic in technology: something dreamed up by middle-managers to add friction to data scientists’ lives. They were experimenting with machine learning and artificial intelligence; they were building models that could easily go astray (with embarrassing repercussions) if they were based on data that was out of date or erroneous. What did the data scientists need? What did the compliance experts need? The problem boils down to managing metadata—the data about the data, the data that describes the data. Data that hasn’t been used for a few years probably hasn’t been used for a good reason. How does this look in practice? The open source project Amundsen was started to enable data discovery at Lyft. Although Amundsen was built to solve a supposedly different problem, it has also become a tool for data governance. It’s really about metadata management, and that’s at the heart of data governance. It won’t prevent someone from accessing data they shouldn’t; it just lets you document what happened after the fact. It also doesn’t track data lineage (at least, not yet), although users can add metadata about how data is modified and remixed. So it’s not a complete solution—but it’s a step toward a solution. Going beyond metadata management, many data governance platforms are designed to enforce data access policies.
#
# Four short links: 6 April 2020
# ==============================
#
# Top N Summary
# -------------
#
# Rufus — Create bootable USB drives the easy way. Improving Audio Quality in Duo with WaveNetEQ — Google filling in missing packets in voice calls using deep learning. CRN++ — language for programming deterministic (mass-action) chemical kinetics to perform computation. Crafting Crafting Interpreters — story behind the writing of the Crafting Interpreters book.
#
# Mean Scored Summary
# -------------------
# Improving Audio Quality in Duo with WaveNetEQ — Google filling in missing packets in voice calls using deep learning.
#
# Four short links: 3 April 2020
# ==============================
#
# Top N Summary
# -------------
#
# The Zero Trust Learning Curve (Palo Alto Networks) — don’t learn with the Crown Jewels. The trouble with starting with the most sensitive protect surfaces is that they’re often too fragile and many people don’t know how they work. Software Engineering Advice from Building Large-Scale Distributed Systems (Jeff Dean) — slide deck from a Stanford talk he gave. gorkiy — decompilation of Russia’s COVID-19 person tracker. Open Source, Experimental, and Tiny Tools Roundup — tons of tools for games, graphics, sounds, live coding, zines, and more.
#
# Mean Scored Summary
# -------------------
#
# The Zero Trust Learning Curve (Palo Alto Networks) — don’t learn with the Crown Jewels. Software Engineering Advice from Building Large-Scale Distributed Systems (Jeff Dean) — slide deck from a Stanford talk he gave. Open Source, Experimental, and Tiny Tools Roundup — tons of tools for games, graphics, sounds, live coding, zines, and more.
#
# Four short links: 2 April 2020
# ==============================
#
# Top N Summary
# -------------
#
# Imperial College’s COVID19 Model — in github, in R, MIT-licensed. The bleeding edge code and advancements are done in a private repository. Readings on Time — I bumped on this idea while reading Alan Kay’s writing about making the difference between mutable and immutable data “moot” in the context of FP vs. OOP by bringing in the concept of managed time. It is a fertile area with a lot of open problems for research and bringing back the fruits of these labour as an interactive system will unlock new pathways in computing. Douyin Suspending Cantonese Livestreamers — you might dislike Facebook’s privacy settings but they don’t tell people they can’t speak their own language.
#
# Mean Scored Summary
# -------------------
# Readings on Time — I bumped on this idea while reading Alan Kay’s writing about making the difference between mutable and immutable data “moot” in the context of FP vs. OOP by bringing in the concept of managed time. It is a fertile area with a lot of open problems for research and bringing back the fruits of these labour as an interactive system will unlock new pathways in computing. Douyin Suspending Cantonese Livestreamers — you might dislike Facebook’s privacy settings but they don’t tell people they can’t speak their own language.
#
# Four short links: 1 April 2020
# ==============================
#
# Top N Summary
# -------------
# Replaying Traffic to Test Proprietary Systems — using Wiresham to replay traffic to test blackbox proprietary systems.Outlaw Innovations — This paper will explore how the often illegal activities of hackers (in the original usage of the term to refer to individuals who modify computer hardware and software) may produce valuable innovations. It will explore how these innovations, termed Outlaw Innovations, may be appropriated by firms and provide case studies where this has taken place. The paper will seek to locate this phenomenon in the existing innovation literature, and explore the implications for firm innovation processes.Testing TikTok Algorithm Theories — I’m fascinated by people reverse-engineering algorithms like this. I used to dream of lying in bed with a split keyboard and a headset, never needing to even get vertical. Now I’m in my 40s, I acknowledge that removing the only movement I get in my working life (walking to the desk and sitting) would probably a step in the wrong direction.
#
# Mean Scored Summary
# -------------------
# Replaying Traffic to Test Proprietary Systems — using Wiresham to replay traffic to test blackbox proprietary systems.Outlaw Innovations — This paper will explore how the often illegal activities of hackers (in the original usage of the term to refer to individuals who modify computer hardware and software) may produce valuable innovations. The paper will seek to locate this phenomenon in the existing innovation literature, and explore the implications for firm innovation processes.Testing TikTok Algorithm Theories — I’m fascinated by people reverse-engineering algorithms like this.
#
# Four short links: 31 March 2020
# ===============================
#
# Top N Summary
# -------------
#
# Medtronic Releases Ventilator Designs — not open source, as the license is a limited-time limited-purpose license that retains rights. I imagine some corporate lawyers have done some frantic Googling for open meditech licensing clauses. Toast UI Editor — extensible WYSIWYG Markdown editor. How to be Curious Instead of Contrarian — it’s about Coronavirus/Covid-19 but could apply equally well to any topic. 1) Care about the answer to a question; 2) Post a question and propose a research design that could answer it; 3) Use failures of your predictions to revise your mode; 4) Form meaningful prior beliefs with a thorough literature review; 5) Don’t form strong prior beliefs based on cherry-picked data; 6) Be specific and concrete about your theory; 7) Choose enough cases to actually test your theory; 8) Convey uncertainty with specificity not doublespeak.
#
# Mean Scored Summary
# -------------------
# 1) Care about the answer to a question; 2) Post a question and propose a research design that could answer it; 3) Use failures of your predictions to revise your mode; 4) Form meaningful prior beliefs with a thorough literature review; 5) Don’t form strong prior beliefs based on cherry-picked data; 6) Be specific and concrete about your theory; 7) Choose enough cases to actually test your theory; 8) Convey uncertainty with specificity not doublespeak.
# What you need to know about product management for AI
# =====================================================
#
# Top N Summary
# -------------
# Identifying “viable” machine learning problems
# Any product manager is part of the team that determines what product to build. It’s an intuition that you can learn through experience–and it’s why understanding your failures is at least as important as understanding your successes. If the needle doesn’t move, you will undermine your team. Customers want you to solve their problems; they don’t care what kind of neural network you’re using. Scope often needs to be reduced or quality sacrificed to align with other teams or priorities.
#
# Mean Scored Summary
# -------------------
# If you’re already a software product manager (PM), you have a head start on becoming a PM for artificial intelligence (AI) or machine learning (ML). A PM for AI needs to do everything a traditional PM does, but they also need an operational understanding of machine learning software development along with a realistic view of its capabilities and limitations. Why AI software development is different
# AI products are automated systems that collect and learn from data to make user-facing decisions. Pragmatically, machine learning is the part of AI that “works”: algorithms and techniques that you can implement now in real products. All you need to know for now is that machine learning uses statistical techniques to give computer systems the ability to “learn” by being trained on existing data. AI systems differ from traditional software in many ways, but the biggest difference is that machine learning shifts engineering from a deterministic process to a probabilistic one. In the best case scenario, the trained neural network accurately represents the underlying phenomenon of interest and produces the correct output even when presented with new input data the model didn’t see during training. For machine learning systems used in consumer internet companies, models are often continuously retrained many times a day using billions of entirely new input-output pairs. The same neural network code trained with seemingly similar datasets of input and output pairs can give entirely different results. Make changes to the training data, repeat the training process with the same code, and you’ll get different output predictions from your model. Predicting development time is hard enough for traditional software, but at least we can make some general guesses based on past experience. You frequently don’t know whether something is feasible until you do the experiment. Your team also needs to solve a cold start problem so you can recommend movies before the system begins collecting user feedback data (typically solved by using contextual topic-based or popularity-based recommendations), but once you gather explicit user ratings and video viewing data, you should be able to build a reasonable system. These issues may be unexpected for teams that aren’t familiar with developing machine learning systems trained on user-generated content. In each of these examples, the machine learning problem faced by the business was similar (recommend movies to users), but the required approach ended up being very different based on subtle differences in the data and product design. Job recommendations also include additional algorithmic and regulatory challenges related to diversity, bias, and fairness that are not encountered in movie recommendations. There are strategies for dealing with all of this uncertainty–starting with the proverb from the early days of Agile: “do the simplest thing that could possibly work.” You don’t always need to start with a complex neural network; a simple regression (or even simpler, an average) might be enough to get your project off the ground. In some cases, that simple model may be all you ever need. Organizational prerequisites for AI at scale
# Particularly at a company that’s new to AI, part of an AI product manager’s job is helping the organization build the culture it needs to succeed with AI. Because it’s so different from traditional software development, where the risks are more or less well-known and predictable, AI rewards people and companies that are willing to take intelligent risks, and that have (or can develop) an experimental culture. As Jeff Bezos has said, “If you only do things where you know the answer in advance, your company goes away.”
# No company wants to dry up and go away; and at least if you follow the media buzz, machine learning gives companies real competitive advantages in prediction, planning, sales, and almost every aspect of their business. Even simple machine learning projects can be difficult, and managing these projects in a real business is much harder than most people realize; that’s why VentureBeat claims 87% of machine learning products never make it into production, and Harvard Business Review says that “The first wave of corporate AI is bound to fail.” Machine learning is not fairy dust you can sprinkle on your existing product. VentureBeat discusses two reasons for failure: management that believes you can solve problems by throwing money at them (whether that means hiring more, or better, developers), and data that is locked away into silos, where the people building your ML applications can’t get it. It turns out that type of data infrastructure is also the foundation needed for building AI products. The ability to make decisions based on data analytics is a prerequisite for an “experimental culture.” This was the path taken by companies like Google, Facebook, and LinkedIn, which were driven by analytics from the beginning. They’ve built the infrastructure needed to collect, manage, and analyze their data, and deploy AI products that can automatically make user-facing decisions in real time. Just as AI product managers need to help build a culture in which they can succeed, they need to help define and build the infrastructure that will allow an organization to walk, and then to run. Although machine learning projects differ in subtle ways from traditional projects, they tend to require similar infrastructure, similar data collection processes, and similar developer habits. The prospect of taking on a costly data infrastructure project is daunting. According to Lukas Biewald, founder of Figure Eight and Weights & Biases: “Big companies should avoid building their own machine learning infrastructure. Start with a simple project, build your infrastructure, learn how to use your data effectively, build relationships within the organization, then make the leap. Identifying “viable” machine learning problems
# Any product manager is part of the team that determines what product to build. An AI pilot project, even one that sounds simple, probably won’t be something you can demo quickly. A demo, or even a first release, can be based on heuristics or simple models (linear regression, or even averages). It’s an intuition that you can learn through experience–and it’s why understanding your failures is at least as important as understanding your successes. Build a prototype they can try with real data. It isn’t; you’ve got to go into much more detail about who your customers are, how they want to organize their pictures, what kinds of pictures they’re likely to have, how they want to search, and more. Otherwise, you will burn money paying external services for labeled data, and that up-front cost–before you can do your first demo–can easily be the most expensive part of the project. Without large amounts of good raw and labeled training data, solving most AI problems is not possible. When you’re planning a product, it’s important to have a gut feel for what error rates are achievable and what aren’t, and what error rates are acceptable for your application. Work on things that matter to your business
# The most important advice we can give is to make sure you work on AI products that matter to the business. It’s entirely too easy to define a problem, spend three to six months solving it, and then find out the solution works, but nobody cares; it doesn’t make a difference to the business. One of a product manager’s most important jobs is ensuring that the team is solving a problem that’s worth solving. You will probably have more ideas than you can possibly use–so how do you prioritize the list of machine learning projects? Shipping any machine learning system requires a huge mountain of organizational and data engineering effort, so the ultimate payoff needs to match that investment. You shouldn’t over-promise, and you shouldn’t under-deliver. If the needle doesn’t move, you will undermine your team. Without this data familiarity, you will have trouble spotting ethical problems that arise from biased or insufficient data. Even if a product is feasible, that’s not the same as product-market fit. Customers want you to solve their problems; they don’t care what kind of neural network you’re using. You may discover that you don’t need AI at all, and that’s just fine. Build a direct connection between your machine learning application and something the company values. A strategic objective for the company was to become the professional profile of record and have complete and up-to-date resume data in the LinkedIn profiles for all professionals. People You May Know (PYMK) was a successful example of this type of strategic alignment from LinkedIn’s data team. Scope often needs to be reduced or quality sacrificed to align with other teams or priorities. In larger companies, it’s best to start by focusing on business units that are eager to work with you and where your help is needed. Ideally, that also aligns with the larger set of company priorities. Resources
# Where do you go from here as a product manager new to the world of AI?
#
# The unreasonable importance of data preparation
# ===============================================
#
# Top N Summary
# -------------
# You may picture data scientists building machine learning models all day, but the common trope that they spend 80% of their time on data preparation is closer to the truth. Data can be low-quality if:
#
# It doesn’t fit your question or its collection wasn’t carefully considered;
# ...
# Remembering Freeman Dyson
# =========================
#
# Top N Summary
# -------------
# Freeman Dyson died last week at the age of 96 after injuring himself in a fall in the cafeteria at the Institute of Advanced Studies in Princeton, where he had continued to work right up to the end. Jonson and Shakespeare were both successful playwrights. Jonson became famous in his own right as a poet and scholar, and at the end of his life he was honored with burial in Westminster Abbey. He was not interested in publishing pretty papers. Then he began to calculate numbers, using his diagrams as a guide.
#
# Mean Scored Summary
# -------------------
# Freeman Dyson died last week at the age of 96 after injuring himself in a fall in the cafeteria at the Institute of Advanced Studies in Princeton, where he had continued to work right up to the end. Perhaps the most famous example is the paper he wrote in 1949 at the age of 25 making the case that the visualizations of Richard Feynman were mathematically equivalent to the calculations of the more conventional physicists Julian Schwinger and Shin’ichirō Tomonaga, a paper that led to Feynman, Schwinger, and Tomonaga receiving the 1965 Nobel Prize in Physics for the theory of quantum electrodynamics. “I visited him recently,” Danny wrote, “and we got into a conversation about self-organizing systems. We see the world through the lens of our received ideas, but for most of us, words predominate. Freeman was good at that, too. It is so good that over the years, I’ve managed to get only about halfway through the book, since each time I pick it up, I first re-read Freeman’s foreword. Jonson and Shakespeare were both successful playwrights. Jonson was learned and scholarly, Shakespeare was slapdash and a genius. Shakespeare was nine years older, already filling the London stage with masterpieces before Jonson began to write. The play was a resounding success and launched Jonson’s professional career. Jonson was then aged 25, Shakespeare 34. Jonson became famous in his own right as a poet and scholar, and at the end of his life he was honored with burial in Westminster Abbey. He was not interested in publishing pretty papers. Then he began to calculate numbers, using his diagrams as a guide. With astonishing speed he was able to calculate physical quantities that could be compared directly with experiment.
#
# Four short links: 4 March 2020
# ==============================
#
# Top N Summary
# -------------
#
# tota11y — an [open source] accessibility visualization toolkit from Khan Academy. (1) Proficiency takes less time; (2) Troubleshooting takes less time; (3) More alternative solutions. Cybersecurity Law, Policy, and Infrastructure — This is the full text of my interdisciplinary “eCasebook” designed from the ground up to reflect the intertwined nature of the legal and policy questions associated with cybersecurity. My aim is to help the reader understand the nature and functions of the various government and private-sector actors associated with cybersecurity in the United States, the policy goals they pursue, the issues and challenges they face, and the legal environment in which all of this takes place. It is designed to be accessible for beginners from any disciplinary background, yet useful to experienced audiences, too.
#
# Mean Scored Summary
# -------------------
#
# tota11y — an [open source] accessibility visualization toolkit from Khan Academy. Cybersecurity Law, Policy, and Infrastructure — This is the full text of my interdisciplinary “eCasebook” designed from the ground up to reflect the intertwined nature of the legal and policy questions associated with cybersecurity. My aim is to help the reader understand the nature and functions of the various government and private-sector actors associated with cybersecurity in the United States, the policy goals they pursue, the issues and challenges they face, and the legal environment in which all of this takes place.
#
# Four short links: 3 March 2020
# ==============================
#
# Top N Summary
# -------------
#
# Facebook’s Incomplete Download Your Data (Privacy International) — Despite Facebook claim, “Download Your Information” doesn’t provide users with a list of all advertisers who uploaded a list with their personal data. Recently announced Off-Facebook feature comes with similar issues, giving little insight into how advertisers collect your personal data and how to prevent such data collection. (via Bruce Schneier)
# Proxy Verifier — an HTTP replay tool designed to verify the behavior of HTTP proxies. It builds a verifier-client binary and a verifier-server binary which each read a set of YAML or JSON files that specify the HTTP traffic for the two to exchange. Stripe’s Covid-19 Company Plan — great time to be a remote working consultant, although I’m sure nobody with entrenched on-site culture wants to hear what’s involved to enable long-term sustainable useful remote work (i.e., change your crappy practices that favor in-office staff, move comms to a slower channel for people who aren’t online all at once because they’re visiting the doctor, etc.).
#
# Mean Scored Summary
# -------------------
#
# Facebook’s Incomplete Download Your Data (Privacy International) — Despite Facebook claim, “Download Your Information” doesn’t provide users with a list of all advertisers who uploaded a list with their personal data. Recently announced Off-Facebook feature comes with similar issues, giving little insight into how advertisers collect your personal data and how to prevent such data collection. Stripe’s Covid-19 Company Plan — great time to be a remote working consultant, although I’m sure nobody with entrenched on-site culture wants to hear what’s involved to enable long-term sustainable useful remote work (i.e., change your crappy practices that favor in-office staff, move comms to a slower channel for people who aren’t online all at once because they’re visiting the doctor, etc.).
#
# The death of Agile?
# ===================
#
# Top N Summary
# -------------
# When a project is going off track because some requirement wasn’t understood properly, you need to fix that as soon as possible—not after a year-long development process. It’s reasonable to have something to demo in two weeks (or whatever interval you choose). There’s plenty of security risks for business executives, sysadmins, DBAs, developers, etc., to be wary of. We also recently conducted a survey looking at the state of data quality. Data scientists and analysts, data engineers, and the people who manage them comprise 40% of the audience; developers and their managers, about 22%.
#
# Mean Scored Summary
# -------------------
# The problem with the claim that Agile is “dead” is that, as Eben Hewitt said to me in a conversation, “no movement has succeeded until it has become a parody of itself.” This is a brilliant point that applies perfectly to Agile. More often than not, the result of fetishization is—nothing at all. I won’t be among the mourners. This is important. Agile is not, and never was, about getting developers to write software faster. If you were involved with professional programming in the 80s and 90s, you may remember how radical it was (and, in many shops, still is) to put software developers in touch with users and customers. They might tell the customer that some feature they want is impossible! You can’t create a “product owner” and say that’s their job—especially since, more often than not, “product owners” don’t have meaningful contact with customers themselves. We were very lucky not to be sued.) When a project is going off track because some requirement wasn’t understood properly, you need to fix that as soon as possible—not after a year-long development process. If Agile’s first principle is frequent interaction with the customer, its second (and a close corollary) is frequent mid-course corrections. And that’s a big clue about what the word “Agile” means. It’s about correcting small mistakes before they become big ones, before they’re amplified by a multi-year, multi-million dollar budget. Large projects are necessary, but they have a momentum that tends to drive them off course. ), and will remain true after Agile. Progress in developing software tends to be slow, incremental, and fairly well understood. It’s reasonable to have something to demo in two weeks (or whatever interval you choose). (Perhaps the appropriate yardstick for AI projects is the experiment itself, not the code committed to git.) But again: value interactions over documentation. Why, when things change do they remain the same? In any organization, answering those questions will say a lot about how Agile becomes self-parody. Also: infrastructure and operations is trending up, while DevOps is trending down. Growth is still strong for such a large topic, but usage slowed in 2018 (+13%) and cooled significantly in 2019, growing by just 7%. There’s plenty of security risks for business executives, sysadmins, DBAs, developers, etc., to be wary of. We also recently conducted a survey looking at the state of data quality. Data scientists and analysts, data engineers, and the people who manage them comprise 40% of the audience; developers and their managers, about 22%. Data quality might get worse before it gets better. Just 20% of organizations publish data provenance and data lineage. Adopting AI can help data quality.
#
# Four short links: 2 March 2020
# ==============================
#
# Top N Summary
# -------------
#
# Gandalf: An Intelligent, End-to-end Analytics Service for Safe Deployment in Cloud-scale Infrastructure — a paper on Azure’s rollout-monitoring software that analyzes more than 20TB of data per day: 270K platform events on average (770K peak), 600 million API calls, with data on over 2,000 different fault types. (That’s from Morning Paper, which has a readable summary of the paper)
# Quarantine Cooking (New Yorker) — we tend to think of the Chinese internet as just a battleground—activists and censors locked in an endless conflict. Quarantine cooking captures their boredom, their loneliness, their creativity, and their desire for connection amid anxiety and panic. Draft of the fast.ai Book — These draft notebooks cover an introduction to deep learning, fast.ai, and PyTorch. p5.js 1.0 — the celebratory Medium post summarizes what’s gone into the release, but it’s everything from tooling to I18N, libraries, and docs.
#
# Mean Scored Summary
# -------------------
#
# Gandalf: An Intelligent, End-to-end Analytics Service for Safe Deployment in Cloud-scale Infrastructure — a paper on Azure’s rollout-monitoring software that analyzes more than 20TB of data per day: 270K platform events on average (770K peak), 600 million API calls, with data on over 2,000 different fault types.
#
# Four short links: 28 February 2020
# ==================================
#
# Top N Summary
# -------------
#
# Mapping Coronavirus Responsibly (ESRI) — Let’s take a look at how maps can help shape the narrative and, as concern (fear?) Don’t Use Low-fidelity Prototypes to Test Desirability — One of my favorite techniques for testing desirability of brand new products is the mock screencast: after creating realistic-looking pages using Web Inspector or your favorite design tool, you can then record your screen while “navigating” through the site by tabbing through mockups and narrating the value proposition. Data Center Power (Jess Frazelle) — fascinating deep dive into power concerns in data centers, talking about what the “hyperscalers” (MSFT, GOOG, etc.) Wildcard: Spreadsheet-driven Customization of Web Applications — In this paper, we present spreadsheet-driven customization, a technique that enables end users to customize software without doing any traditional programming. When the user manipulates the spreadsheet, the underlying data is modified and the changes are propagated to the UI, and vice versa.
#
# Mean Scored Summary
# -------------------
# Don’t Use Low-fidelity Prototypes to Test Desirability — One of my favorite techniques for testing desirability of brand new products is the mock screencast: after creating realistic-looking pages using Web Inspector or your favorite design tool, you can then record your screen while “navigating” through the site by tabbing through mockups and narrating the value proposition. Data Center Power (Jess Frazelle) — fascinating deep dive into power concerns in data centers, talking about what the “hyperscalers” (MSFT, GOOG, etc.)
#
# Four short links: 27 February 2020
# ==================================
#
# Top N Summary
# -------------
#
# BellTopo Sans — typeface and free font inspired by the sans serif in old maps. (via Flowing Data)
# YC’s Guide to Raising Series A — This guide is a distillation of everything we know about successfully raising an A. It includes insights learned from watching hundreds of founders succeed in raising, and in watching dozens fail. Information Disorders (Renee DiResta) — survey proposed regulatory approaches to addressing the range of challenges in the information environment, looking at regulatory proposals around ads, antitrust, and privacy, and how these proposed laws impact the privacy-security-free expression balance. (via Fast.ai)
# Issues — Issues come in many flavors, for example feature requests, bug reports, customer complaints, security alerts, team retrospectives, etc.
#
# Mean Scored Summary
# -------------------
# Information Disorders (Renee DiResta) — survey proposed regulatory approaches to addressing the range of challenges in the information environment, looking at regulatory proposals around ads, antitrust, and privacy, and how these proposed laws impact the privacy-security-free expression balance. (via Fast.ai)
# Issues — Issues come in many flavors, for example feature requests, bug reports, customer complaints, security alerts, team retrospectives, etc.
#
# Intellectual control
# ====================
#
# Top N Summary
# -------------
# This is a keynote highlight from the O’Reilly Software Architecture Conference in New York 2020. Watch the full version of this keynote on the O’Reilly online learning platform. You can also see other highlights from the event.
#
# Mean Scored Summary
# -------------------
# This is a keynote highlight from the O’Reilly Software Architecture Conference in New York 2020.
#
# Highlights from the O’Reilly Software Architecture Conference in New York 2020
# ==============================================================================
#
# Top N Summary
# -------------
# People from across the software architecture world came together in New York for the O’Reilly Software Architecture Conference. Watch “Where do great architectures come from?“
#
# Architecture.Next: Invalidating old axioms
# Mark Richards challenges the tried-and-true axioms in software architecture and shows you how to manage the changing state of the space. Watch “Architecture.Next: Invalidating old axioms“
#
# Sometimes I draw
# Kai Holnes walks you through the nebulous world of creative outlets and why maybe, just maybe, that journey is worth it. Watch “Sometimes I draw“
#
# Intellectual control
# George Fairbanks considers whether today’s complex software has eclipsed our intellectual control. Watch “Intellectual control“
#
# From the trenches: Rachel Laycock
# Neal Ford interviews Rachel Laycock about her career path and her work as an architect.
#
# Mean Scored Summary
# -------------------
# Watch “Where do great architectures come from?“
#
# Architecture.Next: Invalidating old axioms
# Mark Richards challenges the tried-and-true axioms in software architecture and shows you how to manage the changing state of the space. Watch “Architecture.Next: Invalidating old axioms“
#
# Sometimes I draw
# Kai Holnes walks you through the nebulous world of creative outlets and why maybe, just maybe, that journey is worth it. Watch “Sometimes I draw“
#
# Intellectual control
# George Fairbanks considers whether today’s complex software has eclipsed our intellectual control.

# %% [markdown]
# ## Visualizing document summarization results with HTML output

# %%
import os
from IPython.display import IFrame
from IPython.core.display import display

HTML_TEMPLATE = """<html>
    <head>
        <title>{0}</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>{1}</body>
</html>"""

for post in blog_data:
   
    # Uses previously defined summarize function.
    post.update(summarize(post['content']))

    # You could also store a version of the full post with key sentences marked up
    # for analysis with simple string replacement...

    for summary_type in ['top_n_summary', 'mean_scored_summary']:
        post[summary_type + '_marked_up'] = '<p>{0}</p>'.format(post['content'])
        
        for s in post[summary_type]:
            post[summary_type + '_marked_up'] = \
            post[summary_type + '_marked_up'].replace(s, '<strong>{0}</strong>'.format(s))

        filename = post['title'].replace("?", "") + '.summary.' + summary_type + '.html'
        
        f = open(os.path.join(filename), 'wb')
        html = HTML_TEMPLATE.format(post['title'] + ' Summary', post[summary_type + '_marked_up'])    
        f.write(html.encode('utf-8'))
        f.close()

        print("Data written to", f.name)

# Display any of these files with an inline frame. This displays the
# last file processed by using the last value of f.name...
print()
print("Displaying {0}:".format(f.name))
display(IFrame('files/{0}'.format(f.name), '100%', '600px'))
# Out:
# Data written to Four short links: 30 April 2020.summary.top_n_summary.html
# Data written to Four short links: 30 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 29 April 2020.summary.top_n_summary.html
# Data written to Four short links: 29 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 28 April 2020.summary.top_n_summary.html
# Data written to Four short links: 28 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 27 April 2020.summary.top_n_summary.html
# Data written to Four short links: 27 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 24 April 2020.summary.top_n_summary.html
# Data written to Four short links: 24 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 23 April 2020.summary.top_n_summary.html
# Data written to Four short links: 23 April 2020.summary.mean_scored_summary.html
# Data written to How data privacy leader Apple found itself in a data ethics catastrophe.summary.top_n_summary.html
# Data written to How data privacy leader Apple found itself in a data ethics catastrophe.summary.mean_scored_summary.html
# Data written to Four short links: 22 April 2020.summary.top_n_summary.html
# Data written to Four short links: 22 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 21 April 2020.summary.top_n_summary.html
# Data written to Four short links: 21 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 20 April 2020.summary.top_n_summary.html
# Data written to Four short links: 20 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 17 April 2020.summary.top_n_summary.html
# Data written to Four short links: 17 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 16 April 2020.summary.top_n_summary.html
# Data written to Four short links: 16 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 15 April 2020.summary.top_n_summary.html
# Data written to Four short links: 15 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 14 April 2020.summary.top_n_summary.html
# Data written to Four short links: 14 April 2020.summary.mean_scored_summary.html
# Data written to Radar trends to watch: April 2020.summary.top_n_summary.html
# Data written to Radar trends to watch: April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 13 April 2020.summary.top_n_summary.html
# Data written to Four short links: 13 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 10 April 2020.summary.top_n_summary.html
# Data written to Four short links: 10 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 9 April 2020.summary.top_n_summary.html
# Data written to Four short links: 9 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 8 April 2020.summary.top_n_summary.html
# Data written to Four short links: 8 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 7 April 2020.summary.top_n_summary.html
# Data written to Four short links: 7 April 2020.summary.mean_scored_summary.html
# Data written to Governance and Discovery.summary.top_n_summary.html
# Data written to Governance and Discovery.summary.mean_scored_summary.html
# Data written to Four short links: 6 April 2020.summary.top_n_summary.html
# Data written to Four short links: 6 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 3 April 2020.summary.top_n_summary.html
# Data written to Four short links: 3 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 2 April 2020.summary.top_n_summary.html
# Data written to Four short links: 2 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 1 April 2020.summary.top_n_summary.html
# Data written to Four short links: 1 April 2020.summary.mean_scored_summary.html
# Data written to Four short links: 31 March 2020.summary.top_n_summary.html
# Data written to Four short links: 31 March 2020.summary.mean_scored_summary.html
# Data written to What you need to know about product management for AI.summary.top_n_summary.html
# Data written to What you need to know about product management for AI.summary.mean_scored_summary.html
# Data written to The unreasonable importance of data preparation.summary.top_n_summary.html
# Data written to The unreasonable importance of data preparation.summary.mean_scored_summary.html
# Data written to Four short links: 24 March 2020.summary.top_n_summary.html
# Data written to Four short links: 24 March 2020.summary.mean_scored_summary.html
# Data written to 3 ways to confront modern business challenges.summary.top_n_summary.html
# Data written to 3 ways to confront modern business challenges.summary.mean_scored_summary.html
# Data written to An enterprise vision is your company’s North Star.summary.top_n_summary.html
# Data written to An enterprise vision is your company’s North Star.summary.mean_scored_summary.html
# Data written to Leaders need to mobilize change-ready workforces.summary.top_n_summary.html
# Data written to Leaders need to mobilize change-ready workforces.summary.mean_scored_summary.html
# Data written to Great leaders inspire innovation and creativity from within their workforces.summary.top_n_summary.html
# Data written to Great leaders inspire innovation and creativity from within their workforces.summary.mean_scored_summary.html
# Data written to Strong leaders forge an intersection of knowledge and experience.summary.top_n_summary.html
# Data written to Strong leaders forge an intersection of knowledge and experience.summary.mean_scored_summary.html
# Data written to Four short links: 23 March 2020.summary.top_n_summary.html
# Data written to Four short links: 23 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 20 March 2020.summary.top_n_summary.html
# Data written to Four short links: 20 March 2020.summary.mean_scored_summary.html
# Data written to 6 trends framing the state of AI and ML.summary.top_n_summary.html
# Data written to 6 trends framing the state of AI and ML.summary.mean_scored_summary.html
# Data written to Four short links: 19 March 2020.summary.top_n_summary.html
# Data written to Four short links: 19 March 2020.summary.mean_scored_summary.html
# Data written to It’s an unprecedented crisis: 8 things to do right now.summary.top_n_summary.html
# Data written to It’s an unprecedented crisis: 8 things to do right now.summary.mean_scored_summary.html
# Data written to AI adoption in the enterprise 2020.summary.top_n_summary.html
# Data written to AI adoption in the enterprise 2020.summary.mean_scored_summary.html
# Data written to Four short links: 18 March 2020.summary.top_n_summary.html
# Data written to Four short links: 18 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 17 March 2020.summary.top_n_summary.html
# Data written to Four short links: 17 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 16 March 2020.summary.top_n_summary.html
# Data written to Four short links: 16 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 13 March 2020.summary.top_n_summary.html
# Data written to Four short links: 13 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 12 March 2020.summary.top_n_summary.html
# Data written to Four short links: 12 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 11 March 2020.summary.top_n_summary.html
# Data written to Four short links: 11 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 10 March 2020.summary.top_n_summary.html
# Data written to Four short links: 10 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 9 March 2020.summary.top_n_summary.html
# Data written to Four short links: 9 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 6 March 2020.summary.top_n_summary.html
# Data written to Four short links: 6 March 2020.summary.mean_scored_summary.html
# Data written to Radar trends to watch: March 2020.summary.top_n_summary.html
# Data written to Radar trends to watch: March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 5 March 2020.summary.top_n_summary.html
# Data written to Four short links: 5 March 2020.summary.mean_scored_summary.html
# Data written to Remembering Freeman Dyson.summary.top_n_summary.html
# Data written to Remembering Freeman Dyson.summary.mean_scored_summary.html
# Data written to Four short links: 4 March 2020.summary.top_n_summary.html
# Data written to Four short links: 4 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 3 March 2020.summary.top_n_summary.html
# Data written to Four short links: 3 March 2020.summary.mean_scored_summary.html
# Data written to The death of Agile.summary.top_n_summary.html
# Data written to The death of Agile.summary.mean_scored_summary.html
# Data written to Four short links: 2 March 2020.summary.top_n_summary.html
# Data written to Four short links: 2 March 2020.summary.mean_scored_summary.html
# Data written to Four short links: 28 February 2020.summary.top_n_summary.html
# Data written to Four short links: 28 February 2020.summary.mean_scored_summary.html
# Data written to Four short links: 27 February 2020.summary.top_n_summary.html
# Data written to Four short links: 27 February 2020.summary.mean_scored_summary.html
# Data written to Intellectual control.summary.top_n_summary.html
# Data written to Intellectual control.summary.mean_scored_summary.html
# Data written to Highlights from the O’Reilly Software Architecture Conference in New York 2020.summary.top_n_summary.html
# Data written to Highlights from the O’Reilly Software Architecture Conference in New York 2020.summary.mean_scored_summary.html
#
# Displaying Highlights from the O’Reilly Software Architecture Conference in New York 2020.summary.mean_scored_summary.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Highlights from the O’Reilly Software Architecture Conference in New York 2020.summary.mean_scored_summary.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Extracting entities from a text with NLTK

# %%
import nltk
import json

BLOG_DATA = "feed.json"

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    sentences = nltk.tokenize.sent_tokenize(post['content'])
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    # Flatten the list since we're not using sentence structure
    # and sentences are guaranteed to be separated by a special
    # POS tuple such as ('.', '.')

    pos_tagged_tokens = [token for sent in pos_tagged_tokens for token in sent]

    all_entity_chunks = []
    previous_pos = None
    current_entity_chunk = []
    for (token, pos) in pos_tagged_tokens:

        if pos == previous_pos and pos.startswith('NN'):
            current_entity_chunk.append(token)
        elif pos.startswith('NN'):
            
            if current_entity_chunk != []:
                
                # Note that current_entity_chunk could be a duplicate when appended,
                # so frequency analysis again becomes a consideration

                all_entity_chunks.append((' '.join(current_entity_chunk), pos))
            current_entity_chunk = [token]

        previous_pos = pos

    # Store the chunks as an index for the document
    # and account for frequency while we're at it...

    post['entities'] = {}
    for c in all_entity_chunks:
        post['entities'][c] = post['entities'].get(c, 0) + 1

    # For example, we could display just the title-cased entities

    print(post['title'])
    print('-' * len(post['title']))
    proper_nouns = []
    for (entity, pos) in post['entities']:
        if entity.istitle():
            print('\t{0} ({1})'.format(entity, post['entities'][(entity, pos)]))
    print()
# Out:
# Four short links: 30 April 2020
# -------------------------------
# 	Microservices (1)
# 	Back Again (1)
# 	Segment Went Back (1)
# 	Monolith (1)
# 	Kernel Recipes (1)
# 	Blender — Facebook (1)
# 	Videos (1)
#
# Four short links: 29 April 2020
# -------------------------------
# 	Pod Paper Scissors (1)
# 	Experts (1)
# 	Ben Klemens (1)
# 	Liz Landau (1)
# 	Ben Klemens (1)
# 	Verification Handbook (1)
# 	Craig Silverman (1)
# 	Ransomware Groups (1)
# 	Microsoft (1)
# 	Bug Stories — (1)
#
# Four short links: 28 April 2020
# -------------------------------
# 	Language — (1)
# 	Cookbook (1)
# 	” Paxos (1)
# 	Consensus (1)
# 	Distributed Consensus (1)
# 	Paxos (1)
# 	Raft (2)
# 	Raft (1)
# 	Paxos (2)
# 	Raft ’ (1)
# 	Google Research Football (1)
# 	Reinforcement Learning (1)
#
# Four short links: 27 April 2020
# -------------------------------
# 	Process (1)
# 	Different Computer (1)
# 	Consistency Maps — Jepsen (1)
# 	Expert Twitter Only Goes (1)
# 	Bring Back Blogs (1)
# 	Wired (1)
# 	Syllabus (1)
#
# Four short links: 24 April 2020
# -------------------------------
# 	Suddenly Remote Playbook — (1)
# 	Python (1)
# 	Cost (1)
# 	Natural Language Processing (1)
# 	Neutrality (1)
# 	Did (1)
# 	Pandemic Internet — (1)
# 	Netflix ’ (1)
# 	States (1)
# 	Steam (1)
#
# Four short links: 23 April 2020
# -------------------------------
# 	Moloch — Large (1)
# 	Instagram Photos — (1)
# 	Instagram ’ (1)
# 	Colab (1)
# 	Cloud (1)
# 	Spotify Doesn ’ (1)
# 	Use (1)
# 	Spotify Model ” (1)
# 	Neither Should (1)
# 	Jeremiah Lee (1)
# 	Spotify (3)
# 	Full (1)
# 	Every (1)
#
# How data privacy leader Apple found itself in a data ethics catastrophe
# -----------------------------------------------------------------------
# 	Apple (6)
# 	Goldman Sachs (1)
# 	Twitter (1)
# 	Apple ’ (1)
# 	Goldman ’ (1)
# 	Goldman (1)
# 	Trust (1)
# 	Compliance (2)
# 	Compliance (2)
# 	Ethics (1)
# 	European Union ’ (2)
# 	General Data Protection Regulation (2)
# 	Fines (1)
# 	Google (1)
# 	Facebook (1)
# 	Practice Fusion (1)
# 	Don ’ (1)
# 	Laws (1)
# 	Organizations (1)
# 	Case (1)
# 	Facebook ’ (1)
# 	Cambridge Analytica (1)
# 	Facebook (1)
# 	New (1)
# 	Legal (1)
# 	Employees (1)
# 	Alison Taylor (1)
# 	Executive Director (1)
# 	Ethical Systems (1)
# 	Enabling (1)
# 	Apple (2)
# 	Fortune (1)
# 	Ethics (1)
# 	Inconsistent (1)
# 	Universal Declaration (1)
# 	Human Rights (1)
# 	International Covenant (1)
# 	Economic (1)
# 	Social (1)
# 	Cultural Rights (1)
# 	Salesforce (1)
# 	Workday (1)
# 	Unisys (1)
# 	Robert Smith (1)
# 	Director (1)
# 	Ethics (1)
# 	Compliance (1)
# 	Partnership (1)
# 	Civic Data Privacy Leaders Network (1)
# 	Cities (1)
# 	Coalition (1)
# 	Digital (1)
# 	Rights (1)
# 	Right (1)
# 	City Alliance (1)
# 	Metrolab (1)
# 	Data Collaboratives Research Network (1)
# 	Paul Barrett (1)
# 	New York University ’ (1)
# 	Center (1)
# 	Business (1)
# 	Human Rights (1)
# 	Americans (1)
#
# Four short links: 22 April 2020
# -------------------------------
# 	Posthog — (1)
# 	Mainframe (1)
# 	Recurse (1)
# 	Developers Knew (1)
# 	Databases (1)
# 	Jaana B. Dogan (1)
#
# Four short links: 21 April 2020
# -------------------------------
# 	Time (1)
# 	Learn (1)
# 	Scott Berkun (1)
# 	Marc Andreessen ’ (1)
# 	Time (1)
# 	Desert Island Devops (1)
# 	April (1)
# 	Animal Crossing (1)
# 	New Horizons (1)
# 	Machine Learning-Powered Bug Sorting — (1)
# 	Microsoft (1)
# 	Part (1)
#
# Four short links: 20 April 2020
# -------------------------------
# 	Mainframes (1)
# 	Moment (1)
# 	Cobol (1)
# 	Cobol (1)
# 	Swim Kernel (1)
# 	Simon Willison (1)
#
# Four short links: 17 April 2020
# -------------------------------
# 	Open Mainframe Project (1)
# 	Serverless Handbook (1)
# 	Novel Annealing Processor (1)
# 	Ever (1)
# 	Combinatorial Optimization Problems (1)
# 	Stochastic Cellular Automata Annealer Architecture (1)
# 	Ising (1)
#
# Four short links: 16 April 2020
# -------------------------------
# 	Kanboard — (1)
# 	Remote Work Playbook — (1)
# 	Notion (1)
# 	Zoom (1)
# 	Skype (1)
# 	Database (1)
# 	Percona (1)
#
# Four short links: 15 April 2020
# -------------------------------
# 	Programming (1)
# 	John Gruber (1)
# 	See (1)
# 	Programming (1)
# 	Computer Science (1)
# 	Coding (1)
# 	Andre Karpathy (1)
# 	Autograd (1)
# 	D (1)
# 	Implements (1)
# 	Game Cheating (1)
# 	Hardware — (1)
# 	Luke Weston (1)
# 	Radar Trends (1)
# 	April (1)
# 	Ops (1)
# 	Infrastructure (1)
# 	Software Development (1)
# 	Quantum Computing (1)
#
# Four short links: 14 April 2020
# -------------------------------
# 	Science (1)
# 	Happiness — (1)
# 	Berkeley ’ (1)
# 	Learn (1)
# 	New Business (1)
# 	A16Z (1)
# 	Scaling (1)
# 	Weaker (1)
# 	Group Chat (1)
# 	Way (1)
# 	Totally Stress (1)
# 	Your Team — Group (1)
# 	Standards Project — (1)
#
# Radar trends to watch: April 2020
# ---------------------------------
# 	March (2)
# 	Coronavirus (5)
# 	April (1)
# 	Coronavirus (1)
# 	Maciej Ceglowski ’ (1)
# 	Surveillance (1)
# 	Program ” (1)
# 	Maciej (1)
# 	Be (1)
# 	Edward Snowden.A (1)
# 	Apple (1)
# 	Operations (1)
# 	Infrastructure Rolling (1)
# 	Kubernetes (1)
# 	Kublr (2)
# 	Bottlerocket (1)
# 	Bottlerocket ’ (1)
# 	Uber (1)
# 	Chronosphere (1)
# 	Software Development Microsoft (1)
# 	Steve Ballmer ’ (1)
# 	Microsoft (1)
# 	Microsoft ’ (1)
# 	Microsoft (1)
# 	Chrome (1)
# 	Mozilla (1)
# 	Intelligence (1)
# 	Machine Learning Realtime (1)
# 	Google Translate (1)
# 	Android (1)
# 	Researchers (1)
# 	Deep Entity Classification (1)
#
# Four short links: 13 April 2020
# -------------------------------
# 	Introduction (1)
# 	University (1)
# 	Limerick (1)
# 	Zoom (1)
#
# Four short links: 10 April 2020
# -------------------------------
# 	Compiler Explorer — (1)
# 	Tim Westbrook (1)
# 	Mac (1)
# 	See (1)
# 	Magnet (1)
# 	Ben Gracewood (1)
#
# Four short links: 9 April 2020
# ------------------------------
# 	Fuzzy Edges (1)
# 	Character Encoding (1)
# 	Morse Code (1)
# 	Unicode (1)
# 	Everest Pipkin (1)
# 	Windows (1)
# 	Electronic Nose (1)
# 	Applications (1)
# 	Survey — (1)
#
# Four short links: 8 April 2020
# ------------------------------
# 	System Design (1)
# 	Advanced Beginners (1)
# 	X (1)
# 	Sara (1)
# 	X ” (1)
# 	Y (1)
# 	” Lozya — Teleconferencing (1)
# 	Walk (1)
# 	Ideal (1)
# 	Hammerspoon — (1)
# 	Lua (1)
# 	Semester Potpourri (1)
# 	Hitchiker ’ (1)
# 	Guide (1)
# 	Logical Verification (1)
# 	Microsoft Research ’ (1)
# 	Lean (1)
#
# Four short links: 7 April 2020
# ------------------------------
# 	Python (1)
# 	Obstructions (1)
# 	Primer — (1)
# 	Covid-19 (1)
#
# Governance and Discovery
# ------------------------
# 	Data Governance (1)
# 	Europe ’ (1)
# 	California (1)
# 	People (1)
# 	Tools (2)
# 	Companies (2)
# 	Data (2)
# 	Datasheets (1)
# 	Datasets (1)
# 	Amundsen (2)
# 	Lyft (1)
# 	Lyft ’ (1)
# 	Google ’ (1)
# 	Amundsen (1)
# 	Amundsen (1)
#
# Four short links: 6 April 2020
# ------------------------------
# 	Rufus — Create (1)
# 	Audio Quality (1)
# 	Duo (1)
# 	Interpreters — (1)
# 	Crafting Interpreters (1)
#
# Four short links: 3 April 2020
# ------------------------------
# 	Zero Trust Learning Curve (1)
# 	Palo Alto Networks (1)
# 	Crown Jewels (1)
# 	Zero Trust (2)
# 	Zero Trust (1)
# 	Software Engineering Advice (1)
# 	Large-Scale Distributed Systems (1)
# 	Jeff Dean (1)
# 	Stanford (1)
# 	Russia ’ (1)
# 	Open Source (1)
# 	Experimental (1)
# 	Tiny Tools Roundup — (1)
#
# Four short links: 2 April 2020
# ------------------------------
# 	Imperial College ’ (1)
# 	R (1)
# 	Readings (1)
# 	Time — (1)
# 	Alan Kay ’ (1)
# 	Douyin Suspending (1)
# 	Livestreamers — (1)
# 	Facebook ’ (1)
#
# Four short links: 1 April 2020
# ------------------------------
# 	Traffic (1)
# 	Test Proprietary (1)
# 	Systems (1)
# 	Wiresham (1)
# 	Innovations (1)
# 	Outlaw Innovations (1)
# 	— Terminal (1)
# 	Oculus Rift (1)
#
# Four short links: 31 March 2020
# -------------------------------
# 	Releases Ventilator Designs — (1)
# 	Googling (1)
# 	Compare (1)
# 	Coronavirus/Covid-19 (1)
# 	Care (1)
# 	Use (1)
# 	Form (1)
# 	Don ’ (1)
# 	Be (1)
# 	Choose (1)
# 	Convey (1)
#
# What you need to know about product management for AI
# -----------------------------------------------------
# 	Machine (2)
# 	Make (1)
# 	Models (1)
# 	Models (1)
# 	Planning (1)
# 	Imagine (1)
# 	Disney (3)
# 	Netflix (2)
# 	Amazon (1)
# 	Netflix Prize (1)
# 	Social (1)
# 	Netflix (2)
# 	Complications (1)
# 	Features (1)
# 	Job (2)
# 	Agile (1)
# 	Particularly (1)
# 	Jeff Bezos (1)
# 	Harvard Business Review (1)
# 	Product (3)
# 	Measurement (1)
# 	Oracle (1)
# 	Oracle ’ (1)
# 	Amazon ’ (1)
# 	Walmart ’ (1)
# 	Consumer (1)
# 	Google (2)
# 	Facebook (1)
# 	Needs (1)
# 	” Monica Rogati (1)
# 	Lukas Biewald (1)
# 	Figure Eight (1)
# 	Weights (1)
# 	Biases (1)
# 	Start (1)
# 	Any (1)
# 	Jeremy Jordan (1)
# 	Jordan (1)
# 	Interview (1)
# 	Data (1)
# 	Fraud (1)
# 	Work (1)
# 	Customers (1)
# 	Pete Skomoroch (1)
# 	People (2)
# 	May Know (1)
# 	Scope (1)
# 	Resources (1)
# 	Rules (1)
# 	Machine Learning (1)
# 	Practices (1)
# 	Google (1)
# 	Machine Learning (1)
# 	Projects (1)
# 	Apple (1)
# 	O ’ Reilly Strata Data (1)
# 	Spring (1)
# 	Full Stack Deep Learning Bootcamp (1)
# 	Berkeley (1)
# 	Rise (1)
# 	Data Product Manager ” (1)
# 	Trey Causey (1)
# 	Everything (1)
# 	Known (1)
# 	Building Data Products ” (1)
# 	Product Management (1)
# 	Pete Skomoroch (1)
# The unreasonable importance of data preparation
# -----------------------------------------------
# 	Monica Rogati ’ (1)
# 	Needs (1)
# 	Rogati (1)
# 	Jawbone (1)
# 	Monica Rogati (1)
# 	Andrei Karpathy (1)
# 	Tesla (1)
# 	Software (1)
# 	Data (5)
# 	John Myles White (1)
# 	Facebook (1)
# 	” John (1)
# 	Z Z (1)
# 	Let ’ (1)
# 	X Correlation (1)
# 	Brian Wansink (1)
# 	Food (1)
# 	Brand Lab (1)
# 	Cornell University (1)
# 	Cornell (1)
# 	Wansink ’ (1)
# 	Data (1)
# 	O ’ Reilly (2)
# 	“ Chicago ” (1)
# 	Look (1)
# 	Google ’ (1)
# 	Twitter (1)
# 	Analysts (1)
# 	Set (1)
# 	Transparent How Variations (1)
# 	Analytic (1)
# 	Choices (1)
# 	Affect Results (1)
# 	Model (1)
# 	Automation (1)
# 	Democratization (1)
# 	Snorkel (1)
# 	Christopher Ré ’ (1)
# 	Stanford (1)
# 	Chicago ” (1)
# 	Snorkel (3)
# 	Researchers (1)
# 	Snorkel (1)
# 	Discovery (1)
# 	Google (1)
# 	Microsoft (1)
# 	Angela Bassa (1)
# 	Angela Bowne (1)
# 	Vicki Boykis (1)
# 	Joyce Chung (1)
# 	Mike Loukides (1)
# 	Mikhail Popov (1)
# 	Emily Robinson (1)
# 	Mikhail Popov (1)
# 	Wikimedia Foundation (1)
# 	Analytics Datasets (1)
# 	Wikipedia (1)
# 	” “ Small (1)
# 	Americans (1)
# 	Hadley Wickham ’ (1)
# 	Tolstoy (1)
# 	] Yet (1)
# 	Azure ’ (1)
# 	R Markdown (1)
# 	Jupyter Notebooks (1)
# 	Series C (1)
#
# Four short links: 24 March 2020
# -------------------------------
# 	Potential Distributed Reading Group (1)
# 	Distributed (1)
# 	Systems (1)
# 	Just (1)
# 	Jitsi Meet — (1)
# 	Pigweed — (1)
# 	See (1)
# 	Google Open Source (1)
# 	Windows (1)
# 	Linux (1)
# 	Consoles (1)
# 	Smartphones (1)
#
# 3 ways to confront modern business challenges
# ---------------------------------------------
# 	Craig Lemasters (1)
# 	Assurant Solutions (2)
# 	Lemasters (2)
# 	Assurant (1)
# 	Disclosure (2)
# 	Science House (2)
# 	Jen Bruno (2)
# 	Bruno (2)
# 	Walt Disney (1)
# 	Dana Codispoti (1)
# 	Morgan Stanley (1)
# 	Codispoti (2)
# 	James Jorasch (2)
# 	Science House (2)
# 	New (1)
# 	Jorasch (1)
# 	Walker Digital (1)
# 	Priceline (1)
# 	Craig Lemasters (1)
# 	Assurant Solutions (1)
# 	Assurant ’ (1)
# 	Lemasters (2)
# 	Technology (1)
# 	” Dana Codispoti (1)
# 	Codispoti (1)
# 	Companies (1)
# 	” Codispoti (2)
# 	” Codispoti (2)
# 	Every (1)
# 	” Bruno (1)
# 	” Bruno (1)
# 	Business (1)
# 	Companies (2)
# 	Codispoti (1)
# 	Create (1)
# 	Agile (2)
# 	Smaller (1)
# 	Once (1)
# 	Huge (1)
# 	Agile (1)
# 	” Jorasch (1)
# 	Managers (1)
# 	” Jorasch (2)
# 	Focus (1)
# 	Humility (1)
# 	People (1)
# 	” Bruno (1)
# 	Humility (2)
# 	A (1)
#
# An enterprise vision is your company’s North Star
# -------------------------------------------------
# 	Rita J (1)
# 	King (1)
# 	Science House (1)
# 	Dana Codispoti (1)
# 	Codispoti (2)
# 	Codispoti (2)
# 	North Star (1)
# 	Talk (1)
# 	People (1)
# 	People (1)
# 	Nobody (1)
#
# Leaders need to mobilize change-ready workforces
# ------------------------------------------------
# 	Rita J (1)
# 	King (1)
# 	Science House (1)
# 	Jen Bruno (1)
# 	Bruno (2)
# 	Companies (1)
# 	Bridging (1)
# 	Bruno (1)
# 	Every (1)
#
# Great leaders inspire innovation and creativity from within their workforces
# ----------------------------------------------------------------------------
# 	Rita J (1)
# 	King (1)
# 	Science House (2)
# 	James Jorasch (1)
# 	Jorasch (2)
# 	Believe (1)
# 	Trying (1)
# 	Well (1)
# 	Science House (1)
# 	Jorasch (1)
# 	Agile (2)
# 	Agile (1)
# 	People (1)
#
# Strong leaders forge an intersection of knowledge and experience
# ----------------------------------------------------------------
# 	Rita J (1)
# 	King (1)
# 	Science House (1)
# 	Craig Lemasters (1)
# 	Global Executive Group (1)
# 	Digital (1)
# 	Lemasters (4)
# 	Assurance Solutions (1)
# 	Lemasters (1)
# 	Lemasters ’ (1)
#
# Four short links: 23 March 2020
# -------------------------------
# 	Stanza (1)
# 	Python Natural Language Processing Toolkit (1)
# 	Many Human Languages — Stanza (1)
# 	Code (1)
# 	Dropbear (2)
# 	Unix (1)
# 	Kit — (1)
#
# Four short links: 20 March 2020
# -------------------------------
# 	Races (1)
# 	Esports (1)
# 	Pro Drivers (1)
# 	Engadget (1)
# 	Firebase Scrutinized (1)
# 	Antitrust (1)
# 	Regulators (1)
# 	— Firebase (1)
# 	Google (1)
# 	Firebase (1)
# 	Journey (1)
# 	Observability (1)
# 	Glitch ’ (1)
# 	Story (1)
# 	Mads Hartmann (1)
# 	Hyphal Mesh (1)
# 	Nifty (1)
#
# 6 trends framing the state of AI and ML
# ---------------------------------------
# 	O ’ Reilly (13)
# 	Deep (1)
# 	Reinforcement (1)
# 	Figure (5)
# 	Growth (2)
# 	Engagement (1)
# 	Figure (4)
# 	Data (1)
# 	Interest (1)
# 	Usage (1)
# 	Interest (1)
# 	Computer (1)
# 	Torch ’ (1)
# 	Torch ’ (1)
# 	Python (1)
# 	Torch (1)
# 	Lua (2)
# 	C (3)
# 	Python (3)
# 	Python (1)
# 	No (1)
# 	No (1)
# 	Keras (2)
# 	Python ’ (1)
# 	Tools (1)
# 	Adoption (1)
# 	Plato (1)
# 	Socrates (1)
# 	Philosophical (1)
# 	October (1)
# 	] Overall (1)
# 	Share (1)
# 	Neural (1)
# 	C++ (1)
# 	Go (1)
# 	Java (1)
# 	Neither (1)
# 	Keras (1)
# 	No (1)
#
# Four short links: 19 March 2020
# -------------------------------
# 	Dos (1)
# 	Don ’ (1)
# 	Open Source (1)
# 	Olaf Geirsson (1)
# 	Consider (1)
# 	Promises (1)
# 	Thread (1)
# 	Sarah T. Roberts (1)
# 	Facebook (1)
# 	Zoom Community Calls (1)
# 	Alex L. Miller (1)
# 	Zoom (1)
# 	Self-Isolating (1)
# 	Kate Montgomery (1)
#
# It’s an unprecedented crisis: 8 things to do right now
# ------------------------------------------------------
# 	Singapore (1)
# 	Singapore (1)
# 	Push (1)
# 	News (1)
# 	Share (1)
# 	Modify (1)
# 	Be (1)
# 	Be (1)
# 	Monitor (1)
# 	Flu (1)
# 	Atlantic (1)
# 	People (2)
# 	Create (1)
# 	Tell (1)
# 	Companies (1)
# 	Take (1)
# 	Ground (1)
#
# AI adoption in the enterprise 2020
# ----------------------------------
# 	December (1)
# 	Key (1)
# 	Survey (2)
# 	“ Software ” (1)
# 	“ Computers (1)
# 	Electronics (1)
# 	Hardware (1)
# 	Figure (1)
# 	Industry (1)
# 	Data (1)
# 	Figure (5)
# 	Role (1)
# 	Regional (1)
# 	Close (1)
# 	North America (1)
# 	United (1)
# 	States (1)
# 	Western Europe (1)
# 	Asia (1)
# 	Participants (1)
# 	South America (1)
# 	Eastern Europe (1)
# 	Oceania (1)
# 	Africa (1)
# 	Analysis (1)
# 	Respondents (1)
# 	Figure (3)
# 	Bottlenecks (2)
# 	No (3)
# 	Difficulties (1)
# 	State (1)
# 	Data Quality (1)
# 	Companies (1)
# 	Consistent (1)
# 	Risks (1)
# 	Model (1)
# 	Python (2)
# 	Python (2)
# 	Keras (1)
# 	O ’ Reilly (2)
# 	Data (2)
# 	Think (1)
# 	R (1)
# 	D (1)
# 	Adopters (1)
# 	Adopters (1)
# 	None (1)
# 	Evaluation ” (1)
# 	Analysis ” (1)
# 	Production ” (1)
# 	Analysis ” (1)
# 	“ Production ” (1)
#
# Four short links: 18 March 2020
# -------------------------------
# 	Inklewriter — (1)
# 	Fun (1)
# 	Andy Baio (1)
# 	Virus Survival Strategy Guide (1)
# 	Startup (1)
# 	Steve Blank (1)
# 	Cambridge University Textbooks — (1)
# 	May (1)
# 	Software Engineering (1)
# 	Google — (1)
# 	O ’ Reilly (1)
# 	Covers (1)
# 	Google ’ (1)
#
# Four short links: 17 March 2020
# -------------------------------
# 	Great Firewall Discovers Hidden Circumvention Servers — (1)
# 	Challenge (1)
# 	Software Liability — Liability (1)
# 	Congress (1)
# 	Research (1)
# 	Papers (1)
# 	Internet Censorship — (1)
#
# Four short links: 16 March 2020
# -------------------------------
# 	Uncensored Library — Reporters (1)
# 	Borders (1)
# 	Minecraft (1)
# 	Gizmodo (1)
# 	Shmoocon (1)
# 	Talk Recordings — (1)
# 	Zero Trust (1)
# 	Privacy (1)
# 	Comparison (1)
# 	Libraries — (1)
# 	Layoffs (1)
# 	Jacob Kaplan-Moss (1)
#
# Four short links: 13 March 2020
# -------------------------------
# 	Relationships (1)
# 	Remote Engineering Manager — (1)
# 	Level (4)
# 	Basic Authentication (1)
# 	Authentication (1)
# 	Authorization (1)
# 	– Centralized Trust Using Claims (1)
# 	Architecture (1)
# 	Netflix (2)
# 	Hexagonal Architecture (1)
#
# Four short links: 12 March 2020
# -------------------------------
# 	Amazon (1)
# 	Design Guide (1)
# 	Zero Trust Information — (1)
# 	Ben (1)
# 	Corporate Engineering Blogs Are Written (1)
# 	Dan Luu (1)
# 	Presents (1)
#
# Four short links: 11 March 2020
# -------------------------------
# 	— Cory Doctorow ’ (1)
# 	C++ (1)
# 	Python (1)
# 	Node (1)
# 	Tetsuo Kogawa (1)
# 	Wi-Fi (1)
#
# Four short links: 10 March 2020
# -------------------------------
# 	Facets (1)
# 	Tim Bray (1)
# 	A+ (1)
# 	Google (1)
# 	See (1)
#
# Four short links: 9 March 2020
# ------------------------------
# 	Sno — Distributed (1)
# 	Open (1)
# 	Woman (1)
# 	Babysitter (1)
# 	Biases (1)
# 	Language Generation — (1)
# 	Violent Peng (1)
# 	Online Academic Conference (1)
# 	Workbook — (1)
# 	Franklin Sayre (1)
# 	Problems (1)
# 	Your Multithreaded Code — (1)
#
# Four short links: 6 March 2020
# ------------------------------
# 	Soul (1)
# 	New (1)
# 	Machine (1)
# 	Computer (1)
# 	Bryan Cantrill (1)
# 	Stanford (1)
# 	Rust (1)
# 	Use (1)
# 	Problems (1)
# 	See (1)
# 	Lobsters (1)
# 	Landmark Computer Science Proof Cascades (1)
# 	Physics (1)
# 	Math (1)
# 	Quanta (1)
# 	Computational (1)
# 	Millions (1)
# 	Tiny Databases — (1)
# 	Block Storage (1)
# 	Availability Zones ] (1)
#
# Radar trends to watch: March 2020
# ---------------------------------
# 	Pete Warden (1)
# 	Foster Provost (1)
# 	Democratization (1)
# 	Google ’ (1)
# 	Meena (1)
# 	O ’ Reilly Software Architecture Conference (1)
# 	New York (1)
# 	Mary Poppendieck (1)
# 	Coronavirus (2)
# 	China (2)
# 	Autonomous (1)
# 	Cornell ’ (1)
# 	College (1)
# 	Agriculture (2)
# 	Schools (1)
# 	Netherlands (1)
# 	China (1)
# 	Tillable (1)
# 	Cybersecurity (1)
# 	Lidar (1)
# 	Sort (1)
# 	Future (1)
# 	Artificial (1)
# 	Mark Zuckerberg (1)
# 	Don ’ (1)
# 	Internet (1)
# 	Handshake Network (1)
# 	Handshake (1)
#
# Four short links: 5 March 2020
# ------------------------------
# 	Open (1)
# 	Hickey (1)
# 	Better Developer — (1)
# 	Mastery (1)
# 	Handbook — (1)
#
# Remembering Freeman Dyson
# -------------------------
# 	Freeman Dyson (2)
# 	Institute (2)
# 	Advanced (2)
# 	Studies (1)
# 	Princeton (1)
# 	Freeman (9)
# 	George (2)
# 	“ Oh (1)
# 	Richard Feynman (1)
# 	Schwinger (5)
# 	Shin ’ (1)
# 	Tomonaga (1)
# 	Feynman (1)
# 	Tomonaga (1)
# 	Nobel Prize (1)
# 	Physics (1)
# 	Royal Air Force Bomber Command (1)
# 	Universe (1)
# 	Britain (1)
# 	Freeman ’ (4)
# 	Danny Hillis (1)
# 	” Danny (1)
# 	Think (1)
# 	Danny (1)
# 	Kenneth Brower ’ (1)
# 	Starship (1)
# 	Canoe (1)
# 	Freeman ’ (1)
# 	Project Orion (1)
# 	George ’ (1)
# 	Pacific Northwest (1)
# 	Rude (1)
# 	Science Foo Camp (1)
# 	Michael Crichton ’ (1)
# 	Prey (1)
# 	Anyone (1)
# 	Freeman (1)
# 	Richard Feynman ’ (1)
# 	Pleasure (1)
# 	Finding Things Out (1)
# 	New York Times (1)
# 	Elizabethan (1)
# 	Ben Jonson (1)
# 	Jonson ’ (4)
# 	William Shakespeare (2)
# 	Jonson (7)
# 	Shakespeare (4)
# 	Shakespeare (1)
# 	London (1)
# 	Shakespeare (6)
# 	Every (2)
# 	Man (2)
# 	Humour (2)
# 	Jonson (2)
# 	Shakespeare ’ (1)
# 	Jonson (3)
# 	Westminster Abbey (1)
# 	Memory (1)
# 	My Beloved Master (1)
# 	Richard Feynman (1)
# 	” Fate (1)
# 	Feynman (10)
# 	England (1)
# 	Cornell University (1)
# 	Feynman ’ (1)
# 	American (1)
# 	Jonson ’ (1)
# 	Nature (1)
# 	Tomonaga (3)
# 	Physical Review (1)
# 	Feynman (2)
# 	Studies (1)
# 	George Dyson (1)
# 	Dyson (1)
#
# Four short links: 4 March 2020
# ------------------------------
# 	Khan Academy (1)
# 	Systems (1)
# 	Have Less Downtime — (1)
# 	Proficiency (1)
# 	Cybersecurity Law (1)
# 	Policy (1)
# 	Infrastructure — (1)
# 	United (1)
# 	States (1)
# Four short links: 3 March 2020
# ------------------------------
# 	Facebook ’ (1)
# 	Incomplete Download Your Data (1)
# 	Privacy International (1)
# 	Facebook (2)
# 	“ Download (1)
# 	Information ” (1)
# 	Information (1)
# 	Off-Facebook (1)
# 	Bruce Schneier (1)
# 	Proxy Verifier — (1)
# 	Yahoo (1)
# 	Stripe ’ (1)
# 	Covid-19 Company Plan — (1)
# 	Google ’ (1)
# 	Tech-Writing Course — (1)
#
# The death of Agile?
# -------------------
# 	Agile (8)
# 	Agile (6)
# 	Eben Hewitt (1)
# 	Agile (7)
# 	Scrum (1)
# 	Scrum (1)
# 	None (1)
# 	Yep (1)
# 	Scrum (1)
# 	Douglas Adams (1)
# 	Agile Manifesto (1)
# 	Neckbeards (1)
# 	Geeks (1)
# 	Agile ’ (1)
# 	“ Agile ” (1)
# 	Isaac Newton (1)
# 	Agile Manifesto (1)
# 	Development (1)
# 	Progress (1)
# 	Amazon ’ (1)
# 	Make (1)
# 	Domain Driven Design (1)
# 	Manifesto (1)
# 	Eben (2)
# 	Mike Loukides Radar (1)
# 	O ’ Reilly (2)
# 	Findings (1)
# 	Python (2)
# 	Software (1)
# 	Coincidence (1)
# 	Growth (1)
# 	Security (1)
# 	Aggregate (1)
# 	Key (1)
# 	Data (1)
# 	Data (1)
# 	Organizations (1)
# 	Radar (1)
#
# Four short links: 2 March 2020
# ------------------------------
# 	Gandalf (2)
# 	Intelligent (1)
# 	Safe Deployment (1)
# 	Azure ’ (1)
# 	Paper (1)
# 	Quarantine (1)
# 	Cooking (1)
# 	New Yorker (1)
# 	Quarantine (1)
# 	Draft (1)
# 	Book — (1)
# 	Medium (1)
# 	I18N (1)
#
# Four short links: 28 February 2020
# ----------------------------------
# 	Coronavirus Responsibly (1)
# 	Let ’ (1)
# 	Don ’ (1)
# 	Test Desirability — (1)
# 	Web Inspector (1)
# 	Data Center Power (1)
# 	Jess Frazelle (1)
# 	Wildcard (1)
# 	Customization (1)
# 	Web Applications — (1)
#
# Four short links: 27 February 2020
# ----------------------------------
# 	Flowing Data (1)
# 	Guide (1)
# 	Raising Series A — (1)
# 	A (1)
# 	Information (1)
# 	Disorders (1)
# 	Issues — Issues (1)
#
# Intellectual control
# --------------------
# 	O ’ Reilly Software Architecture Conference (1)
# 	New York (1)
# 	O ’ Reilly (1)
#
# Highlights from the O’Reilly Software Architecture Conference in New York 2020
# ------------------------------------------------------------------------------
# 	People (1)
# 	New York (1)
# 	O ’ Reilly Software Architecture Conference (1)
# 	Martin Fowler (1)
# 	Watch (2)
# 	Mary Poppendieck (1)
# 	Watch “ Where (1)
# 	Architecture.Next (1)
# 	Invalidating (2)
# 	Mark Richards (1)
# 	Watch “ Architecture.Next (1)
# 	Kai Holnes (1)
# 	Watch “ Sometimes (1)
# 	Intellectual (1)
# 	George Fairbanks (1)
# 	Watch “ Intellectual (1)
# 	Rachel Laycock Neal Ford (1)
# 	Rachel Laycock (2)

# %% [markdown]
# ## Discovering interactions between entities

# %%
import nltk
import json

BLOG_DATA = "feed.json"

def extract_interactions(txt):
    sentences = nltk.tokenize.sent_tokenize(txt)
    tokens = [nltk.tokenize.word_tokenize(s) for s in sentences]
    pos_tagged_tokens = [nltk.pos_tag(t) for t in tokens]

    entity_interactions = []
    for sentence in pos_tagged_tokens:

        all_entity_chunks = []
        previous_pos = None
        current_entity_chunk = []

        for (token, pos) in sentence:

            if pos == previous_pos and pos.startswith('NN'):
                current_entity_chunk.append(token)
            elif pos.startswith('NN'):
                if current_entity_chunk != []:
                    all_entity_chunks.append((' '.join(current_entity_chunk),
                            pos))
                current_entity_chunk = [token]

            previous_pos = pos

        if len(all_entity_chunks) > 1:
            entity_interactions.append(all_entity_chunks)
        else:
            entity_interactions.append([])

    assert len(entity_interactions) == len(sentences)

    return dict(entity_interactions=entity_interactions,
                sentences=sentences)

blog_data = json.loads(open(BLOG_DATA).read())

# Display selected interactions on a per-sentence basis

for post in blog_data:

    post.update(extract_interactions(post['content']))

    print(post['title'])
    print('-' * len(post['title']))
    for interactions in post['entity_interactions']:
        print('; '.join([i[0] for i in interactions]))
    print()
# Out:
# Four short links: 30 April 2020
# -------------------------------
# Microservices; Back Again; Segment Went Back; Monolith; —; microservices; overhead; problems
# …; microservices; band-aid; root; flaws; system; product development; drowning
# GNU; —; editor
# entities; bits; bytes; procedural; programming language
# Kernel Recipes; Blender — Facebook; open-domain; anything; ”
# evaluations; models; approaches; dialogue; terms; engagingness; humanness
# CopyLeft Conf; Videos; schedule; info
#
# Four short links: 29 April 2020
# -------------------------------
# podpaperscissors; “ prisoner; ’; dilemma ”; coördination; games; Pod Paper Scissors; game theory; textbook
# episode; kinds; games
# Experts; variety; fields; hosts; game; applies
# episodes; music; topic
# podcast; game theorist; Ben Klemens; science journalist; composer
# Ben Klemens; Verification Handbook; —; guide; disinformation; media; manipulation; actors; platforms
# Craig Silverman; Ransomware Groups; Microsoft; analysis; ransomware; campaigns yields; report; taxonomy; ransomware
# Bug Stories —; tales; bugs; bug-hunting
#
# Four short links: 28 April 2020
# -------------------------------
# Language —; list; questions; anyone; language; test run
# encouraging; questions; Cookbook; format; OpenVAS — Open Vulnerability Assessment Scanner; security assessment vendor; mail; report; ” Paxos; vs Raft; Consensus
# —; Paxos; Raft; approach; consensus; approach
# Raft; servers; logs; leaders; whereas; Paxos; server; leader
# Raft ’; s approach; simplicity; Paxos; log; entries
# understandability; Raft; paper; ’; presentation
# Google Research Football; Reinforcement Learning; environment; agents; world; ’
# football video; games; physics; football simulation; agents; football; players; team; manage; opponent; s defense; order
#
# Four short links: 27 April 2020
# -------------------------------
# Process; Different Computer; proof; concept; t replicate; things; s; fun tech demo; ’; t use; anything; telefork; function call; process; machine; instance
# Consistency Maps — Jepsen; safety; properties; systems–most; violations; consistency
#
#
# kind; consistency
# reference guide; definitions; explanations; underpinnings; consistency; models; engineers
# wasmachine; —; wasmachine; implementation; WebAssembly; specification
#
# Expert Twitter Only Goes; Bring Back Blogs; Wired; re; opinion; machines; opinion; inflammatory; fit; businesses; people
# Syllabus; systems; substack; part; response; dearth
#
#
# Four short links: 24 April 2020
# -------------------------------
# Suddenly Remote Playbook —; kids; re
# everyone; s; introduction; delights
# taichi; language; high-performance computer
# Python; compiler; tasks; CPUs
# Cost; Training NLP Models —; cost; language; models; drivers
# audience; engineers; scientists; experiments; non-practitioners; sense; economics; Natural Language Processing
# Neutrality; Did; Pandemic Internet —; ’; evidence; networks; COVID-19
# differences; performance; anything; deregulation
# Netflix ’; decision; bandwidth usage
# network; data; regulators
#
#
# YouTube; example; video quality
# game platform; Steam; game
# EU ’; efforts; front; US
#
#
# Four short links: 23 April 2020
# -------------------------------
# Moloch — Large; scale; source; packet capture
# Instagram Photos —; source toolset; effect; Instagram ’
# running; Colab; GPU; Cloud; pubsub/storage
# glimpse; future; apps; services
# xkcd; —; data; science
# Spotify Doesn ’; t; Use; Spotify Model ”; Neither Should; Jeremiah Lee; work; Spotify; experience
# Spotify; squad model; Spotify
#
# Full; killer; points; Every; responsibility; team; focus
#
# How data privacy leader Apple found itself in a data ethics catastrophe
# -----------------------------------------------------------------------
# months; Apple; credit card; partnership; Goldman Sachs; world
# software developer; credit line; wife; fact; tax; returns
# story; Twitter; government investigation
# Apple—the; privacy; gender; product; launches
# Apple ’; customer base; style; Goldman ’; knowledge; industry
# Apple; producer; computer hardware; Goldman; finance; rules backwards
# anyone; product
# Apple; lesson
# buy-in; compliance
# ethics; fight; users
# strategies; perceptions
#
# Compliance; ethics; Compliance; concept; “; rules; regulations. ”; Compliance; possibility; defense
# compliance; experts
# compliance; allows; plenty; room
# example; lending; businesses; doubt compliant; law; aren; models
#
# boundaries; ethics; discussion; ’; set
# ” life; way
# standards; tests; behavior
# behavior; customers; business; partners; ’; trust; actions
# importance; ethics; companies; compliance; Compliance; functions; violations
# European Union ’; General Data Protection Regulation; GDPR; instance; fines; %; %
# millions; billions
# era; fines; cost
# Fines; billions; Google; Facebook; Practice Fusion; records; company; settlement; “; EHR; software; prescribing; pain medications.; ”; impact; line; compliance; business
# instance; companies; millions; intelligence; regulations
# compliance; compliance; ethics; Don ’
# Apple; case; rule-following
# Laws; standard
# privacy leader; technology space; Apple; well; reputation
# law; technology
# Organizations; rules; technology
# Case; point; hearings; outrage; Facebook ’
# public; senators; t; key; technologies; Facebook; harm
# companies; game; ”; data regulations
# New; rules; organizations; technologies
# investors; BlackStone; JP Morgan; governance metrics—like; definition
# Legal; compliance
# result; trust; company; ethics; changing world; ethics; “; platinum rule ”
# field; ethics—bioethics—offers; principles; platinum rule; nonmaleficence; justice; autonomy
# organizations; ethics; law; principles; tools; mission; protecting; nonmaleficence; justice; users; employees; autonomy
# leader; users; workers; operations; governance
# product; qualitative; contexts; stakeholders; needs
# product; data; protection; design; roles; privacy; engineers; principles; lifecycle; product
# launching; product; scenario planning; mishaps; perceived; gender bias; rights violations
# terms; service; collection; methods; enables; users
# Ethics leaders; users
# leaders; consumer; protections; place
# movements; leaders; actors; communities; public; large—and; examines; participation
# result; heroic; efforts
# ethics leaders; users
# communities; employees; products; needs; autonomy
# efforts; revenue; streams; relationships; workers; company; ’
# Employees; values
# Alison Taylor; Executive Director; Ethical Systems; processes; workers; reasoning; creativity; them. ”; Enabling; culture; safety; training
# strategies; employee performance; retention; customer loyalty; carve
#
# instance; Apple; provisions; European Union ’; General Data Protection Regulation; US; residents—not; EU; CA; ability; access; edit
# move; requirements
# ethics strategies; limitations leaders; waves; “; principles; Fortune; companies; commissions; ethics programs; male
# ethics; companies; way; ride; goodwill; lack; oversight
# companies; data ethics principles; engagement; data; regulation; principles
# Long-term; ability; requirements; lawyers; ethics leaders; barriers
# sales; marketing; compliance; counterparts; ethics programs; revenue
# recessions; “; ”; programs
# result; factors; surge; companies; ethics
# efforts; ethics stunts; t deeply engage
# business; models; ethics leaders
# barriers; leaders; ethics; strategies; Ethics; leaders; governance; C-suite; incentives; roadmaps; operations
# Inconsistent; company behavior
# interpretations; ethics; leaders; critiques—like
# push; leaders; power; relations; processes; history; injustice
# leaders; rights frameworks; IHRFs; Universal Declaration; Human Rights; International Covenant; Economic; Social
# states; instance; censorship; trials; torture; supporters; IHRFs; afford; ecosystem; organizations; compliance; approaches; language; jurisprudence; organizations; rights; interests
# buy-in; business; leaders; ethics leaders; coalitions; compliance; data; marketing
# programs; resources; accountability; ethics leaders; ethics; trust
# effectiveness; coalitions; rise; chief; ethics; compliance officers—; host; trust; responsibility; citizenship; data officers; technology; leaders; Salesforce; Workday
# Robert Smith; Director; Ethics; Compliance; InterContinental Hotels Group; teams; “; voice. ”; bolster support; leaders
# technologies; AI; Partnership; AI; b; industries; health; All-in; government; Civic Data Privacy Leaders Network; cities; Cities; Coalition; Digital; Rights; Right; City Alliance; c; set; issues; IEEE; WEF; Metrolab
# variety; community; leaders; coalitions; opportunities; leaders; networks
# rights; ethics; business; strategies; run; term; Paul Barrett; director; New York University ’; s; Center; Business; Human Rights; “; companies; humane; supply; chains; workers proud; jobs.; ”; organizations; ethics; side
# banks; communities; color; loans; risk; government agency; treatment; Americans; syphilis; desire; research; company; planes; people; ” pressure; safety; approvals; algorithms
# decade; Apple; startup—; technologies; fight; advantage
# history; books; fight
#
#
# Four short links: 22 April 2020
# -------------------------------
# Posthog —; source product
# Mainframe; Recurse; interviews; mainframe; programmers; reminder
#
# instance; career; punching clown
# programmers; users
# requests; data
# staff; office; mad; users
#
# doors; office; time; guy; life; office; clown
#
# simulations/modeling.Things; Developers Knew; Databases; Jaana B. Dogan; points
# %; time network
#
# Four short links: 21 April 2020
# -------------------------------
# Time; Learn; Scott Berkun; response; Marc Andreessen ’; ’
# time; anything; folks
# pygraphistry; library
# Desert Island Devops; event; twitch.tv/oncallmemaybe
# presentations; place; world; Animal Crossing
# MSFT ’; Machine Learning-Powered Bug Sorting —; Microsoft; work; items
# data; process; machine learning model; security; non-security; bugs; percent; time; priority security; bugs; percent
#
# Part; augmentation; developers; ML-powered
#
# Four short links: 20 April 2020
# -------------------------------
# CastleDB; database
# CastleDB; spreadsheet editor; sheet
# …; ]; stores; data; model; data; rows; JSON
# … ]; collaboration
# Mainframes; Moment; IEEE Spectrum; college; university computer science; departments; mainframe; curriculum; languages; technologies; faculty; staff; others; interest; Cobol
# increase; layoffs; state unemployment agency computer; systems; government; officials; call; programmers; Cobol
# swimOS; software platform; building stateful; streaming
# swimOS; microkernel; Swim Kernel; database; message broker; job manager; applications
# README Powered; GitHub Actions; TILs; Simon Willison; —
# years; people; person; ’; s
#
# Four short links: 17 April 2020
# -------------------------------
# Nebula —open; source
# COBOL Programming Course; —
# Serverless Handbook; resource; engineers; everything
# Novel Annealing Processor; Ever; Combinatorial Optimization Problems; IEEE Spectrum; STATICA; Stochastic Cellular Automata Annealer Architecture; processor; challenges; portfolio; traffic flow optimization; form; Ising
#
# Four short links: 16 April 2020
# -------------------------------
# Kanboard —; source; Trello-like Kanban
# Remote Work Playbook —; advice
# E.g.; contributor; something; colleague; point; future
# answer; questions; documentation; thing; store; place; team
#
# share; link; communication; channel
# fake technology; avatars; choice; use; Zoom
# pstress; Database; concurrency; crash recovery
#
#
# Four short links: 15 April 2020
# -------------------------------
# vs; Programming; John Gruber
# See; vs; Programming; vs
# Coding; ’
# micrograd; Andre Karpathy; Autograd; engine
#
# Implements; backpropagation; autodiff; DAG; networks; top
#
# Game Cheating; Hardware —; pcileech; WebRadar; browser; radar cheat; CS; PC; PCIe; card; memory access
#
# Luke Weston; Radar Trends; April; —; signals; developments; Ops; Infrastructure; Software Development; AI; ML
#
#
# Four short links: 14 April 2020
# -------------------------------
# Science; Happiness —; enrolment; Berkeley ’; MOOC
# Learn; principles; practices
# New Business; AI; A16Z; AI; companies; margins; infrastructure usage; support; Scaling; challenges; thorny problem; edge; cases; Weaker; moats; commoditization; AI; models; challenges; data; network
# Group Chat; Way; Totally Stress; Your Team — Group; meeting; participants
# Standards Project —; manufacturer; standards; ventilator
#
# Radar trends to watch: April 2020
# ---------------------------------
# March; technology news; Coronavirus
#
# ’; start; Coronavirus; news; something
# Coronavirus; Coronavirus; pandemic; reconsideration
# Maciej Ceglowski ’; post “; Surveillance; Program ”; Maciej; history
# time; privacy; advocates; Be; ’; t get; ”; Edward Snowden.A; number; organizations; blockchains; way; coronavirus
# t; blockchain killer app
# maker movement; decade; coronavirus; lot; maker projects—from; facemasks; ventilators
# Coronavirus; research; papers; archive; question
# s; answer; summarization; search
# Apple; biometrics; watches
# companies; watch; products; doctors; visits
# lot; change; doctors; data; detection; Coronavirus
# Operations; Infrastructure Rolling; Kubernetes; Kublr; updates; feature; groups
# workarounds; Kublr; attempts; solution.AWS; operating system; containers
# Bottlerocket ’; feature; process; container; production; systems
# m3; source; tool; Uber
#
# Software Development Microsoft; npm; ’; t; Steve Ballmer ’; s
# Microsoft ’; acquisition; GitHub; Microsoft; player
# Chrome; tools; page; vision
# step; developers
#
# Intelligence; Machine Learning Realtime; transcription; translation; Google Translate; feature
# lots; issues; example; variations; country; ’; accomplishment
#
# Researchers; LIDAR; effect; development
#
#
# article.Facebook; system; Deep Entity Classification
# s; connection; patterns; users; advantage
# Quantum Computing TensorFlow Quantum; TensorFlow; research; machine
# TensorFlow; quantum computing; tool; simulations; way; quantum computers.Honeywell hasn; ’; t; part; quantum; picture; beginning; March
#
# legislation; US Senate; effect
# bill; abuse; effects; computer security
#
# Four short links: 13 April 2020
# -------------------------------
# Introduction; COBOL
# slides; University; Limerick
#
# zoombot; AI
# storybook.js; —; source toolkit; sandbox; UI; components; isolation; states; edge
# —; computer
#
# Four short links: 10 April 2020
# -------------------------------
# FairMOT —; tracking; state-of-the-arts; MOT; challenge; datasets
# pipedream —; IFTTT
# Compiler Explorer —; tool; code; window; results; compilation
# site; default; hand pane; source window; hand
# Tim Westbrook; MOOM —; move; zoom; windows
#
# Ben Gracewood; @
# Four short links: 9 April 2020
# ------------------------------
# Fuzzy Edges; Character Encoding; history; politics; basics; character encoding; representations; text; Morse Code; ASCII; Unicode; emoji; text
# Everest Pipkin; AutoHotkey —; automation scripting language
# Electronic Nose; Applications; Survey —; summary; tech; limitations; applications; “; noses; chemical; sensors; machine
# falsisign; —; PDF
#
# Four short links: 8 April 2020
# ------------------------------
# System Design; Advanced Beginners; explanation; systems; acknowledgement; world; tools; strengths; weaknesses; ways
# reasons; choices; X; Sara; lot; X ”; “; Y; spur; moment; t; decision; time; ” Lozya — Teleconferencing; RPG
# Walk; talk; folks; conversations; corner; drop
#
# Hammerspoon —; desktop automation framework
# Lua; scripts; operating system functionality; keyboard/mouse; windows; displays
# CSAIL ’; Semester Potpourri; Hitchiker ’; Guide; Logical Verification; PDF; book; course; Microsoft Research ’; Lean
#
# Four short links: 7 April 2020
# ------------------------------
# —; source load; tool; define; behaviour; Python; code; system; millions
# @; nzigel; method; matte; foreground color; –; person; photos; videos; setting
# methods; screen background; trimap
#
# Obstructions; approach; obstructions; reflections; fence; occlusions; raindrops; sequence; images
# Primer —; summaries; Covid-19
#
#
# Governance and Discovery
# ------------------------
# Data Governance; candidate; topic; technology; something; middle-managers; friction; scientists
# thing; governance; data
# data; discovery; friction; process; data projects; reporting; intelligence
# idea; data; governance; regulation
# data; ”; rules
#
# way; Europe ’; s; GDPR; stringent; requirements; data; individuals; use; data; penalties; organizations
# US; California; data privacy law; CCPA; GDPR; ways
# need; data
# People; data; regulations
#
# dataset; merges; data sources
# data; notice; customer; example; GDPR ’
# data; consent
#
# data sources; biases
# set; tools; data; data warehouse; data
#
# time; companies; regulation; scrutiny
# machine learning; intelligence; models; astray; repercussions; data
# data; science; teams; amount; time; data; silo
# time; analysis
#
# data; isn; ’; t trustworthy; results; data
#
# Tools; data
#
# Tools; data; schema; data
#
# problem; data; data; data
# Companies; metadata; data means; data; columns; table
# Data; t; years; ’; t
# Companies; restrictions; data; ’; s use
# Datasheets; Datasets; metadata
# metadata; “; data; data scales; management
#
#
# requirement; s
# process; data; data
# ’; data; scientist; companies
# data—what; re
#
# source project; Amundsen; data; discovery
# data scientists; data; Lyft ’; “; data; lake; ”; implements; something; Google ’; PageRank; algorithm; data
#
# Amundsen; problem; tool; data
# metadata management; s; heart; data
# s; management; tools; Amundsen; ’
# Amundsen; tracks data; access; s; “; paper trail ”; data; implement; kind
# ’; t prevent someone; data; t
#
# track; data; lineage; users; metadata
# ’; solution—but; step
# management; data; governance; platforms; data; access
# paper trail ”; data; access; credentials
# data lineage; data catalogs; search
# tools; support; compliance; GDPR
# tools; data; governance
#
# data; t
# risk; data breaches; liability; customer; ’; s trust; don; ’; t
# Data; governance
# metadata; data; governance; enabler
#
#
# Four short links: 6 April 2020
# ------------------------------
# Rufus — Create; USB
# Audio Quality; Duo; WaveNetEQ — Google; filling; packets; voice; calls
# CRN++ —; language; mass-action; chemical; kinetics
# Interpreters —; story; writing; Crafting Interpreters
#
# Four short links: 3 April 2020
# ------------------------------
# Zero Trust Learning Curve; Palo Alto Networks; ’; t learn
# trouble; protect; surfaces; people
# Zero Trust; results
# organizations; failures
# fact; problem; one; organization; experience building; Zero Trust
# Software Engineering Advice; Large-Scale Distributed Systems; Jeff Dean; —; slide deck; Stanford
# gorkiy; —; decompilation; Russia ’; COVID-19
# Open Source; Experimental; Tiny Tools Roundup —; tons; tools; games; graphics; sounds; coding
#
# Four short links: 2 April 2020
# ------------------------------
# Imperial College ’; COVID19 Model —; github
# repository; replication
# bleeding edge code; advancements
# Readings; Time —; idea; Alan Kay ’; difference; data “; ”; context; FP; OOP; concept
# look; material
# area; lot; problems; research; fruits; labour; system
# collection; resources
# Douyin Suspending; Livestreamers —; Facebook ’; privacy; settings; t; people
# vim; awful
#
# Four short links: 1 April 2020
# ------------------------------
# Traffic; Test Proprietary; Systems; —; Wiresham; traffic; blackbox; systems.Outlaw; Innovations; paper; activities; hackers; usage; term; individuals; computer hardware; software
# innovations; Outlaw Innovations; firms; case; studies
# paper; phenomenon; innovation literature; implications; firm innovation; TikTok Algorithm Theories —; people
# kinda; people
# — Terminal; emulator meant; use; Oculus Rift
# bed; split keyboard
# movement; life; desk; step
#
#
# Four short links: 31 March 2020
# -------------------------------
# Releases Ventilator Designs —; source; license; license
# lawyers; Googling; meditech licensing
# dolt; version history
# Compare; version control
# Toast UI Editor —; WYSIWYG Markdown
# —; Coronavirus/Covid-19
# Care; answer; question; question; research design; Use; failures; predictions; mode; Form; beliefs; literature review; Don ’; form; beliefs; data; Be; theory; Choose; cases; theory; Convey; uncertainty
#
# What you need to know about product management for AI
# -----------------------------------------------------
# software product manager; PM; start; PM; intelligence; AI; machine learning
# game; coordinator; everything; developers; designers
# design; product-market fit; product
# ’; host; challenges; projects; unknowns; outcomes; infrastructures; processes
# lot; access; unique; value; AI
# AI; products; AI; tools; projects
# AI; products; business; plans; strategies; products; change; plans; strategies; value; business
# PM; AI; needs; everything; PM; understanding; machine; software development; view; capabilities
# AI; software development; AI; products; systems; collect; learn; data
# machine learning; part; AI; “; ”; algorithms; techniques
# ’; t; mathematics; engineering
# machine learning; techniques; computer; systems; ability; ”
# training; system; predictions; results; data; ’
# AI; systems; software; ways; difference; machine; shifts; engineering; process
# code; algorithms; rules; manner; ML; engineers; number; examples; input; output; pairs; training; data
# example; engineers; network; data; network; function
# case scenario; network; phenomenon; interest; correct output; input; data; model didn; ’; t see
# machine; systems; consumer internet; companies; models; times; day; billions
# Machine; uncertainty; machine learning; system; simpler; techniques; tradeoff; percentage; model; predictions
# shift; change
# network code; datasets; input; output; pairs
# model; outputs; code; changes; things; size; training; data; number; examples; network training; parameters
# implications; software testing; deployment
# input; program; ’; t; output; output
# Make; changes; training; data; training process; code; output; predictions
#
# model; code; code; artifact; code; training
#
# base; grows; demographics; behavior; population; production shift; training; data
#
# things; world; adapts; model ’; predictions
# model; fraud; kinds; fraud harder; actors; kinds; fraud
# Models; AI; products
# uncertainty; uncertainty
#
# development time; software; guesses
#
# AI; t
# t uncommon; weeks; months; something; accuracy; %
# model improvement; network design; input; features
# manager; model; week; month; try; one
# t; something
# AI; product estimation; strategies; Planning; estimation; AI; products; systems; training; data
# Imagine; data; scientist
# division; video; service; system
# baseline; filtering; models; teams; recommenders; MovieLens; Netflix
# someone; team; video recommender; project; requirements; experience; point
# scenario; Disney; team; problem; Netflix Prize
# catalog; number; movies; TV series; items; users; interests
# team; start problem; movies; system; feedback; data; recommendations; ratings; video viewing; data
# recommender system; Disney; data team; access; research
#
# video catalog; recommender system; consumer video app; anyone; content
# millions; videos; ratings; metadata; creators
# Social; signals; network; spam; abuse
# image; video analysis; recommendations; fraud; content; rules; example
# recommender system; model; level; accuracy
# challenges; recommender; amounts; UGC
# issues; teams; t; machine; systems
# complications; planning; system; recommenders; Netflix; project; schedule; abuse; problems; Netflix; ’
# examples; machine learning problem; business; movies; users; approach; differences; data
# development time; algorithm; domain
# Netflix; filtering algorithm; jobs; job
# surface; problems; dataset; items; jobs; users; job; seekers; theory; job seeker; ’; history; jobs; job; applications
# Complications; nuances; data; job
# Features; geography; job seniority
# Job; postings; lifetime; movies; features; metadata; company; skills; education; requirements
# Job; recommendations; challenges; diversity; bias; fairness; movie
# point isn; ’; t; AI; projects; s; t; AI; project
# strategies; uncertainty–starting; proverb; days; Agile; “; thing; ”; t; network; regression; average; project
#
# problems; shortcuts; machine; model; application; context
# prerequisites; AI; Particularly; company; AI; part; AI; product manager; ’; s job; organization; culture
# s; software development; risks; AI; people; companies; risks
# Jeff Bezos; things; answer; advance; company; company; media; buzz; machine; companies; advantages; prediction; planning; sales; aspect
# machine learning; hasn ’ t
# machine; projects; projects; business; people; VentureBeat; %; machine learning; products; production; Harvard Business Review; wave; AI; Machine; learning; dust
# plug; cloud; APIs
# Machine learning; rethinking; products; workflows
# Product; managers
# VentureBeat; reasons; failure; management; problems; money; developers; data; silos; people; ML
#
# solutions; AI; products; collaboration; teams; data silos; way; success; remedy
# data; concern; compliance; customer privacy; bias
# need; culture; implies; machine learning; consumer space
# enterprise; products; requirements; number; customers
# business; relationships
# Measurement; tracking; priority
# enterprise company; Oracle; lot; customers; Oracle ’; customer base; Amazon ’; Walmart ’
# Consumer; product management; volumes; feedback; tracking
# consumer internet; companies; analytics; infrastructure; product experience; measure
# type; data; infrastructure; foundation; building; AI
# ability; decisions; data analytics; prerequisite; culture. ”; path; companies; Google; Facebook; LinkedIn; analytics
# companies; part; product experience
# companies; data; product design
# machine; scale; movies; friends; ads; search
# user; agreements; data
# infrastructure; manage; data; AI; products; decisions
# pieces; companies; environment; machine learning; discoveries; innovation; AI; property
# AI; t
# foundation; culture; data; infrastructure
# AI Hierarchy; Needs; ” Monica Rogati; AI; capability; data infrastructure; data; collection; data; storage; data pipelines; data; preparation
#
# AI; product; managers; culture; infrastructure
#
# machine; projects; ways; projects; infrastructure; data; collection; developer
# project; search interface; product; lot; basics; ability; store
# become; problems; real-world
# ll; infrastructure
# start; relationships; relationships
#
# company; path; source; tools; platforms; power
# Lukas Biewald; founder; Figure Eight; Weights; Biases; “; companies
# tech company; custom machine; stack; team; way; this. ”; analytics; strategy
# mean; t; AI; goal
# Start; project; infrastructure; data; relationships; organization
# “; ” machine; problems; Any; product manager; part; team
#
# stakes; ideas; probability
# Product; managers; roadmaps; market value; months; costs
# AI; doesn; ’; t fit
# AI; pilot project; ’; t
#
# attention; product; ”
# MVP; stress; “; minimum ”; “
#
# demo; release; heuristics; models; regression
# something; pressure
# question; difference; technology
# things; AI; edge; engineering; t; engineering team; insight
# ideas; managers; t; risks; developers
#
# product; managers; AI; difference
# example; problem
# reach; machine learning algorithms; practice; text; state
# text; glance; inspection; errors; business
# “; art; intuition; ’
# intuition; experience–and; failures
# AI; products; part; “
# Jeremy Jordan; problem; ”; successes; AI; years; ’; magic; ’
# state; problems
# Jordan; advice; start; problem
# customers; pictures; phones; time; phone
#
#
# t; customers; pictures; ”
# t; detail; customers; pictures
# proxy; “; ” machine; problems; benchmark dataset; accuracy; goals; ML
# Data; labeling ease; proxy
# data; activities; product; example; spam; emails; shot; pairs
# money; services; data; cost–before; part
# amounts; raw; training; data; AI
# training; data; accuracy; levels; end; users
# product; gut feel; error; rates; t; error; rates
# Product; recommendations; nobody; products; customers; t want; t
# Fraud; detection; money; errors
# vehicles; matter
#
# kind; difference; effect; structure
# Work; things; business; advice; AI; products; matter
# problem; months; solution; nobody; cares; t; difference
# product manager; ’; jobs; team; problem
# data team; understanding; company; s; data; shortage; ideas
# ideas; list; machine
#
#
# machine learning system; mountain; data; engineering effort; payoff; needs
# buzz; AI; people; AI
#
#
#
#
# doesn; ’; t move
# product; something; customers; error; rates; development; investment; time
#
# judgements; AI; product manager; company; ’; s
# ability; analysis; SQL; queries; metrics
# t; data; trouble; ’
# trouble; problems; data quality–you; bones; %; data; scientist; time
# data familiarity; trouble; problems
# metrics; ’; t; product
# product; ’
#
# segment; customers; majority
# companies; building something cool
# Customers; problems; t care; kind
# t; AI
# business; mind; number; ways; features; product roadmap; product organization
# machine; teams; number; projects; prioritization
# companies; lot; data scientists; building; ML; platforms
# approach; issue; ML; product feature; ideas; theme; concentrate; ROI
# company; mission
#
# machine; application; objectives; accuracy; model; metrics; business
# connection; machine; application; something
# example; LinkedIn; co-author; Pete Skomoroch; mission; world; ’; s
# objective; company; profile; record; resume; data; LinkedIn; profiles
# project idea; objective; machine; model; skills; member
# team; impact estimate; product feature; increase; conversion rate; users; ML
# People; May Know; PYMK; example; type; alignment; LinkedIn ’; s; data
# PYMK; recommendation system; data; LinkedIn; connections; similarity; contacts; email; members
# PYMK; company; connections; machine
# number; engineers; data team; production machine; model
# months; growth; site; flywheel; growth; LinkedIn
# set; ideas; ones; align; objectives; number
# approach; everyone; room; system; group form consensus; estimates; difficulty; headcount; impact
# chart; impact; ease; project; return
# reality; prioritization; messy; fluid process; projects; dependencies; face; limitations; conflicts; stakeholder
# Scope; quality; teams
# something; business; criteria; access; data; ML
# companies; business; units
# development; ML; product; teams
# set; company
# Resources; product manager; world
#
# places; “; Rules; Machine Learning; Practices; ML Engineering ”; Google; People; AI Guidebook ”; Google; Machine Learning; Projects; ”; AWS; Great ML Experiences ”; Apple; O ’ Reilly Strata Data; AI Conference Insight Fellows Data PM Program; Spring; Full Stack Deep Learning Bootcamp; Berkeley; Rise; Data Product Manager ”; Trey Causey; Everything; Known; Building Data Products ”; First Round / DJ Patil; “; Does AI; tech; companies; ”; a16z; Product Management; AI ”; Pete Skomoroch; AI
# lot; AI; transformation; transformation; people; changes; culture; help; data infrastructure; problems; return
# The unreasonable importance of data preparation
# -----------------------------------------------
# world; models; algorithms; importance; data; preparation; quality; models
# garbage; garbage; principle; data; leads; results; algorithms; business
# car ’; algorithm; data; traffic; day; t; roads
# step; algorithm; environment; cars; humans; roads
# example described; garbage; side; equation; example; data; data; data
# executives; AI; transformation; Monica Rogati ’; s; AI Hierarchy; Needs; everything; foundation; data; Rogati; data science; AI; advisor; VP; data; Jawbone; LinkedIn; data; scientist; courtesy; Monica Rogati
# high-quality; data
# basing business; decisions; dashboards; results; experiments
# machine; side; Andrei Karpathy; director; AI; Tesla; Software; era; paradigm; software; machine learning; AI; focus; code; configuring; inputs; data; level; models
# world; data; citizen; computation; programs; thing
# model; data specification
# right data; approach; function
# Data; purpose; use
# value; data; myth; valuations; start-ups
# John Myles White; data; scientist; engineering manager; Facebook; risk; data; science; projects; data; se
# data; analysis plan
# data; ” John; attention; data; question; analysis [
# mindset; lot; example; data; early-stage; companies
# “; everything ”; maxim; tech
# data; water; semantics; data
#
# example; correlation; organization ’; database; experiment; causation; ]; pattern; tech; fraction; users; Z Z; Let ’; everybody; X Correlation; data; evidence; causation
# challenge; plagues
# case; Brian Wansink; head; Food; Brand Lab; Cornell University; Cornell; faculty review; misconduct; research; scholarship; misreporting; research; data; techniques; failure; document; research results.; ”; errors; data; hypotheses; stuck; hypothesis
# NPR; standard; studies; hypothesis; data
# Wansink ’; admission; blog post; ’; lab. ”; hypotheses; data; hypothesis; perversion
# Data; professionals; inordinate amount; time cleaning; data; modeling; machine learning; AI; data; analysis—this; realm; data
# data scientists; machine learning; models; day; trope; %; time; data; preparation
# news; ways; news; O ’ Reilly; survey; lack; data; data; quality; issues; bottlenecks; AI; adoption; companies; AI; evaluation stage; bottleneck; companies; AI
# quality; datasets; low-quality dataset; way
# Data; question; collection wasn; ’; t; “; cicago ”; location; “; ”; place; “ Chicago ”; data; way—e.g.; range; siloed; databases; organization; emails; spam ”; “; ”
# definition; low-quality; data defines; quality; function; work; data
# Look; responses; tweet; data; quality; nightmares; data professionals
# importance; data; preparation; conversation; AI; automation; machine learning; models; field
# models; scale; time; Google ’; search engine; tweets; Twitter; surfaces
# automation; steps; data; science workflow/pipeline
#
# amount; time
# Data; drudgery automation; era; data smog; data scientists; work; modeling; business; questions
# %; data scientists; data; preparation; part; work; CrowdFlower
# series; data; preparation; micro-decisions
# example; analyst; data; values
# micro-decisions; analysis; results; Analysts; Data; Set; Transparent How Variations; Analytic; Choices; Affect Results; ]; micro-decisions; study; preparation
# data; preparation; ’
# Model; results; individuals; hundreds
# benefit; work; sense; somebody; department; analysis; results; ]; number; algorithms; production; humans; loop; runtime; loop; managers; reservation; table; restaurant tonight; model; search model; model
# data; work; data pipeline; everything; time; data preparation; data; quality workflow; ”
# point; speaks; need; automation; parts; data
# need; devices; IoT; voice; assistants; drones
# Automation; case; democratization; data skills
# Democratization; education; work; DataCamp; tools
# importance; automation; democratization; parts; DS/ML/AI; workflow; data; collection; gathering; ]; data; ]; process
# tools; data; cleaning; data; preparation; emergence; tools; data; cleaning; preparation; HoloClean; Snorkel; Christopher Ré ’; group
# task; data; error detection; location; “; cicago ”; data; “; Chicago ”; fact; “; data; cleaning; learning; inference problem.; data; analysis; data; science work; combination; data; assumptions
# data; low-quality; data; ”; assumptions; statistics; inference
#
# user; assertions; domain expertise; respect; invariants; input
# supervision; HoloClean; team; system; “ building; [; datasets; labeling ”
# data; part; data; machine; models
#
# Snorkel; way; labeling; paradigm; data; programming; users; domain information [; heuristics; machine learning; models; level; bandwidth; ways; thousands; millions; data; points. ”; Researchers; Google AI; Snorkel; data; scale; utility; scenarios; topic classification; product classification
# Snorkel; doesn; ’; t stop
# aspects; data; preparation; Data; augmentation—that
# image recognition problem; cars; photos
#
# t; training; data; ’; data
# Discovery; data; example; subsets; data
# examples; data; preparation revolution; products; IBM
# future; data; data; preparation; challenge
# world; number; models; algorithms; production; amounts; streaming; data; education; tooling/products; domain; experts; interact; data
# lot; headway; democratizing; data; collection; building
# look; emergence; drag-and-drop; tools; machine learning; workflows; Google
# O ’ Reilly; survey; data; preparation; cleaning; lot; time; data professionals
# reason; tooling; data; cleaning
#
# future; data; preparation; data; quality; first-class; citizens; data; workflow; machine learning; learning
# incorrect; data
# data; surprise; amount
# problems; data; data; biases; example; estate redlining
# honest; conversations; organization; data
# fact; business; leaders; models; learning; data workers; time; data; preparation
# part; data; flow pipeline; future; everybody
# thanks; Angela Bassa; Angela Bowne; Vicki Boykis; Joyce Chung; Mike Loukides; Mikhail Popov; Emily Robinson; feedback; drafts; essay
# ]; example; ’; data; users; website; items
# data; website ’; search; results; bias; order
# ]; example; Mikhail Popov; data analyst; Wikimedia Foundation; re; years; data; insights; users; editors
# example; data; sources; history; projects; Analytics Datasets; questions; “; languages; Wikipedia; %; accounts; edit; hours; ”; traffic; pageviews; activity –; insights
# ]; focus; “; data.; ” “ Small; data; ”; manner; lot
# fact; poll; Americans; people; percent margin; error; sample; case; correction; methods
# “; thick; qualitative; data; ”; data
# ]; example; ’
# ]; Hadley Wickham ’; rendition; Tolstoy
# ]; expert; teams; data set; research question; soccer; referees; cards; players; players.; %; yes; %
# concerning; teams; results; teams
# paper; findings; variation; results; analyses; data; experts; intentions. ”; ] Yet; benefit; data; preparation; pipelines; form; techniques; methodology; alter; function; data
# research; scientists; preregistration; reproducibility crisis; research
# ]; machine; packages; TPOT; interfaces; Azure ’; s; machine
# ]; R Markdown
# ]; example; detection model; model; emails; spam ”; ”; training; data
# challenge; quality; data; data; Scale AI ’; Series C; round; valuation; Scale AI; humans; data
#
# Four short links: 24 March 2020
# -------------------------------
# Potential Distributed Reading Group; Distributed; Systems; —; folks; time; groups
#
# Just; socials; time; time
#
# Pigweed —; source collection; [ … ]; development
# See; Google Open Source; blog; FASTBuild; high-performance; source build system; Windows; Linux
# compilation; caching
# studios; world; developers; FASTBuild; production; day; PC/Mac/Linux; Consoles; Smartphones
#
# 3 ways to confront modern business challenges
# ---------------------------------------------
# business; leaders; perspectives; obstacles
# Craig Lemasters; president; CEO
# leadership; Assurant Solutions; size; transformation; offering; risk management; solutions; living space; markets
# Lemasters; Assurant; company; GXG; executive officer; growth; companies
# Disclosure; GXG; partner; Science House
# Jen Bruno; SVP; culture; capital; LPL Financial; firm; advisors
# career; Bruno; florist; Walt Disney
#
# Disclosure; LPL; client
# Dana Codispoti; head; HR; transformation
# BNY Mellon; Morgan Stanley; industries; consumer; products; pharmaceuticals
# engineering background; mind; data; analytics; Codispoti; change; processes; companies; eye; humanity
# James Jorasch; CEO; Science House; New
# years; Science House; Jorasch; head
# inventor; patents; patents; core; Priceline; innovation work; industries; health care
#
#
# learning; improvement; people; Craig Lemasters; Assurant Solutions; quarters
#
# time; quarter
#
# place. ”; Assurant ’; distribution model—big box; Lemasters; company; ’; future
# CEO; t; “; CEOs ”
# GXG; company; hurdle; wisdom; others
# learning; others; wisdom; position
# learning; relationship; humanity
# Technology; time
#
# mind. ”; HR; perspective; Codispoti
# Companies; things; power; robotics; AI; art; foundation
# companies; thing
# “; ’; world; things
# “; enabler. ”
# Every; business professional; learner
# people; change; ”
# company; employees; change; keeps; “; company; world-class
# “; people; mindset; improvement
#
#
# Share talent; knowledge; collaboration; outcomes. ”; Business; lessons; technology; processes; Companies; vision; world
# Create; star; people; people; problem
# “; spin
# people; t
# enterprise vision. ”; companies; Agile; software development; Agile; mindset; culture; companies; nature
# Smaller; pieces
# microservices; architecture; example; people
# Codispoti; process; vision; fragments
# “; Once; process ]; technology; changes; people; technology
# Huge; problems; James Jorasch; “; something; client; action; Science House; enterprise; clients; software; projects
# parallel; technology
# projects; transformations; impact; people; structures; nature; responsibilities; spans
# pieces; modules; role; structures
# nature; management; Agile
# ’; way
# Managers; people; processes; mindsets; skills; ”; information flow
# “; lessons; tech; people
#
#
#
# information; person; time; Humility; asset; themes; interviews; need
#
# “; Companies; cross-collaboration
#
# partner; experts
# t; opportunities.; ” Bruno; Lemasters; humility; trait
# Humility; people; energy; area; Bruno; capacity
# “; humility quotient
# A; willingness; leaders; thinking
#
# humility; people; swim
#
# s goodness; humanity; people; ” Jorasch; need; innovation; sessions; example; person; ’; comment; person
# Humility; people; authority
# humility; input; defensiveness; collaboration; respect; ’ s; peers
#
#
# An enterprise vision is your company’s North Star
# -------------------------------------------------
#
# King; co-director; EVP; business development; Science House; series; interviews; business; leaders; challenges; hurdles companies; business
# interview; chats; Dana Codispoti; head; HR Transformation; AIG; factor; business; transformations; employees
# future; human-technology relationship; technology; enabler; replacement
# highlights; conversation; technology iterating; speeds; companies; data; analytics; technology
# Codispoti; foundation; “ building; blocks; ”; innovation; object.; key; Codispoti; notes; technologies; processes; people; engagement; company; ’; s
# things; technology; initiatives; vision
# lot; work; trenches; people; t; picture—everybody; ’; project; set; projects
# ’; vision; company; North Star
# people; problem; people
# people; t; work; value add; picture; ”; risk; hurdle; company; technology; business
# Codispoti; solution; silos; comfort; zones; expertise; colleagues
# “; companies; cross collaboration
# “; someone; ’; s; example; business
# case; HR; finance; risk organization; audit
# people; silos; heads; people; experts
# Talk; partner; problems; solving
# People; opportunities
# s; silos; collaboration
# People; mindset; ‘; area; ’; ’
# transformations; culture; hats; enterprise; lead; enterprise mindset.; ”; future; humanity; ’; relationship; technology; Codispoti; machines; people
# “; ’; level; awareness; technology; future; lot; ways; ’; s; technology; humanity—we; ’; case
#
# …; end; day; work; work; process; culture; people; technology
# driving; enabling; time; everybody
# Nobody; technology; matter; things; ways; mind; technology
#
# Leaders need to mobilize change-ready workforces
# ------------------------------------------------
#
# King; co-director; EVP; business development; Science House; series; interviews; business; leaders; challenges; hurdles companies; business
# interview; chats; Jen Bruno; SVP; culture; capital; LPL Financial; workforce; leadership rotation; programs
# highlights; conversation; reality; Bruno; businesses; state
# humans; time; change; time; people; advantage
# “; Companies; time; workforce; people; careers; skills
# re; time; people; skills; department; area; imagination; creativity; innovation; companies; order
# opportunity; people; change; agents; areas
# Bridging; culture gaps—and communication gaps—; departments; Bruno; teams
# relationship; bridges
# “; fan; leaders; jobs
# way; empathy; work; people; roles
# ll; understanding; business operation
# business leader; empathy; network; people; ’; too.; ”; key; transition; work; future
# Every; business professional
# organizations; situations; business; people; things; ’
# value; companies; ”; end; development; approaches; face; changes
# “; PowerPoint; presentation; room; hour; somebody; talks; audience; ’; way; people
#
# Great leaders inspire innovation and creativity from within their workforces
# ----------------------------------------------------------------------------
#
# King; co-director; EVP; business development; Science House; series; interviews; business; leaders; challenges; hurdles companies; business
# interview; chats; James Jorasch; CEO; Science House; importance; innovation; talent
# highlights; conversation; Jorasch; techniques; innovation; ideas; disparate; sources; people
# “; people; people; perspectives; concepts; ideas; ”; invention isn; ’; talent
# “; people
# Believe; problem
#
#
# Trying; %; ”; juices; Jorasch; meetings; people; contributing
# “; meeting; people; ’; hiding; ’; s; Well
#
# sense; focus; people; imagination process.; focus
# “; ’; lot
# driven; way; problems
# everything; ’; re; thing; hours
#
# solutions; world.; ”; data; Science House; companies; years; insights; nature; management
# instance; Agile; business; systems; hierarchy; contributor; manager; director; VP; SVP
# “; rules
# “; t; rules; se
# collision; managers; directors; ‘; director; years—what; role; Agile; teams; People; re; ”; ’; cultures; approaches; leaders
# idea; microservices; example; way; thinking
# “; managers; directors; VPs; people; process; mindsets; skills; workers; problems; information flow
# set; skills; types; training.
#
# Strong leaders forge an intersection of knowledge and experience
# ----------------------------------------------------------------
#
# King; co-director; EVP; business development; Science House; series; interviews; business; leaders; challenges; hurdles companies; business
# interview; chats; Craig Lemasters; CEO; Global Executive Group; companies
# power; humility
# highlights; conversation; Digital; transformation ”; something
# key; transformation; Lemasters
# case; insurance company; Assurance Solutions; areas; focus; “; relationship
# [; ]; type; distribution model.; ”; space; Lemasters; knowledge; intersection; Lemasters; “; wisdom. ”; realization; Lemasters ’; “ ah-ha; moment; stumbling block; digital; t; knowledge; experience
#
# team; none; lot; knowledge; experience; thing
#
# knowledge; experience; room—could; point
# ’; passion; thing; wisdom; conversation; process; ”; Lemasters; humility
# decisions; rate; speed; today; village
# ‘; humility quotient ’; willingness; leaders; thinking
# criticism; ’
#
# humility; people; wisdom; lanes; speed
#
# Four short links: 23 March 2020
# -------------------------------
# Stanza; Python Natural Language Processing Toolkit; Many Human Languages — Stanza; pipeline; analysis; tokenization; expansion; lemmatization; feature tagging; dependency parsing
# Code; models
# Dropbear SSH — Dropbear; SSH; server
#
# Dropbear; source software
# Dropbear; “; ” -type Linux; Unix; systems; wireless
# Kit —; source privacy; system; locations; researchers; terms—e.g.; contact; coronavirus
# EAX Register; history; roots
#
# Four short links: 20 March 2020
# -------------------------------
# NASCAR Replaces; Races; Esports; Pro Drivers; Engadget; world
# Firebase Scrutinized; Antitrust; Regulators; — Firebase; Google; internet; ’; ad seller; information; consumers; ads; users; makers; Firebase
# Journey; Observability; Glitch ’; Story; Mads Hartmann; recap; journey; lots; heatmaps
#
#
# Nifty; idea; people
#
# 6 trends framing the state of AI and ML
# ---------------------------------------
# O ’ Reilly; learning; trove; information; trends; topics; issues; leaders
# data source; platform analysis; basis; report; look; topics; machine learning; ML; intelligence; AI; O ’ Reilly
# analysis; ML-; AI-related; data; O ’ Reilly; platform; usage
# Deep; learning; % relative; learning; %; AI/ML
# TensorFlow; %; % share; AI/ML
# PyTorch; contender; growth; share
# Reinforcement; %
# strength; learning; networks; reinforcement learning; organizations; ML; tools
#
# AI/ML; topics; O ’ Reilly; platform; rate; change
# Growth; ML; AI; Engagement; intelligence topic; %; %; Figure; share growth; machine; topic; %
# intelligence; machine learning; topics accounts; %; activity; platform; touch; %; “; data; science; ”; topic
# Data; engineering; topic; data; category; %; share; platform
# data engineering share; %; declines; engagement; data; management
#
# High-level; data topics; O ’ Reilly; platform; rate; change
# learning; Interest; learning topic; usage; %; %; ]
#
# people; cases; serves; default; strategy
# topic; growth; users; tools; use; cases
# analogy; users; learning methods—e.g.; regressions; support vector machines—than
# learning; contrast; ’; t; names; methods—e.g.; applications; networks
# ...
# Challenge; Software Liability — Liability; insecure software
# question; Congress; shape
# Talks — video; archive
#
# Research; Papers; Internet Censorship —; papers; CensorBib; approach; topic; angle; designs; censorship; systems
#
# Four short links: 16 March 2020
# -------------------------------
# Uncensored Library — Reporters; Borders; library; Minecraft
# Gizmodo; Shmoocon; Talk Recordings —; everything; addresses; way; Zero Trust; media
# Privacy; Comparison; Libraries —; look; dataset size; affects; accuracy; privacy level; epsilon
# case; results; privacy
# Layoffs; Jacob Kaplan-Moss; —; elder
#
# Four short links: 13 March 2020
# -------------------------------
# OpenAM; management solution; authentication; SSO; authorization; federation; entitlements; web; services
# Relationships; Remote Engineering Manager —; t; re; lot
# API Security Maturity Model —; framework; idea; maturity model; APIs
# Level; API Keys; Basic Authentication; Level; –; Authentication; Level; –; Authorization; Level
# Architecture; Netflix; idea; Hexagonal Architecture; inputs; outputs; edges
# Business logic; REST; GraphQL API; data; database; microservice; API; gRPC; REST; CSV
# Netflix; concept
#
# Four short links: 12 March 2020
# -------------------------------
#
# case; project owner; Amazon; AWS
# Design Guide; Writing Offline-first Apps —; article; engineering; applications; user experience
# Zero Trust Information —; end; internet—to try; castle; moat; information; tradeoffs; value
#
# Ben; access; encryption
# Corporate Engineering Blogs Are Written; Dan Luu; —; order; blog; corporation; engineers
# state; corporations; risk aversion; people; case; PR
# Presents; process; couple; companies; blogs
#
# Four short links: 11 March 2020
# -------------------------------
# — Cory Doctorow ’; news site; newsletter; WhatsApp; modders
# Mapnik — LGPLed; software; image output; algorithms; interfaces; C++; Python
# pi node; π-box; system; broadcast; multiples inputs
# aims; micro-FM
# approach; ’; artist; researcher; Tetsuo Kogawa; transmissions; FM; perimeter; house; block
# combines; transmission; possibilities; ethernet; Wi-Fi; possibilities
# system; source; source software; /
# AutoML-Zero —; search; math; operations; direction; search; shows; results; regression; descent; networks; backpropagation; surpass; baselines
#
#
# Four short links: 10 March 2020
# -------------------------------
# MLflow; source platform; ML; lifecycle; experimentation; reproducibility
# components; tracking; projects
# Facets; Tim Bray; word “; crawl; series; posts; A+
# Workbox — JavaScript Libraries; support; apps
# TensorFlow Quantum; library
# See; paper; Google AI Blog
#
# Four short links: 9 March 2020
# ------------------------------
# Sno — Distributed; version control
# git; geo; data
#
# Woman; Babysitter; Biases; Language Generation —; prompts; woman; ”; person; ”; generation; systems
# Violent Peng; Online Academic Conference; Workbook —; conferences; center; interest
# Franklin Sayre; Problems; Your Multithreaded Code —; set
# languages; libraries; concepts; time; concurrency today; t
# article; challenges; presents; advice
#
# Four short links: 6 March 2020
# ------------------------------
# Soul; New; Machine; Computer; Bryan Cantrill; talk; Stanford; vision; machine—and; advances; firmware; RISC-V; Rust; role
# ’; Use; Problems; part; team; ’; t; lot; pain
# See; discussion; Lobsters
# Landmark Computer Science Proof Cascades; Physics; Math; Quanta; Computational; complexity; ’; s
# resources; computers; problems—time
# reason; discoveries; physics
#
# Millions; Tiny Databases —; reasoning; design; control plane
# decade; introduction; Availability Zones ]; failure; availability; attention; radius; correlation
# outages; number; resources; customers; approach
# philosophy; everything; size; datacenter; design; services
# Radar trends to watch: March 2020
# ---------------------------------
# AI; practice; book; TinyML; Pete Warden; talks; stickers; AI; communicate; radio; contain; sensors; machinery
# technology; bluetooth; stickers; ambient
# year; Foster Provost; causality; thing; data
# trend; years; AI; technology; cause; effect
# Democratization; learning; ’; idea; t
# models; cost; training; time; system
# issues; AI; transition; research; development; production
# aspect; transition; challenge; models; OpenAI ’; GPT-2; Google ’
# coincidence; language
# signs; machine learning; edge; fact; way; edge
# O ’ Reilly Software Architecture Conference; New York; Mary Poppendieck; absurdity; vacuum
# kind; intelligence; needs; edge
# COVID-19; Coronavirus; impact; economy; shutdown; factories; China; disruption; supply; chains; deal; ’
# Coronavirus; opportunity; technology
# China; work; AI; education; t; closing
# agriculture; Autonomous; vehicles; farm; time
#
# t; traffic; laws
# Cornell ’; College; Agriculture
# Schools; Netherlands; China
#
# ’; s; startup; Tillable; “; AirBnB; farmland; ”; trouble; farm
# Cybersecurity; ’; government comment; websites
# FCC; demise
# ’; s; surprise; government
# Lidar; intrusion detection system
#
# system; attacks; ability; anomalies; information; kinds
# Future; Artificial; qubits; breakthrough
# RapidQL; source; query language; APIs; sign-on; access; APIs; REST; SOAP
# API; consolidation; m; step
# trends; Mark Zuckerberg; regulation; systems; place; liability
# issue; content; way; media; capabilities; systems; pieces
# zsh; time; lot; traction
# Don ’; t forget; default shell; OS X
# DNS; part; Internet; issues; sale; .org
# Handshake Network; alternative; ICANN ’; control; DNS
# lot; problems; Handshake; work; application
#
# Four short links: 5 March 2020
# ------------------------------
#
#
# Hickey; Better Developer —; thing; comfort zone; skill
# Mastery; combination; knowledge; focus; relentless; practice; period; time; failures; expert
#
# NGINX Admin ’; Handbook —; handbook; set; rules; recommendations; NGINX; source; HTTP
# practices; notes; helpers
#
#
#
# Remembering Freeman Dyson
# -------------------------
# Freeman Dyson; week; age; fall; cafeteria; Institute; Advanced; Studies; Princeton
# resist; outpouring; appreciation
# place; mind; heart; someone; person
# Freeman; stage; OSCON; son; George; subject
# standards; information storage
# room; ideas; ”; Freeman; moment; perspective
# example; paper; age; case; visualizations; Richard Feynman; calculations; physicists; Schwinger; Shin ’; ichirō; Tomonaga; paper; Feynman; Schwinger; Tomonaga; Nobel Prize; Physics; theory; quantum
# talent; Freeman; heart; things; statistician; operations; research section; Royal Air Force Bomber Command
# volumes; autobiography; Universe; pattern; bullet; holes; bombers; Britain; forays; eye; areas
# Freeman; reinforcement; areas; damage; planes; hits; regions
#
# George; email; group; friends; Freeman ’; death; Danny Hillis; story; gift; Freeman ’; s; things
# “; ” Danny; “; conversation
# lunch; stairs; office
#
#
# thing; ”; world doesn; ’; sense; t; observations
#
# memory; Freeman; air
# Kenneth Brower ’; book; Starship; Canoe; Freeman ’; Project Orion; George ’; canoes; Pacific Northwest; account; way; Freeman; notice anyone; him—his; world; thought; middle
#
#
# someone; sound; car accident; conversation
#
# experience; world; concentration
# moment; fragment; conversation
# physicist; Michael Crichton ’; Prey; monster; jour; swarm
# something; isn; nanoparticles
# Anyone; particle; medium; air; moves; velocity proportional
#
#
# world; lens; ideas
# Freeman; gift; words; numbers
#
#
# pieces; writing; foreword; collection; Richard Feynman ’; s; essays; Pleasure
# years; book; time; Freeman ’
# account; paper; quantum; electrodynamics; appreciation; Freeman
# Freeman ’; life; career; obituaries; New York Times; week; man
# place; “; man; side idolatry; Elizabethan; dramatist
# man ”; Jonson ’; friend; mentor
# Jonson; Shakespeare
# Jonson; Shakespeare
#
# Shakespeare; years; London; stage; masterpieces
# Shakespeare; Jonson; “; nature; ”; help
# help; Shakespeare; roles; Jonson ’; s; Every; Man; Humour
# play; success; Jonson ’
#
# Jonson; poems; plays; plays; Shakespeare ’
# Jonson; right; poet; scholar; end; life
#
# Shakespeare; Jonson; poem; “; Memory; My Beloved Master; William Shakespeare; ”; lines; “; age; ” …; Jonson; Shakespeare
#
# Jonson; man; side idolatry; ” Fate; luck; Feynman
# student; England; Cornell University; genius
# arrogance; youth; Jonson; Feynman ’; s
# Shakespeare; American; soil
# Feynman; number; papers; clever; tricks
#
#
# anyone struggle; workings; nature; physics; opportunity; Feynman; talk; deluge
#
#
# year; Feynman; way; nature; pictures; diagrams; ends
# numbers; diagrams
# speed; quantities
#
# summer; Jonson ’; words; Nature; herself; proud; designs; dressing; ”; year; Feynman; work; physicists; Schwinger; Tomonaga; paths
# Schwinger; Tomonaga; methods; quantities; Feynman
# Schwinger; Tomonaga
# physics; methods; numbers
# results; calculations; Feynman; opportunity
# paper; Physical Review; career; Every; Man; Humour; ”; Jonson ’
#
# Feynman; years
# protagonists; dignity; respect; heart; Feynman; purpose; paper; ideas; physicists
# Feynman; ideas
#
#
#
#
# Freeman Dyson; celebration; Institute; Advanced
#
# photo; George Dyson; courtesy; Dyson
#
# Four short links: 4 March 2020
# ------------------------------
# tota11y; source; ]; accessibility visualization toolkit
# DOS Pi; DOS; computer
#
# Proficiency; time; time
# Cybersecurity Law; Policy; Infrastructure —; text; eCasebook ”; ground; nature; policy; questions
# aim; reader; nature; functions; government; private-sector; actors; cybersecurity; United; States; policy; goals; issues; challenges; environment
# beginners; background
#
# Four short links: 3 March 2020
# ------------------------------
# Facebook ’; Incomplete Download Your Data; Privacy International; Facebook; claim; “ Download; Information ”; doesn; ’; t provide; users; list; advertisers; list
# user; rights; GDPR; t; companies; data
# Information; advertisers; name; contact; details; users
# Off-Facebook; feature; issues; advertisers; data; data
# Bruce Schneier; Proxy Verifier —; HTTP; replay tool; behavior; HTTP
# binary; verifier-server binary; set; YAML; JSON; files; HTTP; traffic
#
# Stripe ’; Covid-19 Company Plan —; time; working consultant; nobody; culture; ’; remote work; practices; staff; move comms; channel; people; t online
# Google ’; Tech-Writing Course —; collection; courses; resources
#
#
# The death of Agile?
# -------------------
# article; death
# article; Agile; ’
# problem; claim; Agile; ”; Eben Hewitt; conversation; movement; parody; ”; point
#
#
#
#
#
# company; lot; practices
#
#
#
#
#
#
#
# practices; rituals; work; “; agile. ”; kind; Agile
# ’; t
# thing; t see; thing; anything; value; Agile; conversation; customer
#
# Agile; developers
# Scrum; Agile; developers; touch; people; users; customers; project; t; course; something; words; Douglas Adams; tea. ”; Agile; fundamentalist; Agile
#
# programming; shops; software; developers; touch; users
#
#
#
#
#
# software; developers; people
# t; sales people
# product owner; job—especially; product; owners; ’; t; contact
# story; company; salesperson; sale; feature; ’; t; t
#
# project; track; requirement wasn; ’; t; possible—not
# Agile ’; principle; interaction; customer; corollary
# corrections; end; finding
# ’; clue; word
# software; developers
#
# mistakes; ones; re
# t; Agile; ’; t work
# t care; projects; methodology; b; get; lot; features; c; customer
# projects; momentum
# project; direction
# Agile; ’; t
#
# Agile; tools; projects; track; tools; service; ’; fault
# years; Agile Manifesto; Agile; number
# data; science; intelligence
# Development; timelines; projects; t; software; meaning; ”; ways
# Progress; software
# something; weeks
# AI; months; model—and; standup meeting; “; experiments; ’; t; progress; ”
# yardstick; AI; projects; experiment
#
# teams; problems; writers; “; pizza group; concept; t; work
#
# t; lines; code support; Amazon ’; core business; software; developers
# value; interactions
# Make; interactions; project
# principle; contact; customer
# concept; context
# t; Agile; ”; t; ”
# Agile; Manifesto; points; number; problems; software development
# solutions; breach; observance; Eben; methodology
# Eben; solution isn; ’; t; Agile
#
# power; rewards; punishments; lie
#
# organization; questions; lot
#
#
#
# contact; customers; in-person; communications; team; members; practices; source control; testing; air
# t agonize; practices; create; rituals
#
# —; Mike Loukides Radar; data; points; research; analysis; areas; tech; leaders; search; data; O ’ Reilly
# data; signals; trends; topics; issues
#
# programming language; O ’ Reilly; %
# year; growth; Python; usage; popularity; data scientists; machine learning; ML; intelligence; AI
# Software; architecture; infrastructure
# shift; design; software architecture; infrastructure
# infrastructure; operations
#
#
#
# ML+AI; topic; topics
# Growth; topic; %
# data; topic; ML+AI; %; usage
#
# usage; cloud; platforms; %
# interest; migrations—usage; %; top; %
#
# Aggregate; security usage; %; year; usage; security; certifications; CompTIA Security; +50; %; CompTIA CySA+; +59
# plenty; security; risks; business; executives; sysadmins; DBAs; developers
# survey; state; data
# topic; responses
# Key; survey; results; C-suite; data
# CxOs; vice; presidents; directors; %; survey
# Data; scientists; analysts; data engineers; people; %; audience; developers; managers
#
# organizations; data; quality
# %; organizations; data; provenance
#
# AI; data
# half; %; respondents; data; analysis; machine learning; AI; tools; data; quality
# respondents; latent; data; quality
# AI; catalyst; data
# Organizations; data; quality
# data sources; inconsistent
# t; resources; data; quality
# ’; s
# building; blocks; data; governance
# basics; metadata; creation; management; data; provenance; data; lineage
# archive; Radar; research
#
# Four short links: 2 March 2020
# ------------------------------
# Gandalf; Intelligent; End-to-end Analytics Service; Safe Deployment; Cloud-scale Infrastructure; paper; Azure ’; software; data; day; platform; events; average; peak; API; calls; data; fault
# Gandalf; ’; t; data; rollout; alert
# s; Paper; summary; paper; Quarantine; Cooking; New Yorker; internet; battleground—activists; censors
# comforting; parts
# Quarantine; captures; boredom; loneliness; creativity; desire; connection; anxiety
#
# Draft; Book —; draft; introduction; learning; fast.ai
# p5.js; celebratory; Medium; post; ’; release; everything; I18N; libraries
#
# Four short links: 28 February 2020
# ----------------------------------
# Coronavirus Responsibly; ESRI; Let ’; look; maps
#
# Don ’; t; Use Low-fidelity Prototypes; Test Desirability —; techniques; desirability; brand; products; mock screencast; pages; Web Inspector; design tool; screen; ”; site; mockups
# Data Center Power; Jess Frazelle; dive; power; concerns; data; centers; “; hyperscalers; MSFT
#
# Wildcard; Customization; Web Applications —; paper; customization; technique; users; software
# idea; application ’; UI; spreadsheet; application; ’; s
# user; spreadsheet; data; changes; UI
#
# Four short links: 27 February 2020
# ----------------------------------
# BellTopo Sans —; typeface; font; sans
# Flowing Data; YC ’; Guide; Raising Series A —; guide; distillation; everything
# insights; hundreds; founders
# Information; Disorders; Renee DiResta; —; survey; approaches; range; challenges; information environment; proposals; ads; privacy; laws
# Fast.ai; Issues — Issues; flavors; example feature; requests; bug; reports; customer; complaints; security; alerts; team
# page; team
#
# Intellectual control
# --------------------
# highlight; O ’ Reilly Software Architecture Conference
# version; keynote; O ’ Reilly
#
#
# Highlights from the O’Reilly Software Architecture Conference in New York 2020
# ------------------------------------------------------------------------------
# People; software architecture world; New York
# links; highlights
# elephant; architecture; Martin Fowler; reveals; discusses; vents
# Watch; elephant; architecture “
# Mary Poppendieck; history
# Watch “ Where; architectures; Architecture.Next; Invalidating; axioms; Mark Richards; axioms; software architecture; state
# Watch “ Architecture.Next; Invalidating; axioms; Kai Holnes; walks; world; outlets
# Watch “ Sometimes; Intellectual; control; George Fairbanks; today; ’; s complex software
# Watch “ Intellectual; control “; trenches; Rachel Laycock Neal Ford; Rachel Laycock; career path; work
# Watch; “; trenches; Rachel Laycock

# %% [markdown]
# ## Visualizing interactions between entities with HTML output

# %%
import os
import json
import nltk
from IPython.display import IFrame
from IPython.core.display import display

BLOG_DATA = "feed.json"

HTML_TEMPLATE = """<html>
    <head>
        <title>{0}</title>
        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
    </head>
    <body>{1}</body>
</html>"""

blog_data = json.loads(open(BLOG_DATA).read())

for post in blog_data:

    post.update(extract_interactions(post['content']))

    # Display output as markup with entities presented in bold text

    post['markup'] = []

    for sentence_idx in range(len(post['sentences'])):

        s = post['sentences'][sentence_idx]
        for (term, _) in post['entity_interactions'][sentence_idx]:
            s = s.replace(term, '<strong>{0}</strong>'.format(term))

        post['markup'] += [s] 
            
    filename = post['title'].replace("?", "") + '.entity_interactions.html'
    f = open(os.path.join(filename), 'wb')
    html = HTML_TEMPLATE.format(post['title'] + ' Interactions', ' '.join(post['markup']))
    f.write(html.encode('utf-8'))
    f.close()

    print('Data written to', f.name)
    
    # Display any of these files with an inline frame. This displays the
    # last file processed by using the last value of f.name...
    
    print('Displaying {0}:'.format(f.name))
    display(IFrame('files/{0}'.format(f.name), '100%', '600px'))
# Out:
# Data written to Four short links: 30 April 2020.entity_interactions.html
# Displaying Four short links: 30 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 30 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 29 April 2020.entity_interactions.html
# Displaying Four short links: 29 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 29 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 28 April 2020.entity_interactions.html
# Displaying Four short links: 28 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 28 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 27 April 2020.entity_interactions.html
# Displaying Four short links: 27 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 27 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 24 April 2020.entity_interactions.html
# Displaying Four short links: 24 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 24 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 23 April 2020.entity_interactions.html
# Displaying Four short links: 23 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 23 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to How data privacy leader Apple found itself in a data ethics catastrophe.entity_interactions.html
# Displaying How data privacy leader Apple found itself in a data ethics catastrophe.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/How data privacy leader Apple found itself in a data ethics catastrophe.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 22 April 2020.entity_interactions.html
# Displaying Four short links: 22 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 22 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 21 April 2020.entity_interactions.html
# Displaying Four short links: 21 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 21 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 20 April 2020.entity_interactions.html
# Displaying Four short links: 20 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 20 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 17 April 2020.entity_interactions.html
# Displaying Four short links: 17 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 17 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 16 April 2020.entity_interactions.html
# Displaying Four short links: 16 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 16 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 15 April 2020.entity_interactions.html
# Displaying Four short links: 15 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 15 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 14 April 2020.entity_interactions.html
# Displaying Four short links: 14 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 14 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Radar trends to watch: April 2020.entity_interactions.html
# Displaying Radar trends to watch: April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Radar trends to watch: April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 13 April 2020.entity_interactions.html
# Displaying Four short links: 13 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 13 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 10 April 2020.entity_interactions.html
# Displaying Four short links: 10 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 10 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 9 April 2020.entity_interactions.html
# Displaying Four short links: 9 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 9 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 8 April 2020.entity_interactions.html
# Displaying Four short links: 8 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 8 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 7 April 2020.entity_interactions.html
# Displaying Four short links: 7 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 7 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Governance and Discovery.entity_interactions.html
# Displaying Governance and Discovery.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Governance and Discovery.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 6 April 2020.entity_interactions.html
# Displaying Four short links: 6 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 6 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 3 April 2020.entity_interactions.html
# Displaying Four short links: 3 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 3 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 2 April 2020.entity_interactions.html
# Displaying Four short links: 2 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 2 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 1 April 2020.entity_interactions.html
# Displaying Four short links: 1 April 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 1 April 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 31 March 2020.entity_interactions.html
# Displaying Four short links: 31 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 31 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to What you need to know about product management for AI.entity_interactions.html
# Displaying What you need to know about product management for AI.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/What you need to know about product management for AI.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to The unreasonable importance of data preparation.entity_interactions.html
# Displaying The unreasonable importance of data preparation.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/The unreasonable importance of data preparation.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 24 March 2020.entity_interactions.html
# Displaying Four short links: 24 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 24 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to 3 ways to confront modern business challenges.entity_interactions.html
# Displaying 3 ways to confront modern business challenges.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/3 ways to confront modern business challenges.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to An enterprise vision is your company’s North Star.entity_interactions.html
# Displaying An enterprise vision is your company’s North Star.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/An enterprise vision is your company’s North Star.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Leaders need to mobilize change-ready workforces.entity_interactions.html
# Displaying Leaders need to mobilize change-ready workforces.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Leaders need to mobilize change-ready workforces.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Great leaders inspire innovation and creativity from within their workforces.entity_interactions.html
# Displaying Great leaders inspire innovation and creativity from within their workforces.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Great leaders inspire innovation and creativity from within their workforces.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Strong leaders forge an intersection of knowledge and experience.entity_interactions.html
# Displaying Strong leaders forge an intersection of knowledge and experience.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Strong leaders forge an intersection of knowledge and experience.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 23 March 2020.entity_interactions.html
# Displaying Four short links: 23 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 23 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 20 March 2020.entity_interactions.html
# Displaying Four short links: 20 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 20 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to 6 trends framing the state of AI and ML.entity_interactions.html
# Displaying 6 trends framing the state of AI and ML.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/6 trends framing the state of AI and ML.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 19 March 2020.entity_interactions.html
# Displaying Four short links: 19 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 19 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to It’s an unprecedented crisis: 8 things to do right now.entity_interactions.html
# Displaying It’s an unprecedented crisis: 8 things to do right now.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/It’s an unprecedented crisis: 8 things to do right now.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to AI adoption in the enterprise 2020.entity_interactions.html
# Displaying AI adoption in the enterprise 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/AI adoption in the enterprise 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 18 March 2020.entity_interactions.html
# Displaying Four short links: 18 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 18 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 17 March 2020.entity_interactions.html
# Displaying Four short links: 17 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 17 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 16 March 2020.entity_interactions.html
# Displaying Four short links: 16 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 16 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 13 March 2020.entity_interactions.html
# Displaying Four short links: 13 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 13 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 12 March 2020.entity_interactions.html
# Displaying Four short links: 12 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 12 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 11 March 2020.entity_interactions.html
# Displaying Four short links: 11 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 11 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 10 March 2020.entity_interactions.html
# Displaying Four short links: 10 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 10 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 9 March 2020.entity_interactions.html
# Displaying Four short links: 9 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 9 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 6 March 2020.entity_interactions.html
# Displaying Four short links: 6 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 6 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Radar trends to watch: March 2020.entity_interactions.html
# Displaying Radar trends to watch: March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Radar trends to watch: March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 5 March 2020.entity_interactions.html
# Displaying Four short links: 5 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 5 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Remembering Freeman Dyson.entity_interactions.html
# Displaying Remembering Freeman Dyson.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Remembering Freeman Dyson.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 4 March 2020.entity_interactions.html
# Displaying Four short links: 4 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 4 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 3 March 2020.entity_interactions.html
# Displaying Four short links: 3 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 3 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to The death of Agile.entity_interactions.html
# Displaying The death of Agile.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/The death of Agile.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 2 March 2020.entity_interactions.html
# Displaying Four short links: 2 March 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 2 March 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 28 February 2020.entity_interactions.html
# Displaying Four short links: 28 February 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 28 February 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Four short links: 27 February 2020.entity_interactions.html
# Displaying Four short links: 27 February 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Four short links: 27 February 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Intellectual control.entity_interactions.html
# Displaying Intellectual control.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Intellectual control.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Data written to Highlights from the O’Reilly Software Architecture Conference in New York 2020.entity_interactions.html
# Displaying Highlights from the O’Reilly Software Architecture Conference in New York 2020.entity_interactions.html:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/Highlights from the O’Reilly Software Architecture Conference in New York 2020.entity_interactions.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
